# %%
import pandas as pd

# %%
data=pd.read_csv("Placement.csv")

# %%
data
# Out:
#      sl_no  gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1       0  67.00   Others  91.00   Others  Commerce     58.00
# 1        2       0  79.33  Central  78.33   Others   Science     77.48
# 2        3       0  65.00  Central  68.00  Central      Arts     64.00
# 3        4       0  56.00  Central  52.00  Central   Science     52.00
# 4        5       0  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...     ...    ...      ...    ...      ...       ...       ...
# 210    211       0  80.60   Others  82.00   Others  Commerce     77.60
# 211    212       0  58.00   Others  60.00   Others   Science     72.00
# 212    213       0  67.00   Others  67.00   Others  Commerce     73.00
# 213    214       1  74.00   Others  66.00   Others  Commerce     58.00
# 214    215       0  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
#1. Display all students who got placed.
data[data["status"]=="Placed"]
# Out:
#      sl_no  gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1       0  67.00   Others  91.00   Others  Commerce     58.00
# 1        2       0  79.33  Central  78.33   Others   Science     77.48
# 2        3       0  65.00  Central  68.00  Central      Arts     64.00
# 4        5       0  85.80  Central  73.60  Central  Commerce     73.30
# 7        8       0  82.00  Central  64.00  Central   Science     66.00
# ..     ...     ...    ...      ...    ...      ...       ...       ...
# 209    210       0  62.00  Central  72.00  Central  Commerce     65.00
# 210    211       0  80.60   Others  82.00   Others  Commerce     77.60
# 211    212       0  58.00   Others  60.00   Others   Science     72.00
# 212    213       0  67.00   Others  67.00   Others  Commerce     73.00
# 213    214       1  74.00   Others  66.00   Others  Commerce     58.00
#
#       degree_t workex  etest_p specialisation  mba_p  status    salary
# ...

# %%
#2. Show records of students who were not placed.
data[data["status"]=="Not Placed"]
# Out:
#      sl_no  gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 3        4       0   56.0  Central   52.0  Central   Science     52.00
# 5        6       0   55.0   Others   49.8   Others   Science     67.25
# 6        7       1   46.0   Others   49.2   Others  Commerce     79.00
# 9       10       0   58.0  Central   70.0  Central  Commerce     61.00
# 12      13       1   47.0  Central   55.0   Others   Science     65.00
# ..     ...     ...    ...      ...    ...      ...       ...       ...
# 198    199       1   67.0  Central   70.0  Central  Commerce     65.00
# 201    202       0   54.2  Central   63.0   Others   Science     58.00
# 206    207       0   41.0  Central   42.0  Central   Science     60.00
# 208    209       1   43.0  Central   60.0   Others   Science     65.00
# 214    215       0   62.0  Central   58.0   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status  salary
# ...

# %%
#3. Display students with ssc_p (10th percentage) greater than 80.
data[data["ssc_p"]>80]
# Out:
#      sl_no  gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 4        5       0  85.80  Central  73.60  Central  Commerce     73.30
# 7        8       0  82.00  Central  64.00  Central   Science     66.00
# 33      34       1  87.00   Others  65.00   Others   Science     81.00
# 39      40       0  81.00   Others  68.00   Others   Science     64.00
# 43      44       0  87.00   Others  87.00   Others  Commerce     68.00
# 61      62       0  84.20  Central  73.40  Central  Commerce     66.89
# 62      63       1  86.50   Others  64.20   Others   Science     67.40
# 66      67       0  83.00   Others  74.00   Others   Science     66.00
# 67      68       0  80.92   Others  78.50   Others  Commerce     67.00
# 70      71       0  82.00   Others  61.00   Others   Science     62.00
# 72      73       0  84.86   Others  67.00   Others   Science     78.00
# 78      79       0  84.00   Others  90.90   Others   Science     64.50
# ...

# %%
#4. Retrieve all students whose hsc_p (12th percentage) is less than 70.
data[data["hsc_p"]<70]
# Out:
#      sl_no  gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 2        3       0   65.0  Central   68.0  Central      Arts     64.00
# 3        4       0   56.0  Central   52.0  Central   Science     52.00
# 5        6       0   55.0   Others   49.8   Others   Science     67.25
# 6        7       1   46.0   Others   49.2   Others  Commerce     79.00
# 7        8       0   82.0  Central   64.0  Central   Science     66.00
# ..     ...     ...    ...      ...    ...      ...       ...       ...
# 208    209       1   43.0  Central   60.0   Others   Science     65.00
# 211    212       0   58.0   Others   60.0   Others   Science     72.00
# 212    213       0   67.0   Others   67.0   Others  Commerce     73.00
# 213    214       1   74.0   Others   66.0   Others  Commerce     58.00
# 214    215       0   62.0  Central   58.0   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
#5. Select students who have degree_p greater than 75 and mba_p greater than 60.
data[(data["degree_p"]>75) & (data["mba_p"]>60)]
# Out:
#      sl_no  gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 1        2       0  79.33  Central  78.33   Others   Science     77.48
# 11      12       0  69.60  Central  68.40  Central  Commerce     78.30
# 21      22       1  79.00   Others  76.00   Others  Commerce     85.00
# 24      25       0  76.50   Others  97.70   Others   Science     78.86
# 33      34       1  87.00   Others  65.00   Others   Science     81.00
# 40      41       1  78.00  Central  77.00   Others  Commerce     80.00
# 44      45       1  77.00   Others  73.00   Others  Commerce     81.00
# 72      73       0  84.86   Others  67.00   Others   Science     78.00
# 75      76       1  59.00  Central  62.00   Others  Commerce     77.50
# 85      86       1  83.84   Others  89.83   Others  Commerce     77.20
# 90      91       1  85.00   Others  90.00   Others  Commerce     82.00
# 96      97       1  76.00  Central  70.00  Central   Science     76.00
# ...

# %%
#6. Display all male students with workex equal to “Yes”.
data[(data["gender"]==1) & (data["workex"]=="Yes")]
# Out:
#      sl_no  gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 15      16       1  65.00  Central  75.00  Central  Commerce     69.00
# 23      24       1  77.40   Others  60.00   Others   Science     64.74
# 25      26       1  52.58   Others  54.60  Central  Commerce     50.20
# 33      34       1  87.00   Others  65.00   Others   Science     81.00
# 41      42       1  74.00   Others  63.16   Others  Commerce     65.00
# 44      45       1  77.00   Others  73.00   Others  Commerce     81.00
# 80      81       1  69.00   Others  62.00   Others  Commerce     69.00
# 85      86       1  83.84   Others  89.83   Others  Commerce     77.20
# 89      90       1  84.00   Others  75.00   Others   Science     69.00
# 96      97       1  76.00  Central  70.00  Central   Science     76.00
# 100    101       1  45.00   Others  57.00   Others  Commerce     58.00
# 102    103       1  77.00   Others  61.00   Others  Commerce     68.00
# ...

# %%
#7. Show female students with degree_t as “Sci&amp;Tech”.
data[(data["gender"]==0) & (data["degree_t"]=="Sci&Tech")]
# Out:
#      sl_no  gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1       0  67.00   Others  91.00   Others  Commerce     58.00
# 1        2       0  79.33  Central  78.33   Others   Science     77.48
# 3        4       0  56.00  Central  52.00  Central   Science     52.00
# 5        6       0  55.00   Others  49.80   Others   Science     67.25
# 7        8       0  82.00  Central  64.00  Central   Science     66.00
# 24      25       0  76.50   Others  97.70   Others   Science     78.86
# 39      40       0  81.00   Others  68.00   Others   Science     64.00
# 53      54       0  80.00   Others  70.00   Others   Science     72.00
# 59      60       0  52.60  Central  65.58   Others   Science     72.11
# 69      70       0  73.00  Central  73.00  Central   Science     66.00
# 70      71       0  82.00   Others  61.00   Others   Science     62.00
# 77      78       0  64.00   Others  80.00   Others   Science     65.00
# ...

# %%
#8. Get students whose etest_p is between 70 and 90.
data[(data["etest_p"]>70) & (data["etest_p"]<90)]
# Out:
#      sl_no  gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 1        2       0  79.33  Central  78.33   Others   Science     77.48
# 2        3       0  65.00  Central  68.00  Central      Arts     64.00
# 6        7       1  46.00   Others  49.20   Others  Commerce     79.00
# 14      15       0  62.00  Central  47.00  Central  Commerce     50.00
# 15      16       1  65.00  Central  75.00  Central  Commerce     69.00
# ..     ...     ...    ...      ...    ...      ...       ...       ...
# 201    202       0  54.20  Central  63.00   Others   Science     58.00
# 204    205       1  74.00   Others  73.00   Others  Commerce     73.00
# 207    208       0  83.33  Central  78.00   Others  Commerce     61.00
# 211    212       0  58.00   Others  60.00   Others   Science     72.00
# 214    215       0  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
#9. Display students who have hsc_b (HSC board) as “Central” and ssc_b as “Central”.
data[(data["hsc_b"]=="Central") & (data["hsc_b"]=="Central")]
# Out:
#      sl_no  gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 2        3       0   65.0  Central   68.0  Central      Arts      64.0
# 3        4       0   56.0  Central   52.0  Central   Science      52.0
# 4        5       0   85.8  Central   73.6  Central  Commerce      73.3
# 7        8       0   82.0  Central   64.0  Central   Science      66.0
# 8        9       0   73.0  Central   79.0  Central  Commerce      72.0
# ..     ...     ...    ...      ...    ...      ...       ...       ...
# 195    196       0   66.0  Central   76.0  Central  Commerce      72.0
# 198    199       1   67.0  Central   70.0  Central  Commerce      65.0
# 202    203       0   70.0  Central   63.0  Central   Science      66.0
# 206    207       0   41.0  Central   42.0  Central   Science      60.0
# 209    210       0   62.0  Central   72.0  Central  Commerce      65.0
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
#10. Show students with mba_p less than 60 or degree_p less than 60.
data[(data["mba_p"]<60) | (data["degree_p"]<60)]
# Out:
#      sl_no  gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1       0   67.0   Others   91.0   Others  Commerce     58.00
# 2        3       0   65.0  Central   68.0  Central      Arts     64.00
# 3        4       0   56.0  Central   52.0  Central   Science     52.00
# 4        5       0   85.8  Central   73.6  Central  Commerce     73.30
# 5        6       0   55.0   Others   49.8   Others   Science     67.25
# ..     ...     ...    ...      ...    ...      ...       ...       ...
# 206    207       0   41.0  Central   42.0  Central   Science     60.00
# 209    210       0   62.0  Central   72.0  Central  Commerce     65.00
# 211    212       0   58.0   Others   60.0   Others   Science     72.00
# 213    214       1   74.0   Others   66.0   Others  Commerce     58.00
# 214    215       0   62.0  Central   58.0   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
#11. Retrieve all students with status equal to “Placed” and salary greater than 400000.
data[(data["status"]=="Placed") | (data["salary"]>400000)]
# Out:
#      sl_no  gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1       0  67.00   Others  91.00   Others  Commerce     58.00
# 1        2       0  79.33  Central  78.33   Others   Science     77.48
# 2        3       0  65.00  Central  68.00  Central      Arts     64.00
# 4        5       0  85.80  Central  73.60  Central  Commerce     73.30
# 7        8       0  82.00  Central  64.00  Central   Science     66.00
# ..     ...     ...    ...      ...    ...      ...       ...       ...
# 209    210       0  62.00  Central  72.00  Central  Commerce     65.00
# 210    211       0  80.60   Others  82.00   Others  Commerce     77.60
# 211    212       0  58.00   Others  60.00   Others   Science     72.00
# 212    213       0  67.00   Others  67.00   Others  Commerce     73.00
# 213    214       1  74.00   Others  66.00   Others  Commerce     58.00
#
#       degree_t workex  etest_p specialisation  mba_p  status    salary
# ...

# %%
#12. Display records where degree_t is “Comm&amp;Mgmt”.
data[data["degree_t"]=="Comm&Mgmt"]
# Out:
#      sl_no  gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 2        3       0   65.0  Central   68.0  Central      Arts      64.0
# 4        5       0   85.8  Central   73.6  Central  Commerce      73.3
# 6        7       1   46.0   Others   49.2   Others  Commerce      79.0
# 8        9       0   73.0  Central   79.0  Central  Commerce      72.0
# 9       10       0   58.0  Central   70.0  Central  Commerce      61.0
# ..     ...     ...    ...      ...    ...      ...       ...       ...
# 209    210       0   62.0  Central   72.0  Central  Commerce      65.0
# 210    211       0   80.6   Others   82.0   Others  Commerce      77.6
# 212    213       0   67.0   Others   67.0   Others  Commerce      73.0
# 213    214       1   74.0   Others   66.0   Others  Commerce      58.0
# 214    215       0   62.0  Central   58.0   Others   Science      53.0
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
#13. Select students whose hsc_p ≥ 85 and workex = “Yes”.
data[(data["hsc_p"]>=85) & (data["workex"]=='Yes')]
# Out:
#      sl_no  gender  ssc_p    ssc_b  hsc_p   hsc_b     hsc_s  degree_p  \
# 85      86       1  83.84   Others  89.83  Others  Commerce     77.20
# 129    130       0  76.70  Central  89.70  Others  Commerce     66.00
# 134    135       1  77.44  Central  92.00  Others  Commerce     72.00
# 162    163       0  74.20  Central  87.60  Others  Commerce     77.25
# 177    178       1  73.00  Central  97.00  Others  Commerce     79.00
#
#       degree_t workex  etest_p specialisation  mba_p  status    salary
# 85   Comm&Mgmt    Yes    78.74        Mkt&Fin  76.18  Placed  400000.0
# 129  Comm&Mgmt    Yes    90.00        Mkt&Fin  68.55  Placed  250000.0
# 134  Comm&Mgmt    Yes    94.00        Mkt&Fin  67.13  Placed  250000.0
# 162  Comm&Mgmt    Yes    75.20        Mkt&Fin  66.06  Placed  285000.0
# 177  Comm&Mgmt    Yes    89.00        Mkt&Fin  70.81  Placed  650000.0

# %%
#14. Show all students whose gender is “F” and ssc_p &lt; 70.
data[(data["gender"]==0) & (data["ssc_p"]<70)]
# Out:
#      sl_no  gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1       0   67.0   Others   91.0   Others  Commerce     58.00
# 2        3       0   65.0  Central   68.0  Central      Arts     64.00
# 3        4       0   56.0  Central   52.0  Central   Science     52.00
# 5        6       0   55.0   Others   49.8   Others   Science     67.25
# 9       10       0   58.0  Central   70.0  Central  Commerce     61.00
# ..     ...     ...    ...      ...    ...      ...       ...       ...
# 206    207       0   41.0  Central   42.0  Central   Science     60.00
# 209    210       0   62.0  Central   72.0  Central  Commerce     65.00
# 211    212       0   58.0   Others   60.0   Others   Science     72.00
# 212    213       0   67.0   Others   67.0   Others  Commerce     73.00
# 214    215       0   62.0  Central   58.0   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
#15. Find students whose salary is missing (NaN).
data[data["salary"]=='NaN']
# Out:
# Empty DataFrame
# Columns: [sl_no, gender, ssc_p, ssc_b, hsc_p, hsc_b, hsc_s, degree_p, degree_t, workex, etest_p, specialisation, mba_p, status, salary]
# Index: []

# %%
#16. Display top 10 rows where etest_p is highest.
data.sort_values(by="etest_p",ascending=False).head(10)
# Out:
#      sl_no  gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 152    153       1  75.40   Others   60.5  Central   Science     84.00
# 24      25       0  76.50   Others   97.7   Others   Science     78.86
# 118    119       0  76.00  Central   80.0  Central   Science     78.00
# 206    207       0  41.00  Central   42.0  Central   Science     60.00
# 4        5       0  85.80  Central   73.6  Central  Commerce     73.30
# 116    117       0  68.20  Central   72.8  Central  Commerce     66.60
# 138    139       1  82.00   Others   64.0   Others   Science     73.00
# 189    190       1  54.00  Central   77.6   Others  Commerce     69.20
# 72      73       0  84.86   Others   67.0   Others   Science     78.00
# 95      96       0  73.00  Central   78.0   Others  Commerce     65.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# 152   Sci&Tech     No    98.00        Mkt&Fin  65.25      Placed  240000.0
# ...

# %%
#17. Show all students who have degree_p between 60 and 80.
data[(data["degree_p"]>60) & (data["degree_p"]<80)]
# Out:
#      sl_no  gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 1        2       0  79.33  Central  78.33   Others   Science     77.48
# 2        3       0  65.00  Central  68.00  Central      Arts     64.00
# 4        5       0  85.80  Central  73.60  Central  Commerce     73.30
# 5        6       0  55.00   Others  49.80   Others   Science     67.25
# 6        7       1  46.00   Others  49.20   Others  Commerce     79.00
# ..     ...     ...    ...      ...    ...      ...       ...       ...
# 208    209       1  43.00  Central  60.00   Others   Science     65.00
# 209    210       0  62.00  Central  72.00  Central  Commerce     65.00
# 210    211       0  80.60   Others  82.00   Others  Commerce     77.60
# 211    212       0  58.00   Others  60.00   Others   Science     72.00
# 212    213       0  67.00   Others  67.00   Others  Commerce     73.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
#18. Select students whose specialisation is “Mkt&amp;Fin”.
data[data["specialisation"]=="Mkt&Fin"]
# Out:
#      sl_no  gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 1        2       0  79.33  Central  78.33   Others   Science     77.48
# 2        3       0  65.00  Central  68.00  Central      Arts     64.00
# 4        5       0  85.80  Central  73.60  Central  Commerce     73.30
# 5        6       0  55.00   Others  49.80   Others   Science     67.25
# 6        7       1  46.00   Others  49.20   Others  Commerce     79.00
# ..     ...     ...    ...      ...    ...      ...       ...       ...
# 207    208       0  83.33  Central  78.00   Others  Commerce     61.00
# 209    210       0  62.00  Central  72.00  Central  Commerce     65.00
# 210    211       0  80.60   Others  82.00   Others  Commerce     77.60
# 211    212       0  58.00   Others  60.00   Others   Science     72.00
# 212    213       0  67.00   Others  67.00   Others  Commerce     73.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
#19. Retrieve all students with workex = “No” and placed = “No”.
data[(data["workex"]=='No') & (data["status"]=="Not Placed")]
# Out:
#      sl_no  gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 3        4       0  56.00  Central  52.00  Central   Science     52.00
# 6        7       1  46.00   Others  49.20   Others  Commerce     79.00
# 9       10       0  58.00  Central  70.00  Central  Commerce     61.00
# 12      13       1  47.00  Central  55.00   Others   Science     65.00
# 14      15       0  62.00  Central  47.00  Central  Commerce     50.00
# 17      18       1  55.00  Central  67.00  Central  Commerce     64.00
# 18      19       1  63.00  Central  66.00  Central  Commerce     64.00
# 29      30       0  62.00  Central  67.00  Central  Commerce     58.00
# 31      32       1  67.00  Central  53.00  Central   Science     65.00
# 34      35       0  62.00   Others  51.00   Others   Science     52.00
# 36      37       0  51.00  Central  44.00  Central  Commerce     57.00
# 42      43       0  49.00   Others  39.00  Central   Science     65.00
# ...

# %%
#20. Show students who studied in “Others” board in ssc_b.
data[data['ssc_b']=="Others"]
# Out:
#      sl_no  gender  ssc_p   ssc_b  hsc_p   hsc_b     hsc_s  degree_p  \
# 0        1       0   67.0  Others   91.0  Others  Commerce     58.00
# 5        6       0   55.0  Others   49.8  Others   Science     67.25
# 6        7       1   46.0  Others   49.2  Others  Commerce     79.00
# 19      20       0   60.0  Others   67.0  Others      Arts     70.00
# 20      21       0   62.0  Others   65.0  Others  Commerce     66.00
# ..     ...     ...    ...     ...    ...     ...       ...       ...
# 205    206       0   61.0  Others   62.0  Others  Commerce     65.00
# 210    211       0   80.6  Others   82.0  Others  Commerce     77.60
# 211    212       0   58.0  Others   60.0  Others   Science     72.00
# 212    213       0   67.0  Others   67.0  Others  Commerce     73.00
# 213    214       1   74.0  Others   66.0  Others  Commerce     58.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
#21. Display students who have exactly 50 in hsc_p.
data[data["hsc_p"]==50]
# Out:
#      sl_no  gender  ssc_p   ssc_b  hsc_p   hsc_b    hsc_s  degree_p  \
# 106    107       0  61.08  Others   50.0  Others  Science      54.0
# 144    145       0  52.00  Others   50.0  Others     Arts      61.0
#
#       degree_t workex  etest_p specialisation  mba_p      status  salary
# 106   Sci&Tech     No     71.0        Mkt&Fin  65.69  Not Placed     NaN
# 144  Comm&Mgmt     No     60.0        Mkt&Fin  58.52  Not Placed     NaN

# %%
#22. Retrieve students whose salary is above average salary.
avg_salary=data["salary"].mean()

# %%
data[data["salary"]>avg_salary]
# Out:
#      sl_no  gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 4        5       0  85.80  Central  73.60  Central  Commerce     73.30
# 16      17       0  63.00  Central  66.20  Central  Commerce     65.60
# 21      22       1  79.00   Others  76.00   Others  Commerce     85.00
# 22      23       1  69.80   Others  60.80   Others   Science     72.23
# 23      24       1  77.40   Others  60.00   Others   Science     64.74
# 24      25       0  76.50   Others  97.70   Others   Science     78.86
# 28      29       0  76.76   Others  76.50   Others  Commerce     67.50
# 35      36       1  69.00  Central  78.00  Central  Commerce     72.00
# 37      38       1  79.00  Central  76.00  Central   Science     65.60
# 39      40       0  81.00   Others  68.00   Others   Science     64.00
# 43      44       0  87.00   Others  87.00   Others  Commerce     68.00
# 53      54       0  80.00   Others  70.00   Others   Science     72.00
# ...

# %%
#23. Show records where both hsc_p and ssc_p are above 80.
data[(data["hsc_p"]>80) & (data["ssc_p"]>80)]
# Out:
#      sl_no  gender  ssc_p   ssc_b  hsc_p   hsc_b     hsc_s  degree_p  \
# 43      44       0  87.00  Others  87.00  Others  Commerce      68.0
# 78      79       0  84.00  Others  90.90  Others   Science      64.5
# 85      86       1  83.84  Others  89.83  Others  Commerce      77.2
# 90      91       1  85.00  Others  90.00  Others  Commerce      82.0
# 107    108       0  82.00  Others  90.00  Others  Commerce      83.0
# 210    211       0  80.60  Others  82.00  Others  Commerce      77.6
#
#       degree_t workex  etest_p specialisation  mba_p  status    salary
# 43   Comm&Mgmt     No    95.00         Mkt&HR  62.90  Placed  300000.0
# 78    Sci&Tech     No    86.04        Mkt&Fin  59.42  Placed  270000.0
# 85   Comm&Mgmt    Yes    78.74        Mkt&Fin  76.18  Placed  400000.0
# 90   Comm&Mgmt     No    92.00        Mkt&Fin  68.03  Placed  300000.0
# 107  Comm&Mgmt     No    80.00         Mkt&HR  73.52  Placed  200000.0
# ...

# %%
#24. Find students with etest_p exactly equal to 100.
data[data["etest_p"]==100]
# Out:
# Empty DataFrame
# Columns: [sl_no, gender, ssc_p, ssc_b, hsc_p, hsc_b, hsc_s, degree_p, degree_t, workex, etest_p, specialisation, mba_p, status, salary]
# Index: []

# %%
#25. Display students with either hsc_b = “Central” or ssc_b = “Others”.
data[(data["hsc_b"]=="Central") | (data["ssc_b"]=="Others")]
# Out:
#      sl_no  gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1       0   67.0   Others   91.0   Others  Commerce     58.00
# 2        3       0   65.0  Central   68.0  Central      Arts     64.00
# 3        4       0   56.0  Central   52.0  Central   Science     52.00
# 4        5       0   85.8  Central   73.6  Central  Commerce     73.30
# 5        6       0   55.0   Others   49.8   Others   Science     67.25
# ..     ...     ...    ...      ...    ...      ...       ...       ...
# 209    210       0   62.0  Central   72.0  Central  Commerce     65.00
# 210    211       0   80.6   Others   82.0   Others  Commerce     77.60
# 211    212       0   58.0   Others   60.0   Others   Science     72.00
# 212    213       0   67.0   Others   67.0   Others  Commerce     73.00
# 213    214       1   74.0   Others   66.0   Others  Commerce     58.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
#26. Add a new column overall_avg = (ssc_p + hsc_p + degree_p + mba_p) / 4.
data["overall_avg"]=(data["ssc_p"]+data["hsc_p"]+data["degree_p"]+data["mba_p"])/4

# %%
data
# Out:
#      sl_no  gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1       0  67.00   Others  91.00   Others  Commerce     58.00
# 1        2       0  79.33  Central  78.33   Others   Science     77.48
# 2        3       0  65.00  Central  68.00  Central      Arts     64.00
# 3        4       0  56.00  Central  52.00  Central   Science     52.00
# 4        5       0  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...     ...    ...      ...    ...      ...       ...       ...
# 210    211       0  80.60   Others  82.00   Others  Commerce     77.60
# 211    212       0  58.00   Others  60.00   Others   Science     72.00
# 212    213       0  67.00   Others  67.00   Others  Commerce     73.00
# 213    214       1  74.00   Others  66.00   Others  Commerce     58.00
# 214    215       0  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary  \
# ...

# %%
#27. Rename the column degree_p to degree_percentage.
data.rename(columns={"degree_p":"degree_percentage"})
# Out:
#      sl_no  gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  \
# 0        1       0  67.00   Others  91.00   Others  Commerce
# 1        2       0  79.33  Central  78.33   Others   Science
# 2        3       0  65.00  Central  68.00  Central      Arts
# 3        4       0  56.00  Central  52.00  Central   Science
# 4        5       0  85.80  Central  73.60  Central  Commerce
# ..     ...     ...    ...      ...    ...      ...       ...
# 210    211       0  80.60   Others  82.00   Others  Commerce
# 211    212       0  58.00   Others  60.00   Others   Science
# 212    213       0  67.00   Others  67.00   Others  Commerce
# 213    214       1  74.00   Others  66.00   Others  Commerce
# 214    215       0  62.00  Central  58.00   Others   Science
#
#      degree_percentage   degree_t workex  etest_p specialisation  mba_p  \
# 0                58.00   Sci&Tech     No     55.0         Mkt&HR  58.80
# 1                77.48   Sci&Tech    Yes     86.5        Mkt&Fin  66.28
# ...

# %%
data["degree_percentage"]=data["degree_p"]

# %%
data
# Out:
#      sl_no  gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1       0  67.00   Others  91.00   Others  Commerce     58.00
# 1        2       0  79.33  Central  78.33   Others   Science     77.48
# 2        3       0  65.00  Central  68.00  Central      Arts     64.00
# 3        4       0  56.00  Central  52.00  Central   Science     52.00
# 4        5       0  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...     ...    ...      ...    ...      ...       ...       ...
# 210    211       0  80.60   Others  82.00   Others  Commerce     77.60
# 211    212       0  58.00   Others  60.00   Others   Science     72.00
# 212    213       0  67.00   Others  67.00   Others  Commerce     73.00
# 213    214       1  74.00   Others  66.00   Others  Commerce     58.00
# 214    215       0  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary  \
# ...

# %%
#28. Create a new column placement_status = “Hired” if status = “Placed” else “Not Hired”.
data["placement_status"]=data["status"].apply(lambda x:"Hired" if x=="Placed" else "Not Hired")

# %%
data
# Out:
#      sl_no  gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1       0  67.00   Others  91.00   Others  Commerce     58.00
# 1        2       0  79.33  Central  78.33   Others   Science     77.48
# 2        3       0  65.00  Central  68.00  Central      Arts     64.00
# 3        4       0  56.00  Central  52.00  Central   Science     52.00
# 4        5       0  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...     ...    ...      ...    ...      ...       ...       ...
# 210    211       0  80.60   Others  82.00   Others  Commerce     77.60
# 211    212       0  58.00   Others  60.00   Others   Science     72.00
# 212    213       0  67.00   Others  67.00   Others  Commerce     73.00
# 213    214       1  74.00   Others  66.00   Others  Commerce     58.00
# 214    215       0  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary  \
# ...

# %%
#29. Drop the column sl_no.
data.drop("sl_no",axis=1)
# Out:
#      gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p   degree_t  \
# 0         0  67.00   Others  91.00   Others  Commerce     58.00   Sci&Tech
# 1         0  79.33  Central  78.33   Others   Science     77.48   Sci&Tech
# 2         0  65.00  Central  68.00  Central      Arts     64.00  Comm&Mgmt
# 3         0  56.00  Central  52.00  Central   Science     52.00   Sci&Tech
# 4         0  85.80  Central  73.60  Central  Commerce     73.30  Comm&Mgmt
# ..      ...    ...      ...    ...      ...       ...       ...        ...
# 210       0  80.60   Others  82.00   Others  Commerce     77.60  Comm&Mgmt
# 211       0  58.00   Others  60.00   Others   Science     72.00   Sci&Tech
# 212       0  67.00   Others  67.00   Others  Commerce     73.00  Comm&Mgmt
# 213       1  74.00   Others  66.00   Others  Commerce     58.00  Comm&Mgmt
# 214       0  62.00  Central  58.00   Others   Science     53.00  Comm&Mgmt
#
# ...

# %%
#30. Replace all “Comm&amp;Mgmt” in degree_t with “Commerce”.
data["degree_t"]=data["degree_t"].replace("Comm&Mgmt","Commerce")

# %%
data
# Out:
#      sl_no  gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1       0  67.00   Others  91.00   Others  Commerce     58.00
# 1        2       0  79.33  Central  78.33   Others   Science     77.48
# 2        3       0  65.00  Central  68.00  Central      Arts     64.00
# 3        4       0  56.00  Central  52.00  Central   Science     52.00
# 4        5       0  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...     ...    ...      ...    ...      ...       ...       ...
# 210    211       0  80.60   Others  82.00   Others  Commerce     77.60
# 211    212       0  58.00   Others  60.00   Others   Science     72.00
# 212    213       0  67.00   Others  67.00   Others  Commerce     73.00
# 213    214       1  74.00   Others  66.00   Others  Commerce     58.00
# 214    215       0  62.00  Central  58.00   Others   Science     53.00
#
#      degree_t workex  etest_p specialisation  mba_p      status    salary  \
# ...

# %%
#31. Convert gender column values “M” → “Male”, “F” → “Female”.
data["gender"]=data['gender'].replace((0,1),("F","M"))

# %%
data
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      F  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      F  79.33  Central  78.33   Others   Science     77.48
# 2        3      F  65.00  Central  68.00  Central      Arts     64.00
# 3        4      F  56.00  Central  52.00  Central   Science     52.00
# 4        5      F  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      F  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      F  58.00   Others  60.00   Others   Science     72.00
# 212    213      F  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      M  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      F  62.00  Central  58.00   Others   Science     53.00
#
#      degree_t workex  etest_p specialisation  mba_p      status    salary  \
# ...

# %%
#32. Create a new column above_80_ssc = True if ssc_p &gt; 80 else False.
data["above_80_ssc"]=data["ssc_p"].apply(lambda x:True if x>80 else False)

# %%
data
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      F  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      F  79.33  Central  78.33   Others   Science     77.48
# 2        3      F  65.00  Central  68.00  Central      Arts     64.00
# 3        4      F  56.00  Central  52.00  Central   Science     52.00
# 4        5      F  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      F  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      F  58.00   Others  60.00   Others   Science     72.00
# 212    213      F  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      M  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      F  62.00  Central  58.00   Others   Science     53.00
#
#      degree_t workex  etest_p specialisation  mba_p      status    salary  \
# ...

# %%
#33. Round all percentage columns to 1 decimal place.
data.round(1)
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      F   67.0   Others   91.0   Others  Commerce      58.0
# 1        2      F   79.3  Central   78.3   Others   Science      77.5
# 2        3      F   65.0  Central   68.0  Central      Arts      64.0
# 3        4      F   56.0  Central   52.0  Central   Science      52.0
# 4        5      F   85.8  Central   73.6  Central  Commerce      73.3
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      F   80.6   Others   82.0   Others  Commerce      77.6
# 211    212      F   58.0   Others   60.0   Others   Science      72.0
# 212    213      F   67.0   Others   67.0   Others  Commerce      73.0
# 213    214      M   74.0   Others   66.0   Others  Commerce      58.0
# 214    215      F   62.0  Central   58.0   Others   Science      53.0
#
#      degree_t workex  etest_p specialisation  mba_p      status    salary  \
# ...

# %%
#34. Convert all column names to lowercase.
data.columns.str.lower()
# Out:
# Index(['sl_no', 'gender', 'ssc_p', 'ssc_b', 'hsc_p', 'hsc_b', 'hsc_s',
#        'degree_p', 'degree_t', 'workex', 'etest_p', 'specialisation', 'mba_p',
#        'status', 'salary', 'overall_avg', 'degree_percentage',
#        'placement_status', 'above_80_ssc'],
#       dtype='object')

# %%
data
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      F  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      F  79.33  Central  78.33   Others   Science     77.48
# 2        3      F  65.00  Central  68.00  Central      Arts     64.00
# 3        4      F  56.00  Central  52.00  Central   Science     52.00
# 4        5      F  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      F  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      F  58.00   Others  60.00   Others   Science     72.00
# 212    213      F  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      M  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      F  62.00  Central  58.00   Others   Science     53.00
#
#      degree_t workex  etest_p specialisation  mba_p      status    salary  \
# ...

# %%
#35. Add a new column salary_in_lpa = salary / 100000.
data["salary_in_lpa"]=data["salary"]/100000

# %%
data
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      F  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      F  79.33  Central  78.33   Others   Science     77.48
# 2        3      F  65.00  Central  68.00  Central      Arts     64.00
# 3        4      F  56.00  Central  52.00  Central   Science     52.00
# 4        5      F  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      F  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      F  58.00   Others  60.00   Others   Science     72.00
# 212    213      F  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      M  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      F  62.00  Central  58.00   Others   Science     53.00
#
#      degree_t workex  etest_p specialisation  mba_p      status    salary  \
# ...

# %%
#36. Replace NaN values in salary with 0.
data["salary"].replace("NaN",0.0)
# Out:
# 0      270000.0
# 1      200000.0
# 2      250000.0
# 3           NaN
# 4      425000.0
#          ...
# 210    400000.0
# 211    275000.0
# 212    295000.0
# 213    204000.0
# 214         NaN
# Name: salary, Length: 215, dtype: float64

# %%
data
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      F  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      F  79.33  Central  78.33   Others   Science     77.48
# 2        3      F  65.00  Central  68.00  Central      Arts     64.00
# 3        4      F  56.00  Central  52.00  Central   Science     52.00
# 4        5      F  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      F  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      F  58.00   Others  60.00   Others   Science     72.00
# 212    213      F  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      M  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      F  62.00  Central  58.00   Others   Science     53.00
#
#      degree_t workex  etest_p specialisation  mba_p      status    salary  \
# ...

# %%
data['salary'] = data['salary'].fillna(0)

# %%
data
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      F  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      F  79.33  Central  78.33   Others   Science     77.48
# 2        3      F  65.00  Central  68.00  Central      Arts     64.00
# 3        4      F  56.00  Central  52.00  Central   Science     52.00
# 4        5      F  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      F  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      F  58.00   Others  60.00   Others   Science     72.00
# 212    213      F  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      M  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      F  62.00  Central  58.00   Others   Science     53.00
#
#      degree_t workex  etest_p specialisation  mba_p      status    salary  \
# ...

# %%
#37. Drop all duplicate rows from the dataset.
data.drop_duplicates()
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      F  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      F  79.33  Central  78.33   Others   Science     77.48
# 2        3      F  65.00  Central  68.00  Central      Arts     64.00
# 3        4      F  56.00  Central  52.00  Central   Science     52.00
# 4        5      F  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      F  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      F  58.00   Others  60.00   Others   Science     72.00
# 212    213      F  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      M  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      F  62.00  Central  58.00   Others   Science     53.00
#
#      degree_t workex  etest_p specialisation  mba_p      status    salary  \
# ...

# %%
#38. Increase all mba_p scores by 5 points.
data["mba_p"]=data["mba_p"]+5

# %%
data
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      F  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      F  79.33  Central  78.33   Others   Science     77.48
# 2        3      F  65.00  Central  68.00  Central      Arts     64.00
# 3        4      F  56.00  Central  52.00  Central   Science     52.00
# 4        5      F  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      F  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      F  58.00   Others  60.00   Others   Science     72.00
# 212    213      F  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      M  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      F  62.00  Central  58.00   Others   Science     53.00
#
#      degree_t workex  etest_p specialisation  mba_p      status    salary  \
# ...

# %%
#39. Convert salary column to integer type.
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 215 entries, 0 to 214
# Data columns (total 20 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sl_no              215 non-null    int64
#  1   gender             215 non-null    object
#  2   ssc_p              215 non-null    float64
#  3   ssc_b              215 non-null    object
#  4   hsc_p              215 non-null    float64
#  5   hsc_b              215 non-null    object
#  6   hsc_s              215 non-null    object
#  7   degree_p           215 non-null    float64
#  8   degree_t           215 non-null    object
#  9   workex             215 non-null    object
#  10  etest_p            215 non-null    float64
#  11  specialisation     215 non-null    object
#  12  mba_p              215 non-null    float64
#  13  status             215 non-null    object
#  14  salary             215 non-null    float64
#  15  overall_avg        215 non-null    float64
# ...

# %%
data["salary"].astype("int")
# Out:
# 0      270000
# 1      200000
# 2      250000
# 3           0
# 4      425000
#         ...
# 210    400000
# 211    275000
# 212    295000
# 213    204000
# 214         0
# Name: salary, Length: 215, dtype: int64

# %%
#40. Reorder columns to make status the first column.
status_data=data.pop("status")
data.insert(0,"status",status_data)

# %%
data
# Out:
#          status  sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  \
# 0        Placed      1      F  67.00   Others  91.00   Others  Commerce
# 1        Placed      2      F  79.33  Central  78.33   Others   Science
# 2        Placed      3      F  65.00  Central  68.00  Central      Arts
# 3    Not Placed      4      F  56.00  Central  52.00  Central   Science
# 4        Placed      5      F  85.80  Central  73.60  Central  Commerce
# ..          ...    ...    ...    ...      ...    ...      ...       ...
# 210      Placed    211      F  80.60   Others  82.00   Others  Commerce
# 211      Placed    212      F  58.00   Others  60.00   Others   Science
# 212      Placed    213      F  67.00   Others  67.00   Others  Commerce
# 213      Placed    214      M  74.00   Others  66.00   Others  Commerce
# 214  Not Placed    215      F  62.00  Central  58.00   Others   Science
#
#      degree_p  degree_t workex  etest_p specialisation  mba_p    salary  \
# ...

# %%
#41. Replace all “Yes”/“No” in workex with 1/0.
data["workex"]=data["workex"].replace(("Yes","No"),(1,0))
# Out:
# C:\Users\rames\AppData\Local\Temp\ipykernel_30088\3262946218.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data["workex"]=data["workex"].replace(("Yes","No"),(1,0))

# %%
data
# Out:
#          status  sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  \
# 0        Placed      1      F  67.00   Others  91.00   Others  Commerce
# 1        Placed      2      F  79.33  Central  78.33   Others   Science
# 2        Placed      3      F  65.00  Central  68.00  Central      Arts
# 3    Not Placed      4      F  56.00  Central  52.00  Central   Science
# 4        Placed      5      F  85.80  Central  73.60  Central  Commerce
# ..          ...    ...    ...    ...      ...    ...      ...       ...
# 210      Placed    211      F  80.60   Others  82.00   Others  Commerce
# 211      Placed    212      F  58.00   Others  60.00   Others   Science
# 212      Placed    213      F  67.00   Others  67.00   Others  Commerce
# 213      Placed    214      M  74.00   Others  66.00   Others  Commerce
# 214  Not Placed    215      F  62.00  Central  58.00   Others   Science
#
#      degree_p  degree_t  workex  etest_p specialisation  mba_p    salary  \
# ...

# %%
#42. Create a new column performance_tag: “Excellent” if degree_p &gt; 80 else “Average”.
data["performance_tag"]=data["degree_p"].apply(lambda x:"Excellent" if x>80 else "Average")

# %%
data
# Out:
#          status  sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  \
# 0        Placed      1      F  67.00   Others  91.00   Others  Commerce
# 1        Placed      2      F  79.33  Central  78.33   Others   Science
# 2        Placed      3      F  65.00  Central  68.00  Central      Arts
# 3    Not Placed      4      F  56.00  Central  52.00  Central   Science
# 4        Placed      5      F  85.80  Central  73.60  Central  Commerce
# ..          ...    ...    ...    ...      ...    ...      ...       ...
# 210      Placed    211      F  80.60   Others  82.00   Others  Commerce
# 211      Placed    212      F  58.00   Others  60.00   Others   Science
# 212      Placed    213      F  67.00   Others  67.00   Others  Commerce
# 213      Placed    214      M  74.00   Others  66.00   Others  Commerce
# 214  Not Placed    215      F  62.00  Central  58.00   Others   Science
#
#      degree_p  degree_t  ...  etest_p  specialisation  mba_p    salary  \
# ...

# %%
#43. Standardize all column names to snake_case (e.g., ssc_p → ssc_percentage).
#data.rename(columns={"degree_t":"degree_type","ssc_p":"ssc_percentage"})

# %%
#44. Create a new column combining degree_t and specialisation (e.g., “Sci&amp;Tech_Mkt&amp;HR”).
data["degree_and_specialization"]=data["degree_t"]+"_"+data["specialisation"]

# %%
data
# Out:
#          status  sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  \
# 0        Placed      1      F  67.00   Others  91.00   Others  Commerce
# 1        Placed      2      F  79.33  Central  78.33   Others   Science
# 2        Placed      3      F  65.00  Central  68.00  Central      Arts
# 3    Not Placed      4      F  56.00  Central  52.00  Central   Science
# 4        Placed      5      F  85.80  Central  73.60  Central  Commerce
# ..          ...    ...    ...    ...      ...    ...      ...       ...
# 210      Placed    211      F  80.60   Others  82.00   Others  Commerce
# 211      Placed    212      F  58.00   Others  60.00   Others   Science
# 212      Placed    213      F  67.00   Others  67.00   Others  Commerce
# 213      Placed    214      M  74.00   Others  66.00   Others  Commerce
# 214  Not Placed    215      F  62.00  Central  58.00   Others   Science
#
#      degree_p  degree_t  ...  specialisation  mba_p    salary  overall_avg  \
# ...

# %%
#45. Fill missing etest_p values with mean of that column.
data["etest_p"].unique()
# Out:
# array([55.  , 86.5 , 75.  , 66.  , 96.8 , 74.28, 67.  , 91.34, 54.  ,
#        62.  , 60.  , 68.  , 76.  , 72.  , 50.48, 50.  , 95.  , 55.53,
#        92.  , 97.4 , 94.  , 73.35, 77.  , 52.  , 64.  , 50.89, 88.  ,
#        68.44, 71.  , 58.  , 53.7 , 93.  , 65.  , 63.  , 89.  , 78.  ,
#        71.2 , 87.  , 80.  , 74.  , 57.6 , 61.6 , 59.  , 68.5 , 61.  ,
#        89.69, 68.92, 68.71, 79.  , 70.  , 95.5 , 86.  , 84.27, 69.  ,
#        86.04, 82.  , 84.  , 78.74, 53.88, 95.46, 93.91, 56.39, 57.5 ,
#        85.  , 57.2 , 72.15, 96.  , 97.  , 82.66, 73.  , 55.67, 80.4 ,
#        55.5 , 81.2 , 90.  , 74.4 , 55.6 , 56.  , 83.  , 57.  , 64.25,
#        98.  , 56.15, 93.4 , 57.63, 75.2 , 53.04, 58.1 , 54.48, 58.06,
#        63.79, 87.5 , 75.5 , 95.65, 59.32, 87.55, 61.28, 88.56, 92.66,
#        91.  ])

# %%
data["etest_p"].mean()
# Out:
# np.float64(72.10055813953488)

# %%
#46. Create a new column total_score = ssc_p + hsc_p + degree_p + mba_p.
data["total_score"]=data["ssc_p"]+data["hsc_p"]+data["degree_p"]+data["mba_p"]

# %%
data
# Out:
#          status  sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  \
# 0        Placed      1      F  67.00   Others  91.00   Others  Commerce
# 1        Placed      2      F  79.33  Central  78.33   Others   Science
# 2        Placed      3      F  65.00  Central  68.00  Central      Arts
# 3    Not Placed      4      F  56.00  Central  52.00  Central   Science
# 4        Placed      5      F  85.80  Central  73.60  Central  Commerce
# ..          ...    ...    ...    ...      ...    ...      ...       ...
# 210      Placed    211      F  80.60   Others  82.00   Others  Commerce
# 211      Placed    212      F  58.00   Others  60.00   Others   Science
# 212      Placed    213      F  67.00   Others  67.00   Others  Commerce
# 213      Placed    214      M  74.00   Others  66.00   Others  Commerce
# 214  Not Placed    215      F  62.00  Central  58.00   Others   Science
#
#      degree_p  degree_t  ...  mba_p    salary overall_avg  degree_percentage  \
# ...

# %%
#47. Drop students whose hsc_p &lt; 40.
data.drop(data[data["hsc_p"]<40].index,inplace=True)

# %%
data
# Out:
#          status  sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  \
# 0        Placed      1      F  67.00   Others  91.00   Others  Commerce
# 1        Placed      2      F  79.33  Central  78.33   Others   Science
# 2        Placed      3      F  65.00  Central  68.00  Central      Arts
# 3    Not Placed      4      F  56.00  Central  52.00  Central   Science
# 4        Placed      5      F  85.80  Central  73.60  Central  Commerce
# ..          ...    ...    ...    ...      ...    ...      ...       ...
# 210      Placed    211      F  80.60   Others  82.00   Others  Commerce
# 211      Placed    212      F  58.00   Others  60.00   Others   Science
# 212      Placed    213      F  67.00   Others  67.00   Others  Commerce
# 213      Placed    214      M  74.00   Others  66.00   Others  Commerce
# 214  Not Placed    215      F  62.00  Central  58.00   Others   Science
#
#      degree_p  degree_t  ...  mba_p    salary overall_avg  degree_percentage  \
# ...

# %%
#48. Create a boolean column is_placed = True if status = “Placed”.
data["is_placed"]=data["status"].apply(lambda x:True if x=="Placed" else False)

# %%
data
# Out:
#          status  sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  \
# 0        Placed      1      F  67.00   Others  91.00   Others  Commerce
# 1        Placed      2      F  79.33  Central  78.33   Others   Science
# 2        Placed      3      F  65.00  Central  68.00  Central      Arts
# 3    Not Placed      4      F  56.00  Central  52.00  Central   Science
# 4        Placed      5      F  85.80  Central  73.60  Central  Commerce
# ..          ...    ...    ...    ...      ...    ...      ...       ...
# 210      Placed    211      F  80.60   Others  82.00   Others  Commerce
# 211      Placed    212      F  58.00   Others  60.00   Others   Science
# 212      Placed    213      F  67.00   Others  67.00   Others  Commerce
# 213      Placed    214      M  74.00   Others  66.00   Others  Commerce
# 214  Not Placed    215      F  62.00  Central  58.00   Others   Science
#
#      degree_p  degree_t  ...    salary  overall_avg degree_percentage  \
# ...

# %%
#49. Add a column mba_grade = “A” if mba_p ≥ 75 else “B”.
data["mba_grade"]=data["mba_p"].apply(lambda x:"A" if x>=75 else "B")

# %%
data
# Out:
#          status  sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  \
# 0        Placed      1      F  67.00   Others  91.00   Others  Commerce
# 1        Placed      2      F  79.33  Central  78.33   Others   Science
# 2        Placed      3      F  65.00  Central  68.00  Central      Arts
# 3    Not Placed      4      F  56.00  Central  52.00  Central   Science
# 4        Placed      5      F  85.80  Central  73.60  Central  Commerce
# ..          ...    ...    ...    ...      ...    ...      ...       ...
# 210      Placed    211      F  80.60   Others  82.00   Others  Commerce
# 211      Placed    212      F  58.00   Others  60.00   Others   Science
# 212      Placed    213      F  67.00   Others  67.00   Others  Commerce
# 213      Placed    214      M  74.00   Others  66.00   Others  Commerce
# 214  Not Placed    215      F  62.00  Central  58.00   Others   Science
#
#      degree_p  degree_t  ...  overall_avg  degree_percentage placement_status  \
# ...

# %%
#50. Replace NaN salaries for non-placed students with 0.
data["status"].value_counts()
# Out:
# status
# Placed        148
# Not Placed     65
# Name: count, dtype: int64

# %%
#51. Count how many students are in each gender.
data["gender"].value_counts()
# Out:
# gender
# F    138
# M     75
# Name: count, dtype: int64

# %%
#52. Find the average mba_p for each specialisation.
data.groupby("specialisation")["mba_p"].mean()
# Out:
# specialisation
# Mkt&Fin    67.923277
# Mkt&HR     66.644894
# Name: mba_p, dtype: float64

# %%
data["specialisation"].unique()
# Out:
# array(['Mkt&HR', 'Mkt&Fin'], dtype=object)

# %%
#53. Get the mean degree_p for placed vs non-placed students.
data.groupby("status")["degree_p"].mean()
# Out:
# status
# Not Placed    61.215231
# Placed        68.740541
# Name: degree_p, dtype: float64

# %%
#54. Find the maximum salary for each specialisation.
data.groupby("specialisation")["salary"].max()
# Out:
# specialisation
# Mkt&Fin    940000.0
# Mkt&HR     450000.0
# Name: salary, dtype: float64

# %%
#55. Count the number of students with and without workex.
data.groupby("workex")["sl_no"].count()
# Out:
# workex
# 0    139
# 1     74
# Name: sl_no, dtype: int64

# %%
#56. Calculate the average etest_p for each degree_t.
data.groupby("degree_t")["etest_p"].mean()
# Out:
# degree_t
# Commerce    71.985241
# Others      74.382222
# Sci&Tech    72.310508
# Name: etest_p, dtype: float64

# %%
#57. Find the total number of placed students per degree_t.
data1=data[data["status"]=="Placed"]

# %%
data1.groupby("degree_t")["status"].count()
# Out:
# degree_t
# Commerce    102
# Others        5
# Sci&Tech     41
# Name: status, dtype: int64

# %%
#58. Get the minimum hsc_p for each hsc_b.
data.groupby("hsc_b")["hsc_p"].min()
# Out:
# hsc_b
# Central    42.0
# Others     40.0
# Name: hsc_p, dtype: float64

# %%
#59. Count of students in each specialisation grouped by gender.
data.groupby(["gender","specialisation"])["sl_no"].count()
# Out:
# gender  specialisation
# F       Mkt&Fin           82
#         Mkt&HR            56
# M       Mkt&Fin           37
#         Mkt&HR            38
# Name: sl_no, dtype: int64

# %%
#60. Find the highest mba_p among placed students.
data[data["status"]=="Placed"]["mba_p"].max()
# Out:
# 82.89

# %%
#61. Calculate mean, min, and max ssc_p for each gender.
g_gender=data.groupby("gender")

# %%
g_gender["ssc_p"].mean()
# Out:
# gender
# F    66.881159
# M    68.555067
# Name: ssc_p, dtype: float64

# %%
g_gender["ssc_p"].min()
# Out:
# gender
# F    41.00
# M    40.89
# Name: ssc_p, dtype: float64

# %%
g_gender["ssc_p"].max()
# Out:
# gender
# F    89.4
# M    88.0
# Name: ssc_p, dtype: float64

# %%
#62. Count how many students have each unique combination of degree_t and workex.
data.groupby(["degree_t","workex"])["sl_no"].count()
# Out:
# degree_t  workex
# Commerce  0         100
#           1          45
# Others    0           5
#           1           4
# Sci&Tech  0          34
#           1          25
# Name: sl_no, dtype: int64

# %%
#63. Find the number of placed students per hsc_b.
placed=data[data["status"]=="Placed"]

# %%
placed.groupby("hsc_b")["sl_no"].count()
# Out:
# hsc_b
# Central    57
# Others     91
# Name: sl_no, dtype: int64

# %%
#64. Get average salary for each specialisation grouped by workex.
data.groupby(["workex","specialisation"])['salary'].mean()
# Out:
# workex  specialisation
# 0       Mkt&Fin           200411.764706
#         Mkt&HR            136394.366197
# 1       Mkt&Fin           289470.588235
#         Mkt&HR            202000.000000
# Name: salary, dtype: float64

# %%
#65. Calculate the average of all numeric columns for each degree_t.
g_degree=data.groupby("degree_t").mean(numeric_only=True)

# %%
g_degree
# Out:
#                sl_no      ssc_p      hsc_p   degree_p    workex    etest_p  \
# degree_t
# Commerce  106.275862  65.955586  67.185379  66.203103  0.310345  71.985241
# Others    143.444444  67.500000  65.111111  61.147778  0.444444  74.382222
# Sci&Tech  108.915254  71.189322  65.385593  67.844237  0.423729  72.310508
#
#               mba_p         salary  overall_avg  degree_percentage  \
# degree_t
# Commerce  66.865379  196000.000000    65.302362          66.203103
# Others    68.088889  155777.777778    64.211944          61.147778
# Sci&Tech  68.461186  218627.118644    66.970085          67.844237
#
#           above_80_ssc  salary_in_lpa  total_score  is_placed
# degree_t
# Commerce      0.096552       2.786275   266.209448   0.703448
# Others        0.111111       2.804000   261.847778   0.555556
# Sci&Tech      0.237288       3.146098   272.880339   0.694915

# %%
#66. Find the number of students with etest_p &gt; 80 grouped by workex.
etest=data[data["etest_p"]>80]

# %%
etest.groupby("workex")["sl_no"].count()
# Out:
# workex
# 0    37
# 1    24
# Name: sl_no, dtype: int64

# %%
#67. Display count of placed and not placed students per degree_t.
data.groupby(["degree_t","status"])["sl_no"].count()
# Out:
# degree_t  status
# Commerce  Not Placed     43
#           Placed        102
# Others    Not Placed      4
#           Placed          5
# Sci&Tech  Not Placed     18
#           Placed         41
# Name: sl_no, dtype: int64

# %%
#68. Show mean mba_p for each specialisation and gender.
data.groupby(["specialisation","gender"])["mba_p"].mean()
# Out:
# specialisation  gender
# Mkt&Fin         F         66.578293
#                 M         70.904054
# Mkt&HR          F         65.290536
#                 M         68.640789
# Name: mba_p, dtype: float64

# %%
#69. Find how many students from each hsc_b got placed.
placed
# Out:
#      status  sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0    Placed      1      F  67.00   Others  91.00   Others  Commerce     58.00
# 1    Placed      2      F  79.33  Central  78.33   Others   Science     77.48
# 2    Placed      3      F  65.00  Central  68.00  Central      Arts     64.00
# 4    Placed      5      F  85.80  Central  73.60  Central  Commerce     73.30
# 7    Placed      8      F  82.00  Central  64.00  Central   Science     66.00
# ..      ...    ...    ...    ...      ...    ...      ...       ...       ...
# 209  Placed    210      F  62.00  Central  72.00  Central  Commerce     65.00
# 210  Placed    211      F  80.60   Others  82.00   Others  Commerce     77.60
# 211  Placed    212      F  58.00   Others  60.00   Others   Science     72.00
# 212  Placed    213      F  67.00   Others  67.00   Others  Commerce     73.00
# 213  Placed    214      M  74.00   Others  66.00   Others  Commerce     58.00
#
# ...

# %%
placed.groupby('hsc_b')["sl_no"].count()
# Out:
# hsc_b
# Central    57
# Others     91
# Name: sl_no, dtype: int64

# %%
#70. Get both min and max salary for each specialisation.
g_sp=data.groupby("specialisation")

# %%
g_sp["salary"].min()
# Out:
# specialisation
# Mkt&Fin    0.0
# Mkt&HR     0.0
# Name: salary, dtype: float64

# %%
g_sp["salary"].max()
# Out:
# specialisation
# Mkt&Fin    940000.0
# Mkt&HR     450000.0
# Name: salary, dtype: float64

# %%
#71. Display number of unique degree_t values for each workex group.
data.groupby(["workex","degree_t"])["sl_no"].count()
# Out:
# workex  degree_t
# 0       Commerce    100
#         Others        5
#         Sci&Tech     34
# 1       Commerce     45
#         Others        4
#         Sci&Tech     25
# Name: sl_no, dtype: int64

# %%
data.groupby(["workex"])["degree_t"].unique()
# Out:
# workex
# 0    [Sci&Tech, Commerce, Others]
# 1    [Sci&Tech, Commerce, Others]
# Name: degree_t, dtype: object

# %%
#72. Find average degree_p per hsc_b and ssc_b.
data.groupby(["hsc_b","ssc_b"])["degree_p"].mean()
# Out:
# hsc_b    ssc_b
# Central  Central    65.547922
#          Others     68.521667
# Others   Central    67.225641
#          Others     66.730440
# Name: degree_p, dtype: float64

# %%
#73. Calculate total number of students grouped by specialisation and status.
data.groupby(["specialisation","status"])["sl_no"].count()
# Out:
# specialisation  status
# Mkt&Fin         Not Placed    24
#                 Placed        95
# Mkt&HR          Not Placed    41
#                 Placed        53
# Name: sl_no, dtype: int64

# %%
#74. Find which degree_t has the highest average placement rate.
aa=data.groupby(["degree_t","status"])["is_placed"].count().reset_index()

# %%
data.groupby('degree_t').mean(numeric_only=True)
# Out:
#                sl_no      ssc_p      hsc_p   degree_p    workex    etest_p  \
# degree_t
# Commerce  106.275862  65.955586  67.185379  66.203103  0.310345  71.985241
# Others    143.444444  67.500000  65.111111  61.147778  0.444444  74.382222
# Sci&Tech  108.915254  71.189322  65.385593  67.844237  0.423729  72.310508
#
#               mba_p         salary  overall_avg  degree_percentage  \
# degree_t
# Commerce  66.865379  196000.000000    65.302362          66.203103
# Others    68.088889  155777.777778    64.211944          61.147778
# Sci&Tech  68.461186  218627.118644    66.970085          67.844237
#
#           above_80_ssc  salary_in_lpa  total_score  is_placed
# degree_t
# Commerce      0.096552       2.786275   266.209448   0.703448
# Others        0.111111       2.804000   261.847778   0.555556
# Sci&Tech      0.237288       3.146098   272.880339   0.694915

# %%
aa
# Out:
#    degree_t      status  is_placed
# 0  Commerce  Not Placed         43
# 1  Commerce      Placed        102
# 2    Others  Not Placed          4
# 3    Others      Placed          5
# 4  Sci&Tech  Not Placed         18
# 5  Sci&Tech      Placed         41

# %%
aa1=data.groupby(["degree_t"])["sl_no"].count().reset_index()

# %%
aa1
# Out:
#    degree_t  sl_no
# 0  Commerce    145
# 1    Others      9
# 2  Sci&Tech     59

# %%
merge=pd.merge(aa,aa1,left_on="degree_t",right_on="degree_t",how="inner")

# %%
merge
# Out:
#    degree_t      status  is_placed  sl_no
# 0  Commerce  Not Placed         43    145
# 1  Commerce      Placed        102    145
# 2    Others  Not Placed          4      9
# 3    Others      Placed          5      9
# 4  Sci&Tech  Not Placed         18     59
# 5  Sci&Tech      Placed         41     59

# %%
my_placed=merge[merge["status"]=="Placed"]

# %%
my_placed
# Out:
#    degree_t  status  is_placed  sl_no
# 1  Commerce  Placed        102    145
# 3    Others  Placed          5      9
# 5  Sci&Tech  Placed         41     59

# %%
my_placed["place_rate"]=(my_placed['is_placed']/my_placed["sl_no"])*100
# Out:
# C:\Users\rames\AppData\Local\Temp\ipykernel_30088\808229152.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   my_placed["place_rate"]=(my_placed['is_placed']/my_placed["sl_no"])*100

# %%
my_placed
# Out:
#    degree_t  status  is_placed  sl_no  place_rate
# 1  Commerce  Placed        102    145   70.344828
# 3    Others  Placed          5      9   55.555556
# 5  Sci&Tech  Placed         41     59   69.491525

# %%
my_placed["place_rate"].max()
# Out:
# 70.34482758620689

# %%
#75. Display how many students scored more than 70 in mba_p for each specialisation.
mba=data[data["mba_p"]>70]

# %%
mba
# Out:
#          status  sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  \
# 1        Placed      2      F  79.33  Central  78.33   Others   Science
# 12   Not Placed     13      M  47.00  Central  55.00   Others   Science
# 13       Placed     14      M  77.00  Central  87.00  Central  Commerce
# 17   Not Placed     18      M  55.00  Central  67.00  Central  Commerce
# 19       Placed     20      F  60.00   Others  67.00   Others      Arts
# ..          ...    ...    ...    ...      ...    ...      ...       ...
# 198  Not Placed    199      M  67.00  Central  70.00  Central  Commerce
# 204      Placed    205      M  74.00   Others  73.00   Others  Commerce
# 207      Placed    208      F  83.33  Central  78.00   Others  Commerce
# 210      Placed    211      F  80.60   Others  82.00   Others  Commerce
# 212      Placed    213      F  67.00   Others  67.00   Others  Commerce
#
#      degree_p  degree_t  ...  overall_avg  degree_percentage placement_status  \
# ...

# %%
mba.groupby("specialisation")['sl_no'].count()
# Out:
# specialisation
# Mkt&Fin    44
# Mkt&HR     25
# Name: sl_no, dtype: int64

# %%
#76. Sort dataset by salary in descending order.
data.sort_values(by="salary",ascending=False)
# Out:
#          status  sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  \
# 119      Placed    120      F  60.80  Central  68.40  Central  Commerce
# 150      Placed    151      F  71.00  Central  58.66  Central   Science
# 177      Placed    178      M  73.00  Central  97.00   Others  Commerce
# 163      Placed    164      F  63.00   Others  67.00   Others   Science
# 77       Placed     78      F  64.00   Others  80.00   Others   Science
# ..          ...    ...    ...    ...      ...    ...      ...       ...
# 184  Not Placed    185      M  56.28   Others  62.83   Others  Commerce
# 206  Not Placed    207      F  41.00  Central  42.00  Central   Science
# 201  Not Placed    202      F  54.20  Central  63.00   Others   Science
# 208  Not Placed    209      M  43.00  Central  60.00   Others   Science
# 214  Not Placed    215      F  62.00  Central  58.00   Others   Science
#
#      degree_p  degree_t  ...  overall_avg  degree_percentage placement_status  \
# ...

# %%
#77. Sort by degree_p and then by mba_p.
data.sort_values(by=["degree_p","mba_p"])
# Out:
#          status  sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  \
# 14   Not Placed     15      F  62.00  Central   47.0  Central  Commerce
# 25   Not Placed     26      M  52.58   Others   54.6  Central  Commerce
# 91   Not Placed     92      F  52.00  Central   57.0  Central  Commerce
# 3    Not Placed      4      F  56.00  Central   52.0  Central   Science
# 34   Not Placed     35      F  62.00   Others   51.0   Others   Science
# ..          ...    ...    ...    ...      ...    ...      ...       ...
# 90       Placed     91      M  85.00   Others   90.0   Others  Commerce
# 107      Placed    108      F  82.00   Others   90.0   Others  Commerce
# 152      Placed    153      M  75.40   Others   60.5  Central   Science
# 21       Placed     22      M  79.00   Others   76.0   Others  Commerce
# 197      Placed    198      M  83.96   Others   53.0   Others   Science
#
#      degree_p  degree_t  ...  overall_avg  degree_percentage placement_status  \
# ...

# %%
#78. Sort all placed students by salary.
placed
# Out:
#      status  sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0    Placed      1      F  67.00   Others  91.00   Others  Commerce     58.00
# 1    Placed      2      F  79.33  Central  78.33   Others   Science     77.48
# 2    Placed      3      F  65.00  Central  68.00  Central      Arts     64.00
# 4    Placed      5      F  85.80  Central  73.60  Central  Commerce     73.30
# 7    Placed      8      F  82.00  Central  64.00  Central   Science     66.00
# ..      ...    ...    ...    ...      ...    ...      ...       ...       ...
# 209  Placed    210      F  62.00  Central  72.00  Central  Commerce     65.00
# 210  Placed    211      F  80.60   Others  82.00   Others  Commerce     77.60
# 211  Placed    212      F  58.00   Others  60.00   Others   Science     72.00
# 212  Placed    213      F  67.00   Others  67.00   Others  Commerce     73.00
# 213  Placed    214      M  74.00   Others  66.00   Others  Commerce     58.00
#
# ...

# %%
placed.sort_values(by="salary",ascending=False)
# Out:
#      status  sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 119  Placed    120      F  60.80  Central  68.40  Central  Commerce     64.60
# 150  Placed    151      F  71.00  Central  58.66  Central   Science     58.00
# 177  Placed    178      M  73.00  Central  97.00   Others  Commerce     79.00
# 77   Placed     78      F  64.00   Others  80.00   Others   Science     65.00
# 163  Placed    164      F  63.00   Others  67.00   Others   Science     64.00
# ..      ...    ...    ...    ...      ...    ...      ...       ...       ...
# 1    Placed      2      F  79.33  Central  78.33   Others   Science     77.48
# 107  Placed    108      F  82.00   Others  90.00   Others  Commerce     83.00
# 44   Placed     45      M  77.00   Others  73.00   Others  Commerce     81.00
# 50   Placed     51      M  75.20  Central  73.20  Central   Science     68.40
# 135  Placed    136      M  72.00  Central  56.00   Others   Science     69.00
#
# ...

# %%
#79. Sort the entire dataset by ssc_p ascending.
data.sort_values(by="ssc_p")
# Out:
#          status  sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  \
# 52   Not Placed     53      M  40.89   Others  45.83   Others  Commerce
# 206  Not Placed    207      F  41.00  Central  42.00  Central   Science
# 208  Not Placed    209      M  43.00  Central  60.00   Others   Science
# 149  Not Placed    150      F  44.00  Central  58.00  Central      Arts
# 100  Not Placed    101      M  45.00   Others  57.00   Others  Commerce
# ..          ...    ...    ...    ...      ...    ...      ...       ...
# 43       Placed     44      F  87.00   Others  87.00   Others  Commerce
# 33       Placed     34      M  87.00   Others  65.00   Others   Science
# 160      Placed    161      F  87.00  Central  74.00  Central   Science
# 185      Placed    186      M  88.00  Central  72.00  Central   Science
# 145      Placed    146      F  89.40   Others  65.66   Others   Science
#
#      degree_p  degree_t  ...  overall_avg  degree_percentage placement_status  \
# ...

# %%
#80. Set sl_no as the index.
data.set_index("sl_no")
# Out:
#            status gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# sl_no
# 1          Placed      F  67.00   Others  91.00   Others  Commerce     58.00
# 2          Placed      F  79.33  Central  78.33   Others   Science     77.48
# 3          Placed      F  65.00  Central  68.00  Central      Arts     64.00
# 4      Not Placed      F  56.00  Central  52.00  Central   Science     52.00
# 5          Placed      F  85.80  Central  73.60  Central  Commerce     73.30
# ...           ...    ...    ...      ...    ...      ...       ...       ...
# 211        Placed      F  80.60   Others  82.00   Others  Commerce     77.60
# 212        Placed      F  58.00   Others  60.00   Others   Science     72.00
# 213        Placed      F  67.00   Others  67.00   Others  Commerce     73.00
# 214        Placed      M  74.00   Others  66.00   Others  Commerce     58.00
# 215    Not Placed      F  62.00  Central  58.00   Others   Science     53.00
#
# ...

# %%
#81. Reset index to default.
data.reset_index()
# Out:
#      index      status  sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b  \
# 0        0      Placed      1      F  67.00   Others  91.00   Others
# 1        1      Placed      2      F  79.33  Central  78.33   Others
# 2        2      Placed      3      F  65.00  Central  68.00  Central
# 3        3  Not Placed      4      F  56.00  Central  52.00  Central
# 4        4      Placed      5      F  85.80  Central  73.60  Central
# ..     ...         ...    ...    ...    ...      ...    ...      ...
# 208    210      Placed    211      F  80.60   Others  82.00   Others
# 209    211      Placed    212      F  58.00   Others  60.00   Others
# 210    212      Placed    213      F  67.00   Others  67.00   Others
# 211    213      Placed    214      M  74.00   Others  66.00   Others
# 212    214  Not Placed    215      F  62.00  Central  58.00   Others
#
#         hsc_s  degree_p  ... overall_avg  degree_percentage  placement_status  \
# ...

# %%
#82. Sort students first by status, then by salary (descending).
data.sort_values(by=["status","salary"],ascending=False)
# Out:
#          status  sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  \
# 119      Placed    120      F   60.8  Central  68.40  Central  Commerce
# 150      Placed    151      F   71.0  Central  58.66  Central   Science
# 177      Placed    178      M   73.0  Central  97.00   Others  Commerce
# 77       Placed     78      F   64.0   Others  80.00   Others   Science
# 163      Placed    164      F   63.0   Others  67.00   Others   Science
# ..          ...    ...    ...    ...      ...    ...      ...       ...
# 198  Not Placed    199      M   67.0  Central  70.00  Central  Commerce
# 201  Not Placed    202      F   54.2  Central  63.00   Others   Science
# 206  Not Placed    207      F   41.0  Central  42.00  Central   Science
# 208  Not Placed    209      M   43.0  Central  60.00   Others   Science
# 214  Not Placed    215      F   62.0  Central  58.00   Others   Science
#
#      degree_p  degree_t  ...  overall_avg  degree_percentage placement_status  \
# ...

# %%
#83. Retrieve top 5 students with highest mba_p.
data.sort_values(by="mba_p",ascending=False).head(5)
# Out:
#          status  sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  \
# 19       Placed     20      F  60.00   Others  67.00   Others      Arts
# 128      Placed    129      F  80.40  Central  73.40  Central   Science
# 85       Placed     86      M  83.84   Others  89.83   Others  Commerce
# 167  Not Placed    168      F  67.90   Others  62.00   Others   Science
# 165  Not Placed    166      M  63.30  Central  78.33   Others  Commerce
#
#      degree_p  degree_t  ...  overall_avg  degree_percentage placement_status  \
# 19      70.00  Commerce  ...      68.7225              70.00            Hired
# 128     77.72  Sci&Tech  ...      76.9450              77.72            Hired
# 85      77.20  Commerce  ...      81.7625              77.20            Hired
# 167     67.00  Sci&Tech  ...      68.1525              67.00        Not Hired
# 165     74.00  Commerce  ...      72.5475              74.00        Not Hired
#
# ...

# %%
#84. Retrieve bottom 10 students with lowest degree_p.
data.sort_values(by="degree_p",ascending=False).tail(10)
# Out:
#          status  sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  \
# 188  Not Placed    189      F  61.80   Others  47.00   Others  Commerce
# 93   Not Placed     94      F  52.00  Central  62.00  Central  Commerce
# 106  Not Placed    107      F  61.08   Others  50.00   Others   Science
# 52   Not Placed     53      M  40.89   Others  45.83   Others  Commerce
# 214  Not Placed    215      F  62.00  Central  58.00   Others   Science
# 34   Not Placed     35      F  62.00   Others  51.00   Others   Science
# 3    Not Placed      4      F  56.00  Central  52.00  Central   Science
# 91   Not Placed     92      F  52.00  Central  57.00  Central  Commerce
# 25   Not Placed     26      M  52.58   Others  54.60  Central  Commerce
# 14   Not Placed     15      F  62.00  Central  47.00  Central  Commerce
#
#      degree_p  degree_t  ...  overall_avg  degree_percentage placement_status  \
# 188     54.38  Commerce  ...      54.8275              54.38        Not Hired
# ...

# %%
#85. Use .nlargest() to get top 5 salaries.
data.nlargest(5,"salary")
# Out:
#      status  sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 119  Placed    120      F   60.8  Central  68.40  Central  Commerce      64.6
# 150  Placed    151      F   71.0  Central  58.66  Central   Science      58.0
# 177  Placed    178      M   73.0  Central  97.00   Others  Commerce      79.0
# 77   Placed     78      F   64.0   Others  80.00   Others   Science      65.0
# 163  Placed    164      F   63.0   Others  67.00   Others   Science      64.0
#
#      degree_t  ...  overall_avg  degree_percentage placement_status  \
# 119  Commerce  ...      64.5350               64.6            Hired
# 150  Sci&Tech  ...      62.2400               58.0            Hired
# 177  Commerce  ...      79.9525               79.0            Hired
# 77   Sci&Tech  ...      66.6625               65.0            Hired
# 163  Sci&Tech  ...      65.1150               64.0            Hired
#
#      above_80_ssc  salary_in_lpa  performance_tag  degree_and_specialization  \
# ...

# %%
#86. Use .nsmallest() to get 3 lowest etest_p values.
data.nsmallest(3,"etest_p")
# Out:
#          status  sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  \
# 20       Placed     21      F   62.0   Others   65.0   Others  Commerce
# 99   Not Placed    100      F   54.0  Central   82.0   Others  Commerce
# 190  Not Placed    191      M   64.0   Others   70.2  Central  Commerce
#
#      degree_p  degree_t  ...  overall_avg  degree_percentage placement_status  \
# 20       66.0  Commerce  ...      62.4250               66.0            Hired
# 99       63.0  Sci&Tech  ...      64.6175               63.0        Not Hired
# 190      61.0  Commerce  ...      64.4250               61.0        Not Hired
#
#      above_80_ssc  salary_in_lpa  performance_tag  degree_and_specialization  \
# 20          False           2.65          Average            Commerce_Mkt&HR
# 99          False            NaN          Average           Sci&Tech_Mkt&Fin
# 190         False            NaN          Average           Commerce_Mkt&Fin
#
#     total_score  is_placed  mba_grade
# ...

# %%
#87. Select rows using .loc[] for index 10 to 20.
data.loc[10:20]
# Out:
#         status  sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  \
# 10      Placed     11      F   58.0  Central   61.0  Central  Commerce
# 11      Placed     12      F   69.6  Central   68.4  Central  Commerce
# 12  Not Placed     13      M   47.0  Central   55.0   Others   Science
# 13      Placed     14      M   77.0  Central   87.0  Central  Commerce
# 14  Not Placed     15      F   62.0  Central   47.0  Central  Commerce
# 15      Placed     16      M   65.0  Central   75.0  Central  Commerce
# 16      Placed     17      F   63.0  Central   66.2  Central  Commerce
# 17  Not Placed     18      M   55.0  Central   67.0  Central  Commerce
# 18  Not Placed     19      M   63.0  Central   66.0  Central  Commerce
# 19      Placed     20      F   60.0   Others   67.0   Others      Arts
# 20      Placed     21      F   62.0   Others   65.0   Others  Commerce
#
#     degree_p  degree_t  ...  overall_avg  degree_percentage placement_status  \
# ...

# %%
#88. Use .iloc[] to get first 3 columns and first 10 rows.
data.iloc[0:10,0:3]
# Out:
#        status  sl_no gender
# 0      Placed      1      F
# 1      Placed      2      F
# 2      Placed      3      F
# 3  Not Placed      4      F
# 4      Placed      5      F
# 5  Not Placed      6      F
# 6  Not Placed      7      M
# 7      Placed      8      F
# 8      Placed      9      F
# 9  Not Placed     10      F

# %%
#89. Sort dataset alphabetically by degree_t.
data.sort_values(by="degree_t")
# Out:
#          status  sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  \
# 108      Placed    109      F   61.0  Central   82.0  Central  Commerce
# 120  Not Placed    121      F   58.0   Others   40.0   Others   Science
# 122      Placed    123      M   66.5  Central   66.8  Central      Arts
# 123      Placed    124      F   74.0   Others   59.0   Others  Commerce
# 125      Placed    126      M   84.0  Central   73.0  Central  Commerce
# ..          ...    ...    ...    ...      ...    ...      ...       ...
# 53       Placed     54      F   80.0   Others   70.0   Others   Science
# 128      Placed    129      F   80.4  Central   73.4  Central   Science
# 126      Placed    127      M   79.0   Others   61.0   Others   Science
# 121      Placed    122      M   64.0  Central   67.0   Others   Science
# 0        Placed      1      F   67.0   Others   91.0   Others  Commerce
#
#      degree_p  degree_t  ...  overall_avg  degree_percentage placement_status  \
# ...

# %%
#90. Display all columns except sl_no and salary.
data_f=data.drop(columns=["sl_no","salary"])

# %%
data_f
# Out:
#          status gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        Placed      F  67.00   Others  91.00   Others  Commerce     58.00
# 1        Placed      F  79.33  Central  78.33   Others   Science     77.48
# 2        Placed      F  65.00  Central  68.00  Central      Arts     64.00
# 3    Not Placed      F  56.00  Central  52.00  Central   Science     52.00
# 4        Placed      F  85.80  Central  73.60  Central  Commerce     73.30
# ..          ...    ...    ...      ...    ...      ...       ...       ...
# 210      Placed      F  80.60   Others  82.00   Others  Commerce     77.60
# 211      Placed      F  58.00   Others  60.00   Others   Science     72.00
# 212      Placed      F  67.00   Others  67.00   Others  Commerce     73.00
# 213      Placed      M  74.00   Others  66.00   Others  Commerce     58.00
# 214  Not Placed      F  62.00  Central  58.00   Others   Science     53.00
#
# ...

# %%
#91. Select only gender, status, salary, and specialisation columns.
data[["gender","status",'salary',"specialisation"]]
# Out:
#     gender      status    salary specialisation
# 0        F      Placed  270000.0         Mkt&HR
# 1        F      Placed  200000.0        Mkt&Fin
# 2        F      Placed  250000.0        Mkt&Fin
# 3        F  Not Placed       0.0         Mkt&HR
# 4        F      Placed  425000.0        Mkt&Fin
# ..     ...         ...       ...            ...
# 210      F      Placed  400000.0        Mkt&Fin
# 211      F      Placed  275000.0        Mkt&Fin
# 212      F      Placed  295000.0        Mkt&Fin
# 213      M      Placed  204000.0         Mkt&HR
# 214      F  Not Placed       0.0         Mkt&HR
#
# [213 rows x 4 columns]

# %%
#92. Filter dataset for first and last 5 rows together.
first=data.head(5)
tail=data.tail(5)

# %%
concat=pd.concat([first,tail])

# %%
concat
# Out:
#          status  sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  \
# 0        Placed      1      F  67.00   Others  91.00   Others  Commerce
# 1        Placed      2      F  79.33  Central  78.33   Others   Science
# 2        Placed      3      F  65.00  Central  68.00  Central      Arts
# 3    Not Placed      4      F  56.00  Central  52.00  Central   Science
# 4        Placed      5      F  85.80  Central  73.60  Central  Commerce
# 210      Placed    211      F  80.60   Others  82.00   Others  Commerce
# 211      Placed    212      F  58.00   Others  60.00   Others   Science
# 212      Placed    213      F  67.00   Others  67.00   Others  Commerce
# 213      Placed    214      M  74.00   Others  66.00   Others  Commerce
# 214  Not Placed    215      F  62.00  Central  58.00   Others   Science
#
#      degree_p  degree_t  ...  overall_avg  degree_percentage placement_status  \
# 0       58.00  Sci&Tech  ...      68.7000              58.00            Hired
# ...

# %%
#93. Reorder columns alphabetically.
data.sort_index(axis=1)
# Out:
#      above_80_ssc degree_and_specialization  degree_p  degree_percentage  \
# 0           False           Sci&Tech_Mkt&HR     58.00              58.00
# 1           False          Sci&Tech_Mkt&Fin     77.48              77.48
# 2           False          Commerce_Mkt&Fin     64.00              64.00
# 3           False           Sci&Tech_Mkt&HR     52.00              52.00
# 4            True          Commerce_Mkt&Fin     73.30              73.30
# ..            ...                       ...       ...                ...
# 210          True          Commerce_Mkt&Fin     77.60              77.60
# 211         False          Sci&Tech_Mkt&Fin     72.00              72.00
# 212         False          Commerce_Mkt&Fin     73.00              73.00
# 213         False           Commerce_Mkt&HR     58.00              58.00
# 214         False           Commerce_Mkt&HR     53.00              53.00
#
#      degree_t  etest_p gender    hsc_b  hsc_p     hsc_s  ...  \
# ...

# %%
#94. Sort dataset based on the rounded value of etest_p.
data.sort_values(by='etest_p',key=lambda col: col.round(0))
# Out:
#          status  sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  \
# 20       Placed     21      F   62.0   Others   65.0   Others  Commerce
# 19       Placed     20      F   60.0   Others   67.0   Others      Arts
# 99   Not Placed    100      F   54.0  Central   82.0   Others  Commerce
# 190  Not Placed    191      M   64.0   Others   70.2  Central  Commerce
# 32       Placed     33      M   61.0  Central   81.0  Central  Commerce
# ..          ...    ...    ...    ...      ...    ...      ...       ...
# 118      Placed    119      F   76.0  Central   80.0  Central   Science
# 4        Placed      5      F   85.8  Central   73.6  Central  Commerce
# 24       Placed     25      F   76.5   Others   97.7   Others   Science
# 206  Not Placed    207      F   41.0  Central   42.0  Central   Science
# 152      Placed    153      M   75.4   Others   60.5  Central   Science
#
#      degree_p  degree_t  ...  overall_avg  degree_percentage placement_status  \
# ...

# %%
data.sort_values(by="etest_p")
# Out:
#          status  sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  \
# 20       Placed     21      F   62.0   Others   65.0   Others  Commerce
# 99   Not Placed    100      F   54.0  Central   82.0   Others  Commerce
# 190  Not Placed    191      M   64.0   Others   70.2  Central  Commerce
# 19       Placed     20      F   60.0   Others   67.0   Others      Arts
# 32       Placed     33      M   61.0  Central   81.0  Central  Commerce
# ..          ...    ...    ...    ...      ...    ...      ...       ...
# 4        Placed      5      F   85.8  Central   73.6  Central  Commerce
# 118      Placed    119      F   76.0  Central   80.0  Central   Science
# 206  Not Placed    207      F   41.0  Central   42.0  Central   Science
# 24       Placed     25      F   76.5   Others   97.7   Others   Science
# 152      Placed    153      M   75.4   Others   60.5  Central   Science
#
#      degree_p  degree_t  ...  overall_avg  degree_percentage placement_status  \
# ...

# %%
#95. Extract all rows with even index numbers only.
data.iloc[::2]
# Out:
#          status  sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  \
# 0        Placed      1      F   67.0   Others   91.0   Others  Commerce
# 2        Placed      3      F   65.0  Central   68.0  Central      Arts
# 4        Placed      5      F   85.8  Central   73.6  Central  Commerce
# 6    Not Placed      7      M   46.0   Others   49.2   Others  Commerce
# 8        Placed      9      F   73.0  Central   79.0  Central  Commerce
# ..          ...    ...    ...    ...      ...    ...      ...       ...
# 206  Not Placed    207      F   41.0  Central   42.0  Central   Science
# 208  Not Placed    209      M   43.0  Central   60.0   Others   Science
# 210      Placed    211      F   80.6   Others   82.0   Others  Commerce
# 212      Placed    213      F   67.0   Others   67.0   Others  Commerce
# 214  Not Placed    215      F   62.0  Central   58.0   Others   Science
#
#      degree_p  degree_t  ...  overall_avg  degree_percentage placement_status  \
# ...

# %%
#96. Concatenate two subsets: one for Placed and one for Not Placed.
placed
# Out:
#      status  sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0    Placed      1      F  67.00   Others  91.00   Others  Commerce     58.00
# 1    Placed      2      F  79.33  Central  78.33   Others   Science     77.48
# 2    Placed      3      F  65.00  Central  68.00  Central      Arts     64.00
# 4    Placed      5      F  85.80  Central  73.60  Central  Commerce     73.30
# 7    Placed      8      F  82.00  Central  64.00  Central   Science     66.00
# ..      ...    ...    ...    ...      ...    ...      ...       ...       ...
# 209  Placed    210      F  62.00  Central  72.00  Central  Commerce     65.00
# 210  Placed    211      F  80.60   Others  82.00   Others  Commerce     77.60
# 211  Placed    212      F  58.00   Others  60.00   Others   Science     72.00
# 212  Placed    213      F  67.00   Others  67.00   Others  Commerce     73.00
# 213  Placed    214      M  74.00   Others  66.00   Others  Commerce     58.00
#
# ...

# %%
Not_placed=data[data["status"]=="Not Placed"]

# %%
Not_placed
# Out:
#          status  sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  \
# 3    Not Placed      4      F   56.0  Central   52.0  Central   Science
# 5    Not Placed      6      F   55.0   Others   49.8   Others   Science
# 6    Not Placed      7      M   46.0   Others   49.2   Others  Commerce
# 9    Not Placed     10      F   58.0  Central   70.0  Central  Commerce
# 12   Not Placed     13      M   47.0  Central   55.0   Others   Science
# ..          ...    ...    ...    ...      ...    ...      ...       ...
# 198  Not Placed    199      M   67.0  Central   70.0  Central  Commerce
# 201  Not Placed    202      F   54.2  Central   63.0   Others   Science
# 206  Not Placed    207      F   41.0  Central   42.0  Central   Science
# 208  Not Placed    209      M   43.0  Central   60.0   Others   Science
# 214  Not Placed    215      F   62.0  Central   58.0   Others   Science
#
#      degree_p  degree_t  ...  overall_avg  degree_percentage placement_status  \
# ...

# %%
pd.concat([placed,Not_placed])
# Out:
#          status  sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  \
# 0        Placed      1      F  67.00   Others  91.00   Others  Commerce
# 1        Placed      2      F  79.33  Central  78.33   Others   Science
# 2        Placed      3      F  65.00  Central  68.00  Central      Arts
# 4        Placed      5      F  85.80  Central  73.60  Central  Commerce
# 7        Placed      8      F  82.00  Central  64.00  Central   Science
# ..          ...    ...    ...    ...      ...    ...      ...       ...
# 198  Not Placed    199      M  67.00  Central  70.00  Central  Commerce
# 201  Not Placed    202      F  54.20  Central  63.00   Others   Science
# 206  Not Placed    207      F  41.00  Central  42.00  Central   Science
# 208  Not Placed    209      M  43.00  Central  60.00   Others   Science
# 214  Not Placed    215      F  62.00  Central  58.00   Others   Science
#
#      degree_p  degree_t  ...  overall_avg  degree_percentage placement_status  \
# ...

# %%
#97. Merge two DataFrames — one containing gender, salary; another with gender, mba_p.
d1=data[["gender","salary"]]
d2=data[["gender","mba_p"]]

# %%
d1
# Out:
#     gender    salary
# 0        F  270000.0
# 1        F  200000.0
# 2        F  250000.0
# 3        F       0.0
# 4        F  425000.0
# ..     ...       ...
# 210      F  400000.0
# 211      F  275000.0
# 212      F  295000.0
# 213      M  204000.0
# 214      F       0.0
#
# [213 rows x 2 columns]

# %%
d2
# Out:
#     gender  mba_p
# 0        F  63.80
# 1        F  71.28
# 2        F  62.80
# 3        F  64.43
# 4        F  60.50
# ..     ...    ...
# 210      F  79.49
# 211      F  58.62
# 212      F  74.72
# 213      M  65.23
# 214      F  65.22
#
# [213 rows x 2 columns]

# %%
pd.merge(d1,d2,left_on="gender",right_on="gender",how="inner")
# Out:
#       gender    salary  mba_p
# 0          F  270000.0  63.80
# 1          F  270000.0  71.28
# 2          F  270000.0  62.80
# 3          F  270000.0  64.43
# 4          F  270000.0  60.50
# ...      ...       ...    ...
# 24664      F       0.0  61.49
# 24665      F       0.0  79.49
# 24666      F       0.0  58.62
# 24667      F       0.0  74.72
# 24668      F       0.0  65.22
#
# [24669 rows x 3 columns]

# %%
#98. Join two small DataFrames on specialisation.
data1 = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David'],
    'specialisation': ['Physics', 'Chemistry', 'Math', 'Physics'],
    'Age': [24, 27, 22, 32]}

# %%
data2 = {
    'specialisation': ['Physics', 'Chemistry', 'Biology'],
    'Department': ['Science', 'Science', 'Science'],
    'Building': [101, 102, 103]
}

# %%
data1
# Out:
# {'Name': ['Alice', 'Bob', 'Charlie', 'David'],
#  'specialisation': ['Physics', 'Chemistry', 'Math', 'Physics'],
#  'Age': [24, 27, 22, 32]}

# %%
data2
# Out:
# {'specialisation': ['Physics', 'Chemistry', 'Biology'],
#  'Department': ['Science', 'Science', 'Science'],
#  'Building': [101, 102, 103]}

# %%
df1=pd.DataFrame(data1)
df2=pd.DataFrame(data2)

# %%
df1
# Out:
#       Name specialisation  Age
# 0    Alice        Physics   24
# 1      Bob      Chemistry   27
# 2  Charlie           Math   22
# 3    David        Physics   32

# %%
df2
# Out:
#   specialisation Department  Building
# 0        Physics    Science       101
# 1      Chemistry    Science       102
# 2        Biology    Science       103

# %%
pd.merge(df1,df2,on="specialisation",how="inner")
# Out:
#     Name specialisation  Age Department  Building
# 0  Alice        Physics   24    Science       101
# 1    Bob      Chemistry   27    Science       102
# 2  David        Physics   32    Science       101

# %%
#99. Sort records by specialisation and then by descending degree_p.
data.sort_values(by=["specialisation","degree_p"],ascending=False)
# Out:
#          status  sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  \
# 197      Placed    198      M  83.96   Others   53.0   Others   Science
# 107      Placed    108      F  82.00   Others   90.0   Others  Commerce
# 118      Placed    119      F  76.00  Central   80.0  Central   Science
# 185      Placed    186      M  88.00  Central   72.0  Central   Science
# 128      Placed    129      F  80.40  Central   73.4  Central   Science
# ..          ...    ...    ...    ...      ...    ...      ...       ...
# 194  Not Placed    195      F  52.00   Others   55.0   Others  Commerce
# 148      Placed    149      M  77.00  Central   86.0  Central      Arts
# 188  Not Placed    189      F  61.80   Others   47.0   Others  Commerce
# 106  Not Placed    107      F  61.08   Others   50.0   Others   Science
# 25   Not Placed     26      M  52.58   Others   54.6  Central  Commerce
#
#      degree_p  degree_t  ...  overall_avg  degree_percentage placement_status  \
# ...

# %%
#100.Retrieve top 10 highest salaries and display only gender, degree_t, specialisation, and salary.
s_sal=data.sort_values(by="salary",ascending=False)

# %%
s_gr=s_sal[["gender","degree_t","specialisation",'salary']]

# %%
s_gr.head(10)
# Out:
#     gender  degree_t specialisation    salary
# 119      F  Commerce        Mkt&Fin  940000.0
# 150      F  Sci&Tech        Mkt&Fin  690000.0
# 177      M  Commerce        Mkt&Fin  650000.0
# 163      F  Sci&Tech        Mkt&Fin  500000.0
# 77       F  Sci&Tech        Mkt&Fin  500000.0
# 174      F  Sci&Tech        Mkt&Fin  500000.0
# 53       F  Sci&Tech         Mkt&HR  450000.0
# 4        F  Commerce        Mkt&Fin  425000.0
# 95       F  Commerce        Mkt&Fin  420000.0
# 39       F  Sci&Tech        Mkt&Fin  411000.0
