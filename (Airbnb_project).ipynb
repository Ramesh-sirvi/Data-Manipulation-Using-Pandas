# %%
import pandas as pd

# %%
data=pd.read_csv("Airbnb.csv")
# Out:
# C:\Users\rames\AppData\Local\Temp\ipykernel_1208\4048832735.py:1: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   data=pd.read_csv("Airbnb.csv")

# %%
data
# Out:
#              id                                              NAME  \
# 0       1001254                Clean & quiet apt home by the park
# 1       1002102                             Skylit Midtown Castle
# 2       1002403               THE VILLAGE OF HARLEM....NEW YORK !
# 3       1002755                                               NaN
# 4       1003689  Entire Apt: Spacious Studio/Loft by central park
# ...         ...                                               ...
# 102594  6092437                        Spare room in Williamsburg
# 102595  6092990                     Best Location near Columbia U
# 102596  6093542                    Comfy, bright room in Brooklyn
# 102597  6094094                  Big Studio-One Stop from Midtown
# 102598  6094647                              585 sf Luxury Studio
#
#             host id host_identity_verified    host name neighbourhood group  \
# 0       80014485718            unconfirmed     Madaline            Brooklyn
# ...

# %%
#1. Display the first 10 rows of the dataset.
data.head(10)
# Out:
#         id                                              NAME      host id  \
# 0  1001254                Clean & quiet apt home by the park  80014485718
# 1  1002102                             Skylit Midtown Castle  52335172823
# 2  1002403               THE VILLAGE OF HARLEM....NEW YORK !  78829239556
# 3  1002755                                               NaN  85098326012
# 4  1003689  Entire Apt: Spacious Studio/Loft by central park  92037596077
# 5  1004098         Large Cozy 1 BR Apartment In Midtown East  45498551794
# 6  1004650                                   BlissArtsSpace!  61300605564
# 7  1005202                                   BlissArtsSpace!  90821839709
# 8  1005754                   Large Furnished Room Near B'way  79384379533
# 9  1006307                Cozy Clean Guest Room - Family Apt  75527839483
#
#   host_identity_verified host name neighbourhood group       neighbourhood  \
# 0            unconfirmed  Madaline            Brooklyn          Kensington
# ...

# %%
#2. Show the last 5 rows of the dataset.
data.tail()
# Out:
#              id                              NAME      host id  \
# 102594  6092437        Spare room in Williamsburg  12312296767
# 102595  6092990     Best Location near Columbia U  77864383453
# 102596  6093542    Comfy, bright room in Brooklyn  69050334417
# 102597  6094094  Big Studio-One Stop from Midtown  11160591270
# 102598  6094647              585 sf Luxury Studio  68170633372
#
#        host_identity_verified    host name neighbourhood group  \
# 102594               verified         Krik            Brooklyn
# 102595            unconfirmed        Mifan           Manhattan
# 102596            unconfirmed        Megan            Brooklyn
# 102597            unconfirmed  Christopher              Queens
# 102598            unconfirmed      Rebecca           Manhattan
#
#               neighbourhood       lat      long        country  ...  \
# 102594         Williamsburg  40.70862 -73.94651  United States  ...
# ...

# %%
#3. Get all column names in the dataset.
data.columns
# Out:
# Index(['id', 'NAME', 'host id', 'host_identity_verified', 'host name',
#        'neighbourhood group', 'neighbourhood', 'lat', 'long', 'country',
#        'country code', 'instant_bookable', 'cancellation_policy', 'room type',
#        'Construction year', 'price', 'service fee', 'minimum nights',
#        'number of reviews', 'last review', 'reviews per month',
#        'review rate number', 'calculated host listings count',
#        'availability 365', 'house_rules', 'license'],
#       dtype='object')

# %%
#4. Display the shape (rows, columns) of the dataset.
data.shape
# Out:
# (102599, 26)

# %%
#6. Display only the columns: name, price, and room_type.
data[["NAME","price","room type"]]
# Out:
#                                                     NAME    price  \
# 0                     Clean & quiet apt home by the park    $966
# 1                                  Skylit Midtown Castle    $142
# 2                    THE VILLAGE OF HARLEM....NEW YORK !    $620
# 3                                                    NaN    $368
# 4       Entire Apt: Spacious Studio/Loft by central park    $204
# ...                                                  ...      ...
# 102594                        Spare room in Williamsburg    $844
# 102595                     Best Location near Columbia U    $837
# 102596                    Comfy, bright room in Brooklyn    $988
# 102597                  Big Studio-One Stop from Midtown    $546
# 102598                              585 sf Luxury Studio  $1,032
#
#               room type
# 0          Private room
# 1       Entire home/apt
# 2          Private room
# 3       Entire home/apt
# 4       Entire home/apt
# ...                 ...
# ...

# %%
#7. Retrieve all unique values in the room_type column.
data["room type"].unique()
# Out:
# array(['Private room', 'Entire home/apt', 'Shared room', 'Hotel room'],
#       dtype=object)

# %%
#8. Count how many unique host IDs exist in the dataset.
data["host id"].unique()
# Out:
# array([80014485718, 52335172823, 78829239556, ..., 23801060917,
#        15593031571, 93578954226])

# %%
#9. Select all rows where price is greater than 100.
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102599 entries, 0 to 102598
# Data columns (total 26 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   id                              102599 non-null  int64
#  1   NAME                            102349 non-null  object
#  2   host id                         102599 non-null  int64
#  3   host_identity_verified          102310 non-null  object
#  4   host name                       102193 non-null  object
#  5   neighbourhood group             102570 non-null  object
#  6   neighbourhood                   102583 non-null  object
#  7   lat                             102591 non-null  float64
#  8   long                            102591 non-null  float64
#  9   country                         102067 non-null  object
#  10  country code                    102468 non-null  object
#  11  instant_bookable                102494 non-null  object
# ...

# %%
data["price"].unique()
# Out:
# array(['$966 ', '$142 ', '$620 ', ..., '$1,184 ', '$905 ', '$309 '],
#       dtype=object)

# %%
data["price"]=data["price"].str.replace("$","")

# %%
data["price"]=data["price"].str.replace(" ","")

# %%
data["price"]=data["price"].str.replace(",","")

# %%
data["price"]=data["price"].astype("float")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102599 entries, 0 to 102598
# Data columns (total 26 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   id                              102599 non-null  int64
#  1   NAME                            102349 non-null  object
#  2   host id                         102599 non-null  int64
#  3   host_identity_verified          102310 non-null  object
#  4   host name                       102193 non-null  object
#  5   neighbourhood group             102570 non-null  object
#  6   neighbourhood                   102583 non-null  object
#  7   lat                             102591 non-null  float64
#  8   long                            102591 non-null  float64
#  9   country                         102067 non-null  object
#  10  country code                    102468 non-null  object
#  11  instant_bookable                102494 non-null  object
# ...

# %%
data[data['price']>100]
# Out:
#              id                                              NAME  \
# 0       1001254                Clean & quiet apt home by the park
# 1       1002102                             Skylit Midtown Castle
# 2       1002403               THE VILLAGE OF HARLEM....NEW YORK !
# 3       1002755                                               NaN
# 4       1003689  Entire Apt: Spacious Studio/Loft by central park
# ...         ...                                               ...
# 102594  6092437                        Spare room in Williamsburg
# 102595  6092990                     Best Location near Columbia U
# 102596  6093542                    Comfy, bright room in Brooklyn
# 102597  6094094                  Big Studio-One Stop from Midtown
# 102598  6094647                              585 sf Luxury Studio
#
#             host id host_identity_verified    host name neighbourhood group  \
# 0       80014485718            unconfirmed     Madaline            Brooklyn
# ...

# %%
#10. Select all listings where room_type is “Entire home/apt”.
data[data["room type"]=="Entire home/apt"]
# Out:
#              id                                              NAME  \
# 1       1002102                             Skylit Midtown Castle
# 3       1002755                                               NaN
# 4       1003689  Entire Apt: Spacious Studio/Loft by central park
# 5       1004098         Large Cozy 1 BR Apartment In Midtown East
# 10      1006859                Cute & Cozy Lower East Side 1 bdrm
# ...         ...                                               ...
# 102590  6090228               Wonderful artists' loft in Brooklyn
# 102591  6090781                Columbus Ave Apt 1 block from Park
# 102592  6091333               3BR/1 Ba in TriBeCa w/ outdoor deck
# 102597  6094094                  Big Studio-One Stop from Midtown
# 102598  6094647                              585 sf Luxury Studio
#
#             host id host_identity_verified    host name neighbourhood group  \
# 1       52335172823               verified        Jenna           Manhattan
# ...

# %%
#11. Show all listings in the city “New York”.
data["country"].unique()
# Out:
# array(['United States', nan], dtype=object)

# %%
data.columns
# Out:
# Index(['id', 'NAME', 'host id', 'host_identity_verified', 'host name',
#        'neighbourhood group', 'neighbourhood', 'lat', 'long', 'country',
#        'country code', 'instant_bookable', 'cancellation_policy', 'room type',
#        'Construction year', 'price', 'service fee', 'minimum nights',
#        'number of reviews', 'last review', 'reviews per month',
#        'review rate number', 'calculated host listings count',
#        'availability 365', 'house_rules', 'license'],
#       dtype='object')

# %%
#12. Retrieve only the host_name and neighbourhood columns.
data[["host name","neighbourhood"]]
# Out:
#           host name        neighbourhood
# 0          Madaline           Kensington
# 1             Jenna              Midtown
# 2             Elise               Harlem
# 3             Garry         Clinton Hill
# 4            Lyndon          East Harlem
# ...             ...                  ...
# 102594         Krik         Williamsburg
# 102595        Mifan  Morningside Heights
# 102596        Megan           Park Slope
# 102597  Christopher     Long Island City
# 102598      Rebecca      Upper West Side
#
# [102599 rows x 2 columns]

# %%
#13. Display all listings with more than 2 bedrooms.
data["room type"].unique()
# Out:
# array(['Private room', 'Entire home/apt', 'Shared room', 'Hotel room'],
#       dtype=object)

# %%
data[data["room type"]=="Entire home/apt"]
# Out:
#              id                                              NAME  \
# 1       1002102                             Skylit Midtown Castle
# 3       1002755                                               NaN
# 4       1003689  Entire Apt: Spacious Studio/Loft by central park
# 5       1004098         Large Cozy 1 BR Apartment In Midtown East
# 10      1006859                Cute & Cozy Lower East Side 1 bdrm
# ...         ...                                               ...
# 102590  6090228               Wonderful artists' loft in Brooklyn
# 102591  6090781                Columbus Ave Apt 1 block from Park
# 102592  6091333               3BR/1 Ba in TriBeCa w/ outdoor deck
# 102597  6094094                  Big Studio-One Stop from Midtown
# 102598  6094647                              585 sf Luxury Studio
#
#             host id host_identity_verified    host name neighbourhood group  \
# 1       52335172823               verified        Jenna           Manhattan
# ...

# %%
#14. Retrieve all listings that have a minimum_nights less than 3.
data["minimum nights"].unique()
# Out:
# array([ 1.000e+01,  3.000e+01,  3.000e+00,  4.500e+01,  2.000e+00,
#         1.000e+00,  5.000e+00,  4.000e+00,  9.000e+01,  7.000e+00,
#         1.400e+01,  6.000e+01,        nan,  1.800e+02,  9.000e+00,
#         3.100e+01,  6.000e+00,  1.500e+01,  2.900e+01,  8.000e+00,
#         4.700e+01,  8.100e+01,  1.440e+02,  3.710e+02,  1.490e+02,
#         2.730e+02,  1.310e+02,  2.750e+02,  3.230e+02,  5.900e+01,
#         9.900e+01,  2.680e+02, -1.000e+01,  1.890e+02,  3.400e+02,
#         1.280e+02,  3.500e+02,  1.660e+02,  1.100e+02,  5.700e+01,
#         1.420e+02,  3.660e+02,  2.800e+01,  2.000e+02,  5.000e+01,
#         3.990e+02,  1.700e+01,  1.100e+01,  4.520e+02,  2.500e+01,
#         1.300e+01,  3.455e+03, -5.000e+00,  2.100e+01,  2.700e+01,
#         1.800e+01,  3.650e+02, -1.000e+00,  2.000e+01, -1.200e+01,
#         4.000e+01,  4.400e+01,  3.980e+02, -2.000e+00,  6.500e+01,
#        -3.000e+00,  5.500e+01,  1.200e+02,  1.220e+02,  1.900e+01,
# ...

# %%
data[data["minimum nights"]<3]
# Out:
#              id                                              NAME  \
# 8       1005754                   Large Furnished Room Near B'way
# 9       1006307                Cozy Clean Guest Room - Family Apt
# 10      1006859                Cute & Cozy Lower East Side 1 bdrm
# 12      1007964                   Central Manhattan/near Broadway
# 14      1009068  Wonderful Guest Bedroom in Manhattan for SINGLES
# ...         ...                                               ...
# 102593  6091885               Welcoming, Clean, Cheap on St Marks
# 102594  6092437                        Spare room in Williamsburg
# 102595  6092990                     Best Location near Columbia U
# 102597  6094094                  Big Studio-One Stop from Midtown
# 102598  6094647                              585 sf Luxury Studio
#
#             host id host_identity_verified    host name neighbourhood group  \
# 8       79384379533               verified       Evelyn           Manhattan
# ...

# %%
#15. Show listings where availability_365 is zero.
data[data["availability 365"]==0]
# Out:
#               id                                             NAME  \
# 154      1086390                                              NaN
# 243      1135545                                Huge Chelsea Loft
# 862      1477419              Your Own 2 Br Apt Bedford and Grand
# 1541     1852430              LARGE PRIVATE FLOOR IN BROOKLYN, NY
# 2408     2331274              Central Park Room/Bath with a View!
# ...          ...                                              ...
# 102462  20404740                               New York Apartment
# 102463  20405292        Affordable bedroom in Brooklyn townhouse.
# 102465  20406397                  beautiful modern 1 bed room apt
# 102468  20408053  Clean, Cozy Home in Perfect Park Slope Location
# 102503   6042178              Perfect for Cat, Book, Park Lovers!
#
#             host id host_identity_verified   host name neighbourhood group  \
# 154     47292670441            unconfirmed     Dainton            Brooklyn
# ...

# %%
#16. Display the top 10 most expensive listings.
expensive=data.sort_values(by="price",ascending=False)

# %%
expensive.head(10)
# Out:
#              id                                               NAME  \
# 20343  12236775                   Lovely apartment in Williamsburg
# 64304  36516435                Great 1BD waterfront City Island NY
# 67200  38115896                         Bright Brooklyn Brownstone
# 33902  19725411                                           Oasis II
# 7453    5117628  Sun-filled bedroom in East Village / Gramercy NYC
# 90165  50799466                   Lovely apartment in Williamsburg
# 52744  30131847  ❤️Couples Retreat/A Road Warriors Dream🌟Perf Loc.
# 19773  11921964           1.5 BATHRM SUNNY SPACIOUS ROOM BY SUBWAY
# 5207    3877162      Bushwick Room w/ Private Entrance & Bathroom!
# 42446  24444262            Cozy room in bright, spacious apartment
#
#            host id host_identity_verified    host name neighbourhood group  \
# 20343  11151122860               verified        Harry            Brooklyn
# 64304  83460973881               verified         Alex               Bronx
# ...

# %%
#17. Sort the dataset by price in descending order.
data.sort_values(by="price",ascending=False)
# Out:
#               id                                               NAME  \
# 20343   12236775                   Lovely apartment in Williamsburg
# 64304   36516435                Great 1BD waterfront City Island NY
# 67200   38115896                         Bright Brooklyn Brownstone
# 33902   19725411                                           Oasis II
# 7453     5117628  Sun-filled bedroom in East Village / Gramercy NYC
# ...          ...                                                ...
# 102046  57361342             Sunny budget friendly room in Bushwick
# 102047  57361894            Cozy Apartment on Bedford Ave, Brooklyn
# 102048  57362446                Your 1 bedroom home away from home!
# 102049  57362999  MASTER Cozy Bedroom Queen size 2 blocks Timesq...
# 102050  57363551        Sunny Brownstone Studio in BedStuy Brooklyn
#
#             host id host_identity_verified  host name neighbourhood group  \
# 20343   11151122860               verified      Harry            Brooklyn
# ...

# %%
#18. Sort listings first by city, then by price ascending.
data.sort_values(by="price",ascending=True)
# Out:
#               id                                               NAME  \
# 8495     5693125                   Private Room in Williamsburg Apt
# 60981   34681142          Charming Greenwich Village Artist’s Haven
# 50592   28943298       Artists' Studio in the heart of Williamsburg
# 28308   16635844         Sunny bedroom on Bed-Stuy/Bushwick boarder
# 17390   10605833                        Cozy Little Italy Apartment
# ...          ...                                                ...
# 102046  57361342             Sunny budget friendly room in Bushwick
# 102047  57361894            Cozy Apartment on Bedford Ave, Brooklyn
# 102048  57362446                Your 1 bedroom home away from home!
# 102049  57362999  MASTER Cozy Bedroom Queen size 2 blocks Timesq...
# 102050  57363551        Sunny Brownstone Studio in BedStuy Brooklyn
#
#             host id host_identity_verified  host name neighbourhood group  \
# 8495     7170817633            unconfirmed      Emeka            Brooklyn
# ...

# %%
#19. Check how many rows belong to each city.
data["country code"].unique()
# Out:
# array(['US', nan], dtype=object)

# %%
#20. Display only listings whose name contains the word “Cozy”.
data[data['NAME'].str.contains('Cozy', case=False, na=False)]
# Out:
#              id                                            NAME      host id  \
# 5       1004098       Large Cozy 1 BR Apartment In Midtown East  45498551794
# 9       1006307              Cozy Clean Guest Room - Family Apt  75527839483
# 10      1006859              Cute & Cozy Lower East Side 1 bdrm   1280143094
# 52      1030056  Cozy 1BD on Central Park West in New York City  50562514538
# 90      1051043               Cozy Bedroom in Williamsburg 3 BR  14067827221
# ...         ...                                             ...          ...
# 102538  6061509      Cozy Bedroom in Renovated Harlem Apartment  75674201040
# 102543  6064270                              Nice and Cozy Room   6402191466
# 102547  6066479              Safe,quiet,cozy,Washington Hts Apt  92398842230
# 102553  6069793                Custom Designed Cozy Garden Apt,   7756381071
# 102564  6075868  Clean & Cozy- Private Room by Park and Subway!  33983881137
#
# ...

# %%
#21. Display all listings where price is between 100 and 200.
data[(data["price"]>100) & (data["price"]<200)]
# Out:
#              id                                              NAME  \
# 1       1002102                             Skylit Midtown Castle
# 14      1009068  Wonderful Guest Bedroom in Manhattan for SINGLES
# 22      1013487                    CBG CtyBGd HelpsHaiti rm#1:1-4
# 35      1020667                             Large B&B Style rooms
# 77      1043863                                    Manhattan Room
# ...         ...                                               ...
# 102500  6040521         *TERRA GARDEN* 1 Bedroom Garden Apartment
# 102534  6059299                 Upper East Side - 1 Bedroom Queen
# 102546  6065927                               LG Bright Apartment
# 102563  6075316                   Large 1Br Apt + Balcony in LES!
# 102578  6083601                Sunny & Spacious near Central Park
#
#             host id host_identity_verified host name neighbourhood group  \
# 1       52335172823               verified     Jenna           Manhattan
# ...

# %%
#22. Show all listings that are either in “Los Angeles” or “San Francisco”.
#data["neighbourhood"].unique()

# %%
#23. Retrieve listings whose number_of_reviews is greater than 50.
data[data["number of reviews"]>50]
# Out:
#              id                                       NAME      host id  \
# 3       1002755                                        NaN  85098326012
# 5       1004098  Large Cozy 1 BR Apartment In Midtown East  45498551794
# 8       1005754            Large Furnished Room Near B'way  79384379533
# 9       1006307         Cozy Clean Guest Room - Family Apt  75527839483
# 10      1006859         Cute & Cozy Lower East Side 1 bdrm   1280143094
# ...         ...                                        ...          ...
# 102579  6084153            Alexander's 2BR Luxury Quarters  32736284559
# 102580  6084705        Near LGA, Citifield, US Open Tennis  97606085736
# 102584  6086914         2 block walk from the beach in NYC  70051719594
# 102587  6088571          Adorable One-Bed in Williamsburg!  20914678851
# 102588  6089124   Loft Space for Events, Meetings & Shoots  85557432222
#
#        host_identity_verified host name neighbourhood group  \
# ...

# %%
#24. Show all listings whose room_type is not “Private room”.
data["room type"].unique()
# Out:
# array(['Private room', 'Entire home/apt', 'Shared room', 'Hotel room'],
#       dtype=object)

# %%
data[data["room type"]=="Private room"]
# Out:
#              id                                 NAME      host id  \
# 0       1001254   Clean & quiet apt home by the park  80014485718
# 2       1002403  THE VILLAGE OF HARLEM....NEW YORK !  78829239556
# 6       1004650                      BlissArtsSpace!  61300605564
# 7       1005202                      BlissArtsSpace!  90821839709
# 8       1005754      Large Furnished Room Near B'way  79384379533
# ...         ...                                  ...          ...
# 102589  6089676  Lrg room 1 block from Prospect Park  74549151787
# 102593  6091885  Welcoming, Clean, Cheap on St Marks  33188605074
# 102594  6092437           Spare room in Williamsburg  12312296767
# 102595  6092990        Best Location near Columbia U  77864383453
# 102596  6093542       Comfy, bright room in Brooklyn  69050334417
#
#        host_identity_verified host name neighbourhood group  \
# 0                 unconfirmed  Madaline            Brooklyn
# ...

# %%
#25. Get listings where host_name starts with the letter “A”.
data[data["host name"].str[0]=="A"]
# Out:
#              id                                             NAME      host id  \
# 6       1004650                                  BlissArtsSpace!  61300605564
# 11      1007411                 Beautiful 1br on Upper West Side  18824631834
# 18      1011277                                  Chelsea Perfect  73862528370
# 20      1012382                Huge 2 BR Upper East  Cental Park  79805143117
# 21      1012934                 Sweet and Spacious Brooklyn Loft  86554611512
# ...         ...                                              ...          ...
# 102508  6044940                 3BR Gramercy Apt in heart of NYC  59749079462
# 102521  6052120               Must Love Dogs / Bushwick Brooklyn  22301937174
# 102522  6052672              Sunny studio in the Upper East Side  16962195392
# 102573  6080839  2BR apt. in converted church with large terrace  38845651458
# 102581  6085258     Bright Bedroom in Bustling Bed Stuy Brooklyn  17339949163
#
# ...

# %%
#26. Retrieve listings whose name ends with “Suite”.
data[data["host name"].str.contains("Suite",case=False,na=False)]
# Out:
#              id                                               NAME  \
# 8195    5527435                 Cozy Room in Super Convenient Area
# 8232    5547870    Private Room Right by Subway to Manhattan *alt*
# 13702   8568951       The Mahogany Suite(Private Studio Apartment)
# 18078  10985815          The Mahogany Suite- The Solo Adventurer l
# 18240  11075288  Middle Size Room Super Convenient Area: ♥of Bklyn
# 18575  11260309          The Mahogany Suite-The Solo Adventurer-ll
# 37489  21706511                    Comfortable- JFK,LGA Best Value
# 37703  21824703    Clean , Safe, Cozy 3min to JFK , LGA Best Value
# 39687  22920466                          The Den -  3 mins  to JFK
# 53941  30792950  Private Queen Suite | Kitchenette | Gym | near...
# 54222  30948147  Hotel Style Suite w Kitchenette+Balcony | near...
# 54591  31151945  Spacious Suite,2 King Beds+ Kitchenette | near...
# 55199  31487744  Modern Queen Suite | close to NYC | Parking | Gym
# ...

# %%
data[data["host name"].str.endswith("Suite",na=False)]
# Out:
#              id                                               NAME  \
# 8195    5527435                 Cozy Room in Super Convenient Area
# 8232    5547870    Private Room Right by Subway to Manhattan *alt*
# 18240  11075288  Middle Size Room Super Convenient Area: ♥of Bklyn
# 37489  21706511                    Comfortable- JFK,LGA Best Value
# 37703  21824703    Clean , Safe, Cozy 3min to JFK , LGA Best Value
# 39687  22920466                          The Den -  3 mins  to JFK
# 88062  49637979  Middle Size Room Super Convenient Area: ♥of Bklyn
#
#            host id host_identity_verified                       host name  \
# 8195   48083055178               verified        Sho-Boo Of Sho-Boo Suite
# 8232   97894790174            unconfirmed        Sho-Boo Of Sho-Boo Suite
# 18240  29929137262            unconfirmed        Sho-Boo Of Sho-Boo Suite
# 37489  48992030362               verified  Shared Stay-JFK The Hugh Suite
# ...

# %%
#27. Select listings that have both price &gt; 150 and availability_365 &gt; 200.
data[(data["price"]>150) & (data["availability 365"]>200)]
# Out:
#              id                                              NAME  \
# 0       1001254                Clean & quiet apt home by the park
# 2       1002403               THE VILLAGE OF HARLEM....NEW YORK !
# 3       1002755                                               NaN
# 4       1003689  Entire Apt: Spacious Studio/Loft by central park
# 5       1004098         Large Cozy 1 BR Apartment In Midtown East
# ...         ...                                               ...
# 102590  6090228               Wonderful artists' loft in Brooklyn
# 102594  6092437                        Spare room in Williamsburg
# 102595  6092990                     Best Location near Columbia U
# 102596  6093542                    Comfy, bright room in Brooklyn
# 102597  6094094                  Big Studio-One Stop from Midtown
#
#             host id host_identity_verified    host name neighbourhood group  \
# 0       80014485718            unconfirmed     Madaline            Brooklyn
# ...

# %%
#28. Filter listings where neighbourhood_group equals “Manhattan” and room_type equals “Entire home/apt”.
data["neighbourhood group"].unique()
# Out:
# array(['Brooklyn', 'Manhattan', 'brookln', 'manhatan', 'Queens', nan,
#        'Staten Island', 'Bronx'], dtype=object)

# %%
data["room type"].unique()
# Out:
# array(['Private room', 'Entire home/apt', 'Shared room', 'Hotel room'],
#       dtype=object)

# %%
data[(data['room type']=="Entire home/apt") & (data['neighbourhood group']=='Manhattan')]
# Out:
#              id                                              NAME  \
# 1       1002102                             Skylit Midtown Castle
# 4       1003689  Entire Apt: Spacious Studio/Loft by central park
# 5       1004098         Large Cozy 1 BR Apartment In Midtown East
# 10      1006859                Cute & Cozy Lower East Side 1 bdrm
# 11      1007411                  Beautiful 1br on Upper West Side
# ...         ...                                               ...
# 102586  6088019                    Patio Oasis in Upper East Side
# 102588  6089124          Loft Space for Events, Meetings & Shoots
# 102591  6090781                Columbus Ave Apt 1 block from Park
# 102592  6091333               3BR/1 Ba in TriBeCa w/ outdoor deck
# 102598  6094647                              585 sf Luxury Studio
#
#             host id host_identity_verified host name neighbourhood group  \
# 1       52335172823               verified     Jenna           Manhattan
# ...

# %%
#29. Show all listings that were last reviewed in the year 2022.
data[data["last review"].str.endswith("2022",na=False)]
# Out:
#              id                                              NAME  \
# 1       1002102                             Skylit Midtown Castle
# 103     1058223                          Monkey Retreat Manhattan
# 189     1105721                  LARGE, COMFY 1BDR W/CHARACTER!!!
# 230     1128365                 Nice, clean, safe, convenient 3BR
# 316     1175863     Luxury 3 bed/ 2 bath apt in Harlem w/ terrace
# ...         ...                                               ...
# 69193  39216630         Cozy BX Home Away From Home ( 2 nd floor)
# 69275  39261919                    Large Room w/ Private Entrance
# 69309  39280697  Rent in beautiful Sunnyside Gardens for holidays
# 69365  39311626                   Enjoy a 1 Bedroom to share, NYC
# 69381  39320462                Cozy, Hella Sunny, and Convenient!
#
#            host id host_identity_verified  host name neighbourhood group  \
# 1      52335172823               verified      Jenna           Manhattan
# ...

# %%
#30. Display all listings where the name column contains “Downtown”.
data[data["NAME"].str.contains("Downtown",case=False,na=False)]
# Out:
#               id                                               NAME  \
# 41       1023980                                ENJOY Downtown NYC!
# 274      1152666                               ENJOY Downtown NYC!!
# 345      1191880        MODERN SPACIOUS 2 BR APT DOWNTOWN MANHATTAN
# 459      1254842                Surfer room 15mins to downtown NYC!
# 487      1270306   Very close to Downtown Awesome Private Apartment
# ...          ...                                                ...
# 102129  35546044  The Residences at W New York - Downtown - Apt 27D
# 102162  35564270     20-25 minutes to downtown NYC/30-40 to midtown
# 102426  20384857                     Charming 3bed/2ba Downtown/LES
# 102429  20386514    Huge Room for Nightly Stays Downtown or Monthly
# 102561   6074212  NO FEE RENTAL *Lease Takeover Modern Apt Downtown
#
#             host id host_identity_verified  host name neighbourhood group  \
# 41      63131487263            unconfirmed      Byron           Manhattan
# ...

# %%
#31. Retrieve listings where reviews_per_month is greater than 2.
data[data["reviews per month"]>2]
# Out:
#              id                                             NAME      host id  \
# 3       1002755                                              NaN  85098326012
# 8       1005754                  Large Furnished Room Near B'way  79384379533
# 18      1011277                                  Chelsea Perfect  73862528370
# 19      1011830  Hip Historic Brownstone Apartment with Backyard  72145018858
# 31      1018457                            front room/double bed  69410526955
# ...         ...                                              ...          ...
# 102569  6078630          Elegant 1BR, Private Bath in Brownstone  37385825013
# 102575  6081944              NYC Chauncey 2 .20 min to manhattan  26326930315
# 102579  6084153                  Alexander's 2BR Luxury Quarters  32736284559
# 102580  6084705              Near LGA, Citifield, US Open Tennis  97606085736
# 102588  6089124         Loft Space for Events, Meetings & Shoots  85557432222
#
# ...

# %%
#32. Select listings where host_id appears more than once.
host_count=data["host id"].value_counts()

# %%
list_host=host_count[host_count>1].index

# %%
data[data["host id"].isin(list_host)]
# Out:
#              id                                               NAME  \
# 9098    6026161     Upper East Side 2 bedroom- close to Hospitals-
# 9099    6026714  Close to East Side Hospitals- Modern 2 Bedroom...
# 9100    6027266  ACADIA Spacious 2 Bedroom Apt - Close to Hospi...
# 9101    6027818    *ENCHANTMENT* Upper East Side 2 bedroom- Sunny!
# 9102    6028371        *JAMES* Amazing Spacious 2 Bedroom- Bright!
# ...         ...                                                ...
# 102594  6092437                         Spare room in Williamsburg
# 102595  6092990                      Best Location near Columbia U
# 102596  6093542                     Comfy, bright room in Brooklyn
# 102597  6094094                   Big Studio-One Stop from Midtown
# 102598  6094647                               585 sf Luxury Studio
#
#             host id host_identity_verified    host name neighbourhood group  \
# 9098    65193709566               verified      Juliana           Manhattan
# ...

# %%
#33. Filter all listings not located in “Brooklyn”.
data[~data["NAME"].str.contains("Brooklyn",case=False,na=False)]
# Out:
#              id                                              NAME  \
# 0       1001254                Clean & quiet apt home by the park
# 1       1002102                             Skylit Midtown Castle
# 2       1002403               THE VILLAGE OF HARLEM....NEW YORK !
# 3       1002755                                               NaN
# 4       1003689  Entire Apt: Spacious Studio/Loft by central park
# ...         ...                                               ...
# 102593  6091885               Welcoming, Clean, Cheap on St Marks
# 102594  6092437                        Spare room in Williamsburg
# 102595  6092990                     Best Location near Columbia U
# 102597  6094094                  Big Studio-One Stop from Midtown
# 102598  6094647                              585 sf Luxury Studio
#
#             host id host_identity_verified    host name neighbourhood group  \
# 0       80014485718            unconfirmed     Madaline            Brooklyn
# ...

# %%
#34. Retrieve listings where city column contains “York”.

# %%
#35. Get all listings that have a price greater than the average price.
avg_p=data["price"].mean()

# %%
data[data["price"]>avg_p]
# Out:
#              id                                 NAME      host id  \
# 0       1001254   Clean & quiet apt home by the park  80014485718
# 7       1005202                      BlissArtsSpace!  90821839709
# 8       1005754      Large Furnished Room Near B'way  79384379533
# 12      1007964      Central Manhattan/near Broadway  88136055909
# 16      1010173     Only 2 stops to Manhattan studio  62566345680
# ...         ...                                  ...          ...
# 102593  6091885  Welcoming, Clean, Cheap on St Marks  33188605074
# 102594  6092437           Spare room in Williamsburg  12312296767
# 102595  6092990        Best Location near Columbia U  77864383453
# 102596  6093542       Comfy, bright room in Brooklyn  69050334417
# 102598  6094647                 585 sf Luxury Studio  68170633372
#
#        host_identity_verified host name neighbourhood group  \
# 0                 unconfirmed  Madaline            Brooklyn
# ...

# %%
#36. Display listings with minimum_nights exactly equal to 7.
data[data["minimum nights"]==7]
# Out:
#              id                                               NAME  \
# 20      1012382                  Huge 2 BR Upper East  Cental Park
# 43      1025085                  1bdr w private bath. in lofty apt
# 45      1026190                                 BEST BET IN HARLEM
# 65      1037236  Double Room w Private Deck Clinton Hill Best Area
# 73      1041654                        Cool Room in Hell's Kitchen
# ...         ...                                                ...
# 102545  6065375                         Loft rental off of Graham!
# 102553  6069793                   Custom Designed Cozy Garden Apt,
# 102555  6070898                      Sublet entire apt in Brooklyn
# 102568  6078078                Furnished Bedroom in 2 Bedroom apt.
# 102582  6085810                Private room in the best part of BK
#
#             host id host_identity_verified     host name neighbourhood group  \
# 20      79805143117               verified        Audrey           Manhattan
# ...

# %%
#37. Select listings with an even number of minimum_nights.
data[data["minimum nights"] %2==0]
# Out:
#              id                                              NAME  \
# 0       1001254                Clean & quiet apt home by the park
# 1       1002102                             Skylit Midtown Castle
# 3       1002755                                               NaN
# 4       1003689  Entire Apt: Spacious Studio/Loft by central park
# 8       1005754                   Large Furnished Room Near B'way
# ...         ...                                               ...
# 102577  6083048               Gigantic Private Brooklyn Apartment
# 102581  6085258      Bright Bedroom in Bustling Bed Stuy Brooklyn
# 102584  6086914                2 block walk from the beach in NYC
# 102586  6088019                    Patio Oasis in Upper East Side
# 102597  6094094                  Big Studio-One Stop from Midtown
#
#             host id host_identity_verified    host name neighbourhood group  \
# 0       80014485718            unconfirmed     Madaline            Brooklyn
# ...

# %%
#38. Retrieve all listings whose host name length is more than 10 characters.
data[data["host name"].str.len()>10]
# Out:
#              id                                           NAME      host id  \
# 1073    1593954                                 Serene Room...  49750343850
# 1091    1603895            Cozy private room, williamsburg NYC  71939962014
# 1100    1608866  Sunny plant-filled apartment with 2 balconies  81188620051
# 1102    1609971                            Bright, Bedstuy Gem  14399757070
# 1113    1616046             Gorgeous Summer Duplex/Yard sublet   9729014487
# ...         ...                                            ...          ...
# 102518  6050463   Beautiful apartment in awesome Clinton Hill!  18401849962
# 102553  6069793               Custom Designed Cozy Garden Apt,   7756381071
# 102555  6070898                  Sublet entire apt in Brooklyn  83573592009
# 102569  6078630        Elegant 1BR, Private Bath in Brownstone  37385825013
# 102597  6094094               Big Studio-One Stop from Midtown  11160591270
#
# ...

# %%
#39. Filter listings where price is a multiple of 50.
data[data["price"]%50==0]
# Out:
#               id                                             NAME  \
# 23       1014039                         CBG Helps Haiti Room#2.5
# 107      1060432                Large 2 Bedroom Great for Groups!
# 165      1092466  Charming & Cozy midtown loft any WEEK ENDS  !!!
# 183      1102407               Couldn't Be Closer To Columbia Uni
# 278      1154875                CHARMING EAST VILLAGE 2 (or 1) BR
# ...          ...                                              ...
# 102320  20326313      Spacious room in awesome Bushwick townhouse
# 102394  20367183          Sonder | Madison Ave | Modern 1BR + Gym
# 102414  20378229     Morningside Heights Cozy & Clean Modern Apt.
# 102503   6042178              Perfect for Cat, Book, Park Lovers!
# 102590   6090228              Wonderful artists' loft in Brooklyn
#
#             host id host_identity_verified  host name neighbourhood group  \
# 23      87668933180                    NaN    William            Brooklyn
# ...

# %%
#40. Show listings with names having more than 3 words.
def length(x):
    sp=x.split(" ")
    if len(sp)>3:
        return x
    else:
        return "N"

# %%
data["new"]=data["NAME"].astype("str").apply(length)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102599 entries, 0 to 102598
# Data columns (total 27 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   id                              102599 non-null  int64
#  1   NAME                            102349 non-null  object
#  2   host id                         102599 non-null  int64
#  3   host_identity_verified          102310 non-null  object
#  4   host name                       102193 non-null  object
#  5   neighbourhood group             102570 non-null  object
#  6   neighbourhood                   102583 non-null  object
#  7   lat                             102591 non-null  float64
#  8   long                            102591 non-null  float64
#  9   country                         102067 non-null  object
#  10  country code                    102468 non-null  object
#  11  instant_bookable                102494 non-null  object
# ...

# %%
data
# Out:
#              id                                              NAME  \
# 0       1001254                Clean & quiet apt home by the park
# 1       1002102                             Skylit Midtown Castle
# 2       1002403               THE VILLAGE OF HARLEM....NEW YORK !
# 3       1002755                                               NaN
# 4       1003689  Entire Apt: Spacious Studio/Loft by central park
# ...         ...                                               ...
# 102594  6092437                        Spare room in Williamsburg
# 102595  6092990                     Best Location near Columbia U
# 102596  6093542                    Comfy, bright room in Brooklyn
# 102597  6094094                  Big Studio-One Stop from Midtown
# 102598  6094647                              585 sf Luxury Studio
#
#             host id host_identity_verified    host name neighbourhood group  \
# 0       80014485718            unconfirmed     Madaline            Brooklyn
# ...

# %%
data[data["new"]!="N"]
# Out:
#              id                                              NAME  \
# 0       1001254                Clean & quiet apt home by the park
# 2       1002403               THE VILLAGE OF HARLEM....NEW YORK !
# 4       1003689  Entire Apt: Spacious Studio/Loft by central park
# 5       1004098         Large Cozy 1 BR Apartment In Midtown East
# 8       1005754                   Large Furnished Room Near B'way
# ...         ...                                               ...
# 102594  6092437                        Spare room in Williamsburg
# 102595  6092990                     Best Location near Columbia U
# 102596  6093542                    Comfy, bright room in Brooklyn
# 102597  6094094                  Big Studio-One Stop from Midtown
# 102598  6094647                              585 sf Luxury Studio
#
#             host id host_identity_verified    host name neighbourhood group  \
# 0       80014485718            unconfirmed     Madaline            Brooklyn
# ...

# %%
#41. Rename the column neighbourhood_group to region.
data.rename(columns={"neighbourhood group":"region"})
# Out:
#              id                                              NAME  \
# 0       1001254                Clean & quiet apt home by the park
# 1       1002102                             Skylit Midtown Castle
# 2       1002403               THE VILLAGE OF HARLEM....NEW YORK !
# 3       1002755                                               NaN
# 4       1003689  Entire Apt: Spacious Studio/Loft by central park
# ...         ...                                               ...
# 102594  6092437                        Spare room in Williamsburg
# 102595  6092990                     Best Location near Columbia U
# 102596  6093542                    Comfy, bright room in Brooklyn
# 102597  6094094                  Big Studio-One Stop from Midtown
# 102598  6094647                              585 sf Luxury Studio
#
#             host id host_identity_verified    host name     region  \
# 0       80014485718            unconfirmed     Madaline   Brooklyn
# ...

# %%
#42. Add a new column price_per_review = price / number_of_reviews.
data["price_per_review"]=data["price"]/data["number of reviews"]

# %%
data
# Out:
#              id                                              NAME  \
# 0       1001254                Clean & quiet apt home by the park
# 1       1002102                             Skylit Midtown Castle
# 2       1002403               THE VILLAGE OF HARLEM....NEW YORK !
# 3       1002755                                               NaN
# 4       1003689  Entire Apt: Spacious Studio/Loft by central park
# ...         ...                                               ...
# 102594  6092437                        Spare room in Williamsburg
# 102595  6092990                     Best Location near Columbia U
# 102596  6093542                    Comfy, bright room in Brooklyn
# 102597  6094094                  Big Studio-One Stop from Midtown
# 102598  6094647                              585 sf Luxury Studio
#
#             host id host_identity_verified    host name neighbourhood group  \
# 0       80014485718            unconfirmed     Madaline            Brooklyn
# ...

# %%
#43. Create a column price_category as “Low”, “Medium”, or “High” based on price ranges.
avg_p
# Out:
# np.float64(625.2935360325152)

# %%
def price(x):
    if x<avg_p:
        return "Low"
    elif x>avg_p:
        return "High"
    else:
        return "Medium"

# %%
data["price_category"]=data["price"].apply(price)

# %%
data
# Out:
#              id                                              NAME  \
# 0       1001254                Clean & quiet apt home by the park
# 1       1002102                             Skylit Midtown Castle
# 2       1002403               THE VILLAGE OF HARLEM....NEW YORK !
# 3       1002755                                               NaN
# 4       1003689  Entire Apt: Spacious Studio/Loft by central park
# ...         ...                                               ...
# 102594  6092437                        Spare room in Williamsburg
# 102595  6092990                     Best Location near Columbia U
# 102596  6093542                    Comfy, bright room in Brooklyn
# 102597  6094094                  Big Studio-One Stop from Midtown
# 102598  6094647                              585 sf Luxury Studio
#
#             host id host_identity_verified    host name neighbourhood group  \
# 0       80014485718            unconfirmed     Madaline            Brooklyn
# ...

# %%
#44. Add a column showing the length of each listing’s name.
data["name_len"]=data["NAME"].astype('str').apply(lambda x:len(x))

# %%
data
# Out:
#              id                                              NAME  \
# 0       1001254                Clean & quiet apt home by the park
# 1       1002102                             Skylit Midtown Castle
# 2       1002403               THE VILLAGE OF HARLEM....NEW YORK !
# 3       1002755                                               NaN
# 4       1003689  Entire Apt: Spacious Studio/Loft by central park
# ...         ...                                               ...
# 102594  6092437                        Spare room in Williamsburg
# 102595  6092990                     Best Location near Columbia U
# 102596  6093542                    Comfy, bright room in Brooklyn
# 102597  6094094                  Big Studio-One Stop from Midtown
# 102598  6094647                              585 sf Luxury Studio
#
#             host id host_identity_verified    host name neighbourhood group  \
# 0       80014485718            unconfirmed     Madaline            Brooklyn
# ...

# %%
#45. Combine city and neighbourhood into a new column full_location.

# %%
def year(x):
    sp=x.split("/")
    return sp[-1]

# %%
#46. Extract the year from last_review into a new column review_year.
data["review_year"]=data["last review"].astype("str").apply(year)

# %%
data
# Out:
#              id                                              NAME  \
# 0       1001254                Clean & quiet apt home by the park
# 1       1002102                             Skylit Midtown Castle
# 2       1002403               THE VILLAGE OF HARLEM....NEW YORK !
# 3       1002755                                               NaN
# 4       1003689  Entire Apt: Spacious Studio/Loft by central park
# ...         ...                                               ...
# 102594  6092437                        Spare room in Williamsburg
# 102595  6092990                     Best Location near Columbia U
# 102596  6093542                    Comfy, bright room in Brooklyn
# 102597  6094094                  Big Studio-One Stop from Midtown
# 102598  6094647                              585 sf Luxury Studio
#
#             host id host_identity_verified    host name neighbourhood group  \
# 0       80014485718            unconfirmed     Madaline            Brooklyn
# ...

# %%
#47. Round all values in the reviews_per_month column to 2 decimal places.
data["reviews per month"]=data["reviews per month"].round(2)

# %%
#48. Replace all spaces in column names with underscores.
data.columns.str.replace(" ","_")
# Out:
# Index(['id', 'NAME', 'host_id', 'host_identity_verified', 'host_name',
#        'neighbourhood_group', 'neighbourhood', 'lat', 'long', 'country',
#        'country_code', 'instant_bookable', 'cancellation_policy', 'room_type',
#        'Construction_year', 'price', 'service_fee', 'minimum_nights',
#        'number_of_reviews', 'last_review', 'reviews_per_month',
#        'review_rate_number', 'calculated_host_listings_count',
#        'availability_365', 'house_rules', 'license', 'new', 'price_per_review',
#        'price_category', 'name_len', 'review_year'],
#       dtype='object')

# %%
#49. Create a column is_available that is True if availability_365 &gt; 0, else False.
data["is_available"]=data["availability 365"].apply(lambda x:True if x>0 else False)

# %%
data
# Out:
#              id                                              NAME  \
# 0       1001254                Clean & quiet apt home by the park
# 1       1002102                             Skylit Midtown Castle
# 2       1002403               THE VILLAGE OF HARLEM....NEW YORK !
# 3       1002755                                               NaN
# 4       1003689  Entire Apt: Spacious Studio/Loft by central park
# ...         ...                                               ...
# 102594  6092437                        Spare room in Williamsburg
# 102595  6092990                     Best Location near Columbia U
# 102596  6093542                    Comfy, bright room in Brooklyn
# 102597  6094094                  Big Studio-One Stop from Midtown
# 102598  6094647                              585 sf Luxury Studio
#
#             host id host_identity_verified    host name neighbourhood group  \
# 0       80014485718            unconfirmed     Madaline            Brooklyn
# ...

# %%
#50. Change all text in room_type to uppercase.
data["room type"]=data["room type"].str.upper()

# %%
data
# Out:
#              id                                              NAME  \
# 0       1001254                Clean & quiet apt home by the park
# 1       1002102                             Skylit Midtown Castle
# 2       1002403               THE VILLAGE OF HARLEM....NEW YORK !
# 3       1002755                                               NaN
# 4       1003689  Entire Apt: Spacious Studio/Loft by central park
# ...         ...                                               ...
# 102594  6092437                        Spare room in Williamsburg
# 102595  6092990                     Best Location near Columbia U
# 102596  6093542                    Comfy, bright room in Brooklyn
# 102597  6094094                  Big Studio-One Stop from Midtown
# 102598  6094647                              585 sf Luxury Studio
#
#             host id host_identity_verified    host name neighbourhood group  \
# 0       80014485718            unconfirmed     Madaline            Brooklyn
# ...

# %%
#51. Create a column price_in_inr assuming 1 USD = 83 INR.
data["price_in_inr"]=data["price"]*83

# %%
data
# Out:
#              id                                              NAME  \
# 0       1001254                Clean & quiet apt home by the park
# 1       1002102                             Skylit Midtown Castle
# 2       1002403               THE VILLAGE OF HARLEM....NEW YORK !
# 3       1002755                                               NaN
# 4       1003689  Entire Apt: Spacious Studio/Loft by central park
# ...         ...                                               ...
# 102594  6092437                        Spare room in Williamsburg
# 102595  6092990                     Best Location near Columbia U
# 102596  6093542                    Comfy, bright room in Brooklyn
# 102597  6094094                  Big Studio-One Stop from Midtown
# 102598  6094647                              585 sf Luxury Studio
#
#             host id host_identity_verified    host name neighbourhood group  \
# 0       80014485718            unconfirmed     Madaline            Brooklyn
# ...

# %%
#52. Reorder columns so that price comes first.
price_column=data.pop("price")
data.insert(0,"price",price_column)

# %%
data
# Out:
#          price       id                                              NAME  \
# 0        966.0  1001254                Clean & quiet apt home by the park
# 1        142.0  1002102                             Skylit Midtown Castle
# 2        620.0  1002403               THE VILLAGE OF HARLEM....NEW YORK !
# 3        368.0  1002755                                               NaN
# 4        204.0  1003689  Entire Apt: Spacious Studio/Loft by central park
# ...        ...      ...                                               ...
# 102594   844.0  6092437                        Spare room in Williamsburg
# 102595   837.0  6092990                     Best Location near Columbia U
# 102596   988.0  6093542                    Comfy, bright room in Brooklyn
# 102597   546.0  6094094                  Big Studio-One Stop from Midtown
# 102598  1032.0  6094647                              585 sf Luxury Studio
#
#             host id host_identity_verified    host name neighbourhood group  \
# ...

# %%
#53. Drop the id column from the dataset.
data.drop("id",axis=1)
# Out:
#          price                                              NAME      host id  \
# 0        966.0                Clean & quiet apt home by the park  80014485718
# 1        142.0                             Skylit Midtown Castle  52335172823
# 2        620.0               THE VILLAGE OF HARLEM....NEW YORK !  78829239556
# 3        368.0                                               NaN  85098326012
# 4        204.0  Entire Apt: Spacious Studio/Loft by central park  92037596077
# ...        ...                                               ...          ...
# 102594   844.0                        Spare room in Williamsburg  12312296767
# 102595   837.0                     Best Location near Columbia U  77864383453
# 102596   988.0                    Comfy, bright room in Brooklyn  69050334417
# 102597   546.0                  Big Studio-One Stop from Midtown  11160591270
# 102598  1032.0                              585 sf Luxury Studio  68170633372
#
# ...

# %%
#54. Change the data type of price to integer.
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102599 entries, 0 to 102598
# Data columns (total 33 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   price                           102352 non-null  float64
#  1   id                              102599 non-null  int64
#  2   NAME                            102349 non-null  object
#  3   host id                         102599 non-null  int64
#  4   host_identity_verified          102310 non-null  object
#  5   host name                       102193 non-null  object
#  6   neighbourhood group             102570 non-null  object
#  7   neighbourhood                   102583 non-null  object
#  8   lat                             102591 non-null  float64
#  9   long                            102591 non-null  float64
#  10  country                         102067 non-null  object
#  11  country code                    102468 non-null  object
# ...

# %%
import numpy as np

# %%
data["price"]=data["price"].replace([np.inf,-np.inf],0)

# %%
data["price"]=data["price"].astype("Int64")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102599 entries, 0 to 102598
# Data columns (total 33 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   price                           102352 non-null  Int64
#  1   id                              102599 non-null  int64
#  2   NAME                            102349 non-null  object
#  3   host id                         102599 non-null  int64
#  4   host_identity_verified          102310 non-null  object
#  5   host name                       102193 non-null  object
#  6   neighbourhood group             102570 non-null  object
#  7   neighbourhood                   102583 non-null  object
#  8   lat                             102591 non-null  float64
#  9   long                            102591 non-null  float64
#  10  country                         102067 non-null  object
#  11  country code                    102468 non-null  object
# ...

# %%
#55. Create a new column showing price per night: price / minimum_nights.
data["price_per_night"]=data["price"]/data["minimum nights"]

# %%
data
# Out:
#         price       id                                              NAME  \
# 0         966  1001254                Clean & quiet apt home by the park
# 1         142  1002102                             Skylit Midtown Castle
# 2         620  1002403               THE VILLAGE OF HARLEM....NEW YORK !
# 3         368  1002755                                               NaN
# 4         204  1003689  Entire Apt: Spacious Studio/Loft by central park
# ...       ...      ...                                               ...
# 102594    844  6092437                        Spare room in Williamsburg
# 102595    837  6092990                     Best Location near Columbia U
# 102596    988  6093542                    Comfy, bright room in Brooklyn
# 102597    546  6094094                  Big Studio-One Stop from Midtown
# 102598   1032  6094647                              585 sf Luxury Studio
#
#             host id host_identity_verified    host name neighbourhood group  \
# ...

# %%
#56. Add a Boolean column indicating if the name contains the word “Luxury”.
data["bool"]=data["NAME"].str.contains("Luxury",case=False,na=False)

# %%
data
# Out:
#         price       id                                              NAME  \
# 0         966  1001254                Clean & quiet apt home by the park
# 1         142  1002102                             Skylit Midtown Castle
# 2         620  1002403               THE VILLAGE OF HARLEM....NEW YORK !
# 3         368  1002755                                               NaN
# 4         204  1003689  Entire Apt: Spacious Studio/Loft by central park
# ...       ...      ...                                               ...
# 102594    844  6092437                        Spare room in Williamsburg
# 102595    837  6092990                     Best Location near Columbia U
# 102596    988  6093542                    Comfy, bright room in Brooklyn
# 102597    546  6094094                  Big Studio-One Stop from Midtown
# 102598   1032  6094647                              585 sf Luxury Studio
#
#             host id host_identity_verified    host name neighbourhood group  \
# ...

# %%
#57. Create a column for total estimated revenue = price * number_of_reviews.
data["total_est_revenue"]=data["price"]*data["number of reviews"]

# %%
data.columns
# Out:
# Index(['price', 'id', 'NAME', 'host id', 'host_identity_verified', 'host name',
#        'neighbourhood group', 'neighbourhood', 'lat', 'long', 'country',
#        'country code', 'instant_bookable', 'cancellation_policy', 'room type',
#        'Construction year', 'service fee', 'minimum nights',
#        'number of reviews', 'last review', 'reviews per month',
#        'review rate number', 'calculated host listings count',
#        'availability 365', 'house_rules', 'license', 'new', 'price_per_review',
#        'price_category', 'name_len', 'review_year', 'is_available',
#        'price_in_inr', 'price_per_night', 'bool', 'total_est_revenue'],
#       dtype='object')

# %%
#58. Replace “Entire home/apt” with “Whole Apartment” in the room_type column.
data['room type'].unique()
# Out:
# array(['PRIVATE ROOM', 'ENTIRE HOME/APT', 'SHARED ROOM', 'HOTEL ROOM'],
#       dtype=object)

# %%
data["room type"].replace('ENTIRE HOME/APT',"Whole Apartment",inplace=True)
# Out:
# C:\Users\rames\AppData\Local\Temp\ipykernel_1208\3381271164.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data["room type"].replace('ENTIRE HOME/APT',"Whole Apartment",inplace=True)

# %%
#59. Change all city names to lowercase.

# %%
#60. Split the listing name into two columns: first word and remaining words.

# %%
list1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102599 entries, 0 to 102598
# Data columns (total 2 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   index   102599 non-null  int64
#  1   NAME    102349 non-null  object
# dtypes: int64(1), object(1)
# memory usage: 1.6+ MB

# %%
split=data["NAME"].str.split(" ",n=1,expand=True)

# %%
split
# Out:
#              0                                          1
# 0        Clean               & quiet apt home by the park
# 1       Skylit                             Midtown Castle
# 2          THE            VILLAGE OF HARLEM....NEW YORK !
# 3          NaN                                        NaN
# 4       Entire  Apt: Spacious Studio/Loft by central park
# ...        ...                                        ...
# 102594   Spare                       room in Williamsburg
# 102595    Best                   Location near Columbia U
# 102596  Comfy,                    bright room in Brooklyn
# 102597     Big               Studio-One Stop from Midtown
# 102598     585                           sf Luxury Studio
#
# [102599 rows x 2 columns]

# %%
data["first_word"]=split[0]

# %%
data["second_column"]=split[1]

# %%
data
# Out:
#         price       id                                              NAME  \
# 0         966  1001254                Clean & quiet apt home by the park
# 1         142  1002102                             Skylit Midtown Castle
# 2         620  1002403               THE VILLAGE OF HARLEM....NEW YORK !
# 3         368  1002755                                               NaN
# 4         204  1003689  Entire Apt: Spacious Studio/Loft by central park
# ...       ...      ...                                               ...
# 102594    844  6092437                        Spare room in Williamsburg
# 102595    837  6092990                     Best Location near Columbia U
# 102596    988  6093542                    Comfy, bright room in Brooklyn
# 102597    546  6094094                  Big Studio-One Stop from Midtown
# 102598   1032  6094647                              585 sf Luxury Studio
#
#             host id host_identity_verified    host name neighbourhood group  \
# ...

# %%
#61.  Find the average price for each room_type.
data.groupby("room type")["price"].mean()
# Out:
# room type
# HOTEL ROOM         668.465517
# PRIVATE ROOM       625.007363
# SHARED ROOM        634.132101
# Whole Apartment    625.082232
# Name: price, dtype: Float64

# %%
#62.  Find the total number of listings per neighbourhood_group.
data.groupby("neighbourhood group")["id"].count()
# Out:
# neighbourhood group
# Bronx             2712
# Brooklyn         41842
# Manhattan        43792
# Queens           13267
# Staten Island      955
# brookln              1
# manhatan             1
# Name: id, dtype: int64

# %%
#63.  Compute the maximum and minimum price for each city.

# %%
#64.  Find which host has the maximum number of listings.
data.groupby('host name')['id'].count().idxmax()
# Out:
# 'Michael'

# %%
#65.  Calculate the mean availability_365 for each room_type.
data.groupby('room type')['availability 365'].mean()
# Out:
# room type
# HOTEL ROOM         218.310345
# PRIVATE ROOM       137.557126
# SHARED ROOM        172.666214
# Whole Apartment    142.760376
# Name: availability 365, dtype: float64

# %%
#66.  Get the count of unique host names per city.

# %%
data.columns
# Out:
# Index(['price', 'id', 'NAME', 'host id', 'host_identity_verified', 'host name',
#        'neighbourhood group', 'neighbourhood', 'lat', 'long', 'country',
#        'country code', 'instant_bookable', 'cancellation_policy', 'room type',
#        'Construction year', 'service fee', 'minimum nights',
#        'number of reviews', 'last review', 'reviews per month',
#        'review rate number', 'calculated host listings count',
#        'availability 365', 'house_rules', 'license', 'new', 'price_per_review',
#        'price_category', 'name_len', 'review_year', 'is_available',
#        'price_in_inr', 'price_per_night', 'bool', 'total_est_revenue',
#        'first_word', 'second_column'],
#       dtype='object')

# %%
data["neighbourhood"].unique()
# Out:
# array(['Kensington', 'Midtown', 'Harlem', 'Clinton Hill', 'East Harlem',
#        'Murray Hill', 'Bedford-Stuyvesant', "Hell's Kitchen",
#        'Upper West Side', 'Chinatown', 'South Slope', 'West Village',
#        'Williamsburg', 'Fort Greene', 'Chelsea', 'Crown Heights',
#        'Park Slope', 'Windsor Terrace', 'Inwood', 'East Village',
#        'Greenpoint', 'Bushwick', 'Flatbush', 'Lower East Side',
#        'Prospect-Lefferts Gardens', 'Long Island City', 'Kips Bay',
#        'SoHo', 'Upper East Side', 'Prospect Heights',
#        'Washington Heights', 'Woodside', 'Brooklyn Heights',
#        'Carroll Gardens', 'Gowanus', 'Flatlands', 'Cobble Hill',
#        'Flushing', 'Boerum Hill', 'Sunnyside', 'DUMBO', 'St. George',
#        'Highbridge', 'Financial District', 'Ridgewood',
#        'Morningside Heights', 'Jamaica', 'Middle Village', 'NoHo',
#        'Ditmars Steinway', 'Flatiron District', 'Roosevelt Island',
# ...

# %%
data[data["neighbourhood"]=="New York"]
# Out:
# Empty DataFrame
# Columns: [price, id, NAME, host id, host_identity_verified, host name, neighbourhood group, neighbourhood, lat, long, country, country code, instant_bookable, cancellation_policy, room type, Construction year, service fee, minimum nights, number of reviews, last review, reviews per month, review rate number, calculated host listings count, availability 365, house_rules, license, new, price_per_review, price_category, name_len, review_year, is_available, price_in_inr, price_per_night, bool, total_est_revenue, first_word, second_column]
# Index: []
#
# [0 rows x 38 columns]

# %%
#67.  For each city, find the average number of reviews.
data.groupby('neighbourhood')['number of reviews'].mean()
# Out:
# neighbourhood
# Allerton           56.618557
# Arden Heights      15.555556
# Arrochar           25.346154
# Arverne            34.098655
# Astoria            26.816239
#                      ...
# Windsor Terrace    35.118541
# Woodhaven          38.468750
# Woodlawn           50.275862
# Woodrow             7.000000
# Woodside           21.692967
# Name: number of reviews, Length: 224, dtype: float64

# %%
#68.  Identify the city with the highest average price.
data.groupby('neighbourhood')["price"].mean().idxmax()
# Out:
# 'New Dorp'

# %%
#69.  Find the total revenue per host (price × number_of_reviews).
data.groupby('host name')["total_est_revenue"].sum()
# Out:
# host name
# #NAME?                       85596.0
# 'Cil                        198581.0
# (Ari) HENRY LEE               7074.0
# (Email hidden by Airbnb)     16197.0
# (Mary) Haiy                 349680.0
#                               ...
# 단비                               0.0
# 빈나                            1836.0
# 소정                             836.0
# 진                                0.0
# 현선                               0.0
# Name: total_est_revenue, Length: 13190, dtype: Float64

# %%
#70.  Group listings by region and show their average price.
data.groupby('new')['price'].mean()
# Out:
# new
#  Private 1 bdrm Lefferts Gr, BK apt                    325.0
# ! ! ! Coliving: live, work, create                      88.0
# !! CLASSIC, LUXURY & CHARM !! By Central Park UWS      985.5
# !!! Beautiful private room with backyard.              780.0
# !!! Outpost Coliving . Shared twin room                864.0
#                                                        ...
# 🥰Lovely 1 bedroom/5 minutes walk to timessquare       1152.0
# 🧑🏼‍✈️Private Room LGA ✈️                               122.0
# 🪁LARGE PRIVATE TERRACE 🚶‍♂️8 MIN WALK TO MAIN ST       666.0
# 🪴XL dojo 🌾 shared green yogi palace apt 🌿               64.0
# 🪴🛋🌞 Unique sunny clean brownstone studio 1st floor     583.0
# Name: price, Length: 55715, dtype: Float64

# %%
data.columns
# Out:
# Index(['price', 'id', 'NAME', 'host id', 'host_identity_verified', 'host name',
#        'neighbourhood group', 'neighbourhood', 'lat', 'long', 'country',
#        'country code', 'instant_bookable', 'cancellation_policy', 'room type',
#        'Construction year', 'service fee', 'minimum nights',
#        'number of reviews', 'last review', 'reviews per month',
#        'review rate number', 'calculated host listings count',
#        'availability 365', 'house_rules', 'license', 'new', 'price_per_review',
#        'price_category', 'name_len', 'review_year', 'is_available',
#        'price_in_inr', 'price_per_night', 'bool', 'total_est_revenue',
#        'first_word', 'second_column'],
#       dtype='object')

# %%
#71.  Count how many listings exist for each minimum_nights value.
data.groupby('minimum nights')['id'].count()
# Out:
# minimum nights
# -1223.0    1
# -365.0     1
# -200.0     1
# -125.0     1
# -12.0      1
#           ..
#  1000.0    2
#  1250.0    1
#  2645.0    1
#  3455.0    1
#  5645.0    1
# Name: id, Length: 153, dtype: int64

# %%
#72.  Group by room_type and get the total number_of_reviews.
data.groupby("room type")["number of reviews"].sum()
# Out:
# room type
# HOTEL ROOM            9679.0
# PRIVATE ROOM       1291669.0
# SHARED ROOM          45368.0
# Whole Apartment    1468059.0
# Name: number of reviews, dtype: float64

# %%
#73.  Find the top 5 hosts with the highest average price.
host_avg=data.groupby('host name')["price"].mean().reset_index()

# %%
host_avg
# Out:
#                       host name       price
# 0                        #NAME?       378.0
# 1                          'Cil       569.0
# 2               (Ari) HENRY LEE      1179.0
# 3      (Email hidden by Airbnb)       343.0
# 4                   (Mary) Haiy       465.0
# ...                         ...         ...
# 13185                        단비       822.0
# 13186                        빈나       918.0
# 13187                        소정  665.333333
# 13188                         진       992.0
# 13189                        현선       703.0
#
# [13190 rows x 2 columns]

# %%
host_avg.sort_values(by="price",ascending=False).head()
# Out:
#       host name   price
# 9966       Rema  1200.0
# 5446  Jeff & TJ  1200.0
# 917     Antonin  1200.0
# 3563      Esaie  1200.0
# 4897      Ilean  1200.0

# %%
#74.  For each neighbourhood_group, find the listing with maximum price.
data.groupby('neighbourhood group')["price"].max()
# Out:
# neighbourhood group
# Bronx            1200
# Brooklyn         1200
# Manhattan        1200
# Queens           1200
# Staten Island    1200
# brookln           580
# manhatan          460
# Name: price, dtype: Int64

# %%
#75.  Group listings by both city and room_type, and compute average price.
data.groupby(["neighbourhood",'room type'])['price'].mean()
# Out:
# neighbourhood  room type
# Allerton       PRIVATE ROOM       709.269231
#                Whole Apartment    550.159091
# Arden Heights  PRIVATE ROOM            604.0
#                Whole Apartment    862.285714
# Arrochar       PRIVATE ROOM          594.625
#                                      ...
# Woodlawn       Whole Apartment         510.8
# Woodrow        Whole Apartment    709.333333
# Woodside       PRIVATE ROOM       638.981567
#                SHARED ROOM             644.5
#                Whole Apartment    621.482993
# Name: price, Length: 574, dtype: Float64

# %%
#76.  Get the standard deviation of price for each room_type.
data.groupby('room type')["price"].std()
# Out:
# room type
# HOTEL ROOM         310.866487
# PRIVATE ROOM       331.332129
# SHARED ROOM        338.701626
# Whole Apartment    331.713213
# Name: price, dtype: Float64

# %%
#77.  Find how many listings were reviewed in each year.
data.groupby('review_year')["number of reviews"].sum()
# Out:
# review_year
# 2012         66.0
# 2013        347.0
# 2014       1310.0
# 2015       7647.0
# 2016      23107.0
# 2017      51597.0
# 2018     130250.0
# 2019    1806152.0
# 2020      81125.0
# 2021     169716.0
# 2022     540721.0
# 2024         21.0
# 2025         41.0
# 2026          1.0
# 2040         41.0
# 2058        124.0
# nan        2509.0
# Name: number of reviews, dtype: float64

# %%
#78.  Group listings by region and count how many have price &gt; 100.
price=data[data['price']>100]

# %%
price.groupby('new')['price'].count()
# Out:
# new
#  Private 1 bdrm Lefferts Gr, BK apt                   2
# !! CLASSIC, LUXURY & CHARM !! By Central Park UWS     2
# !!! Beautiful private room with backyard.             4
# !!! Outpost Coliving . Shared twin room               4
# !!!Co-Housing taken to the Next Level /Flatbush/2     4
#                                                      ..
# 😸Cirilo's G. Nice Private Room🪴🐈‍⬛                    1
# 🥰Lovely 1 bedroom/5 minutes walk to timessquare       1
# 🧑🏼‍✈️Private Room LGA ✈️                              1
# 🪁LARGE PRIVATE TERRACE 🚶‍♂️8 MIN WALK TO MAIN ST      1
# 🪴🛋🌞 Unique sunny clean brownstone studio 1st floor    1
# Name: price, Length: 53398, dtype: Int64

# %%
#79.  Identify which region has the most total reviews.
data.groupby("new")["number of reviews"].sum().idxmax()
# Out:
# 'N'

# %%
#80.  For each host_id, calculate the total availability days.
data.groupby('host id')['availability 365'].sum()
# Out:
# host id
# 123600518        0.0
# 124039648        0.0
# 124472619        0.0
# 129756565      348.0
# 130349612      205.0
#                ...
# 98758136270    117.0
# 98760968631      0.0
# 98762661810     71.0
# 98762683230     17.0
# 98763129024      0.0
# Name: availability 365, Length: 102057, dtype: float64

# %%
#81.  Split the dataset into two DataFrames: one with price, one with reviews, then merge them back on id.
d1=data[['id','price']]
d2=data[['id','number of reviews']]

# %%
merge_d=pd.merge(d1,d2,left_on='id',right_on='id',how='inner')

# %%
merge_d
# Out:
#              id  price  number of reviews
# 0       1001254    966                9.0
# 1       1002102    142               45.0
# 2       1002403    620                0.0
# 3       1002755    368              270.0
# 4       1003689    204                9.0
# ...         ...    ...                ...
# 103676  6093542    988                0.0
# 103677  6094094    546                5.0
# 103678  6094094    546                5.0
# 103679  6094647   1032                0.0
# 103680  6094647   1032                0.0
#
# [103681 rows x 3 columns]

# %%
#82.  Create a pivot table showing average price by city and room_type.
data.pivot_table(index="neighbourhood",values="price",columns="room type",aggfunc=np.mean)
# Out:
# C:\Users\rames\AppData\Local\Temp\ipykernel_1208\3889929656.py:2: FutureWarning: The provided callable <function mean at 0x000001FE21953A60> is currently using DataFrameGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   data.pivot_table(index="neighbourhood",values="price",columns="room type",aggfunc=np.mean)
# room type        HOTEL ROOM  PRIVATE ROOM  SHARED ROOM  Whole Apartment
# neighbourhood
# Allerton               <NA>    709.269231         <NA>       550.159091
# Arden Heights          <NA>         604.0         <NA>       862.285714
# Arrochar               <NA>       594.625         <NA>       653.444444
# Arverne                <NA>    653.959459       988.25       641.917241
# Astoria                <NA>    656.797932   652.130435       613.408673
# ...                     ...           ...          ...              ...
# ...

# %%
#83.  Unstack a groupby result of room_type vs neighbourhood_group.
data.pivot_table(index="neighbourhood group",columns="room type",aggfunc='size',fill_value=0)
# Out:
# room type            HOTEL ROOM  PRIVATE ROOM  SHARED ROOM  Whole Apartment
# neighbourhood group
# Bronx                         0          1573          117             1022
# Brooklyn                      8         20434          825            20575
# Manhattan                   100         16312          907            26473
# Queens                        8          7751          362             5146
# Staten Island                 0           466           15              474
# brookln                       0             1            0                0
# manhatan                      0             1            0                0

# %%
#84.  Melt columns related to reviews into a long format.
data.melt(id_vars=['id'],value_vars=['number of reviews','last review','reviews per month','review rate number','price_per_review','review_year'],var_name="review_number",value_name="review_content")
# Out:
#              id      review_number review_content
# 0       1001254  number of reviews            9.0
# 1       1002102  number of reviews           45.0
# 2       1002403  number of reviews            0.0
# 3       1002755  number of reviews          270.0
# 4       1003689  number of reviews            9.0
# ...         ...                ...            ...
# 615589  6092437        review_year            nan
# 615590  6092990        review_year           2015
# 615591  6093542        review_year            nan
# 615592  6094094        review_year           2015
# 615593  6094647        review_year            nan
#
# [615594 rows x 3 columns]

# %%
data
# Out:
#         price       id                                              NAME  \
# 0         966  1001254                Clean & quiet apt home by the park
# 1         142  1002102                             Skylit Midtown Castle
# 2         620  1002403               THE VILLAGE OF HARLEM....NEW YORK !
# 3         368  1002755                                               NaN
# 4         204  1003689  Entire Apt: Spacious Studio/Loft by central park
# ...       ...      ...                                               ...
# 102594    844  6092437                        Spare room in Williamsburg
# 102595    837  6092990                     Best Location near Columbia U
# 102596    988  6093542                    Comfy, bright room in Brooklyn
# 102597    546  6094094                  Big Studio-One Stop from Midtown
# 102598   1032  6094647                              585 sf Luxury Studio
#
#             host id host_identity_verified    host name neighbourhood group  \
# ...

# %%
data.columns
# Out:
# Index(['price', 'id', 'NAME', 'host id', 'host_identity_verified', 'host name',
#        'neighbourhood group', 'neighbourhood', 'lat', 'long', 'country',
#        'country code', 'instant_bookable', 'cancellation_policy', 'room type',
#        'Construction year', 'service fee', 'minimum nights',
#        'number of reviews', 'last review', 'reviews per month',
#        'review rate number', 'calculated host listings count',
#        'availability 365', 'house_rules', 'license', 'new', 'price_per_review',
#        'price_category', 'name_len', 'review_year', 'is_available',
#        'price_in_inr', 'price_per_night', 'bool', 'total_est_revenue',
#        'first_word', 'second_column'],
#       dtype='object')

# %%
#85.  Concatenate two subsets of listings (top 10 expensive + top 10 cheapest).
price_g=data.sort_values(by="price",ascending=False)

# %%
g1=price_g.head(10)

# %%
g2=price_g.tail(10)

# %%
pd.concat([g1,g2])
# Out:
#         price        id                                               NAME  \
# 20343    1200  12236775                   Lovely apartment in Williamsburg
# 64304    1200  36516435                Great 1BD waterfront City Island NY
# 67200    1200  38115896                         Bright Brooklyn Brownstone
# 33902    1200  19725411                                           Oasis II
# 7453     1200   5117628  Sun-filled bedroom in East Village / Gramercy NYC
# 90165    1200  50799466                   Lovely apartment in Williamsburg
# 52744    1200  30131847  ❤️Couples Retreat/A Road Warriors Dream🌟Perf Loc.
# 19773    1200  11921964           1.5 BATHRM SUNNY SPACIOUS ROOM BY SUBWAY
# 5207     1200   3877162      Bushwick Room w/ Private Entrance & Bathroom!
# 42446    1200  24444262            Cozy room in bright, spacious apartment
# 97775    <NA>  55002469      Studio at Upper East Side Manhattan, New York
# ...

# %%
#86.  Merge two DataFrames: one with host info, one with listing info (based on host_id).
d1=data[['host id','host name','host_identity_verified']]
d2=data[['host id','room type','country']]

# %%
pd.merge(d1,d2,left_on="host id",right_on='host id',how='inner')
# Out:
#             host id    host name host_identity_verified        room type  \
# 0       80014485718     Madaline            unconfirmed     PRIVATE ROOM
# 1       52335172823        Jenna               verified  Whole Apartment
# 2       78829239556        Elise                    NaN     PRIVATE ROOM
# 3       85098326012        Garry            unconfirmed  Whole Apartment
# 4       92037596077       Lyndon               verified  Whole Apartment
# ...             ...          ...                    ...              ...
# 103678  69050334417        Megan            unconfirmed     PRIVATE ROOM
# 103679  11160591270  Christopher            unconfirmed  Whole Apartment
# 103680  11160591270  Christopher            unconfirmed  Whole Apartment
# 103681  68170633372      Rebecca            unconfirmed  Whole Apartment
# 103682  68170633372      Rebecca            unconfirmed  Whole Apartment
#
#               country
# 0       United States
# 1       United States
# ...

# %%
#87.  Create a MultiIndex DataFrame grouped by city and region.
index=data.set_index(['new','neighbourhood'])

# %%
index.sort_index()
# Out:
#                                                                               price  \
# new                                                neighbourhood
#  Private 1 bdrm Lefferts Gr, BK apt                Prospect-Lefferts Gardens    325
#                                                    Prospect-Lefferts Gardens    325
# ! ! ! Coliving: live, work, create                 East Flatbush                 88
#                                                    East Flatbush                 88
#                                                    East Flatbush                 88
# ...                                                                             ...
# 🥰Lovely 1 bedroom/5 minutes walk to timessquare    Upper East Side             1152
# 🧑🏼‍✈️Private Room LGA ✈️                           East Elmhurst                122
# 🪁LARGE PRIVATE TERRACE 🚶‍♂️8 MIN WALK TO MAIN ST   Flushing                     666
# ...

# %%
#88.  Sort index after grouping by multiple columns.
index1=data.set_index(['new','neighbourhood','host name'])
index1.sort_index()
# Out:
#                                                                                          price  \
# new                                                neighbourhood             host name
#  Private 1 bdrm Lefferts Gr, BK apt                Prospect-Lefferts Gardens Rachael       325
#                                                                              Rachael       325
# ! ! ! Coliving: live, work, create                 East Flatbush             Valentin       88
#                                                                              Valentin       88
#                                                                              Valentin       88
# ...                                                                                        ...
# 🥰Lovely 1 bedroom/5 minutes walk to timessquare    Upper East Side           Madison      1152
# 🧑🏼‍✈️Private Room LGA ✈️                           East Elmhurst             Joe Jobana    122
# ...

# %%
#89.  Pivot table showing count of listings per room_type across cities.
data.pivot_table(index="neighbourhood",columns="room type",values='id',aggfunc='count',fill_value=0)
# Out:
# room type        HOTEL ROOM  PRIVATE ROOM  SHARED ROOM  Whole Apartment
# neighbourhood
# Allerton                  0            53            0               44
# Arden Heights             0             2            0                7
# Arrochar                  0            24            0               28
# Arverne                   0            74            4              145
# Astoria                   0          1067           46              763
# ...                     ...           ...          ...              ...
# Windsor Terrace           0            96            0              235
# Woodhaven                 0           132            5               55
# Woodlawn                  0            17            2               10
# Woodrow                   0             0            0                3
# Woodside                  0           438            2              148
#
# [224 rows x 4 columns]

# %%
#90.  Reshape the dataset so each host has one row with average metrics per city.
data.groupby(['host name','neighbourhood'])['price'].mean()
# Out:
# host name                 neighbourhood
# #NAME?                    Queens Village              378.0
# 'Cil                      Astoria                     569.0
# (Ari) HENRY LEE           East Harlem                1179.0
# (Email hidden by Airbnb)  Clinton Hill                168.0
#                           Midtown                492.333333
#                                                     ...
# 빈나                        Stuyvesant Town             918.0
# 소정                        Bedford-Stuyvesant          418.0
#                           Hell's Kitchen             1160.0
# 진                         Upper West Side             992.0
# 현선                        Morningside Heights         703.0
# Name: price, Length: 34412, dtype: Float64
