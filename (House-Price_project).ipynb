# %%
import pandas as pd

# %%
data=pd.read_csv('House_data.csv')

# %%
data
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07
# ...

# %%
data.columns
# Out:
# Index(['area_type', 'availability', 'location', 'size', 'society',
#        'total_sqft', 'bath', 'balcony', 'price'],
#       dtype='object')

# %%
#1. Display all rows where the price is greater than 1 crore.
data[data["price"]>1]
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07
# ...

# %%
#2. Retrieve all properties located in the area “Whitefield”.
data[data["location"]=='Whitefield']
# Out:
#                   area_type   availability    location       size  society  \
# 5      Super built-up  Area  Ready To Move  Whitefield      2 BHK  DuenaTa
# 10     Super built-up  Area         18-Feb  Whitefield      3 BHK      NaN
# 11               Plot  Area  Ready To Move  Whitefield  4 Bedroom  Prrry M
# 27           Built-up  Area         20-Dec  Whitefield      3 BHK      NaN
# 47     Super built-up  Area         20-Sep  Whitefield      2 BHK  Goted U
# ...                     ...            ...         ...        ...      ...
# 13235  Super built-up  Area  Ready To Move  Whitefield      3 BHK  SJces R
# 13257  Super built-up  Area  Ready To Move  Whitefield      3 BHK  SLiritn
# 13258  Super built-up  Area         19-Dec  Whitefield      1 BHK  Oreldhi
# 13299  Super built-up  Area         18-Dec  Whitefield      4 BHK  Prtates
# 13315        Built-up  Area  Ready To Move  Whitefield  5 Bedroom  ArsiaEx
#
#         total_sqft  bath  balcony   price
# ...

# %%
#3.Show houses that have more than 3 bedrooms.
bed=data["size"].str.split(" ",n=1,expand=True)

# %%
data['bedroom']=bed[0]

# %%
data
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price bedroom
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07       2
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13320 entries, 0 to 13319
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   area_type     13320 non-null  object
#  1   availability  13320 non-null  object
#  2   location      13319 non-null  object
#  3   size          13304 non-null  object
#  4   society       7818 non-null   object
#  5   total_sqft    13320 non-null  object
#  6   bath          13247 non-null  float64
#  7   balcony       12711 non-null  float64
#  8   price         13320 non-null  float64
#  9   bedroom       13304 non-null  object
# dtypes: float64(3), object(7)
# memory usage: 1.0+ MB

# %%
data['bedroom']=data['bedroom'].astype('Int64')

# %%
data[data['bedroom']>3]
# Out:
#                   area_type   availability               location       size  \
# 1                Plot  Area  Ready To Move       Chikka Tirupathi  4 Bedroom
# 6      Super built-up  Area         18-May       Old Airport Road      4 BHK
# 7      Super built-up  Area  Ready To Move           Rajaji Nagar      4 BHK
# 9                Plot  Area  Ready To Move           Gandhi Bazar  6 Bedroom
# 11               Plot  Area  Ready To Move             Whitefield  4 Bedroom
# ...                     ...            ...                    ...        ...
# 13306            Plot  Area  Ready To Move  Rajarajeshwari Nagara  4 Bedroom
# 13311            Plot  Area  Ready To Move       Ramamurthy Nagar  7 Bedroom
# 13315        Built-up  Area  Ready To Move             Whitefield  5 Bedroom
# 13316  Super built-up  Area  Ready To Move          Richards Town      4 BHK
# 13318  Super built-up  Area         18-Jun        Padmanabhanagar      4 BHK
#
# ...

# %%
#4. Select rows where bath is greater than balcony.
data[data['bath']>data['balcony']]
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# 5      Super built-up  Area  Ready To Move                Whitefield
# ...                     ...            ...                       ...
# 13311            Plot  Area  Ready To Move          Ramamurthy Nagar
# 13313  Super built-up  Area  Ready To Move               Uttarahalli
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
#
#             size  society total_sqft  bath  balcony   price  bedroom
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07        2
# ...

# %%
#5.Display all houses with total square feet greater than 2000.

# %%
data["total_sqft"].unique()
# Out:
# array(['1056', '2600', '1440', ..., '1133 - 1384', '774', '4689'],
#       dtype=object)

# %%
sp=data["total_sqft"].str.split("-",n=1,expand=True)

# %%
sp
# Out:
#           0     1
# 0      1056  None
# 1      2600  None
# 2      1440  None
# 3      1521  None
# 4      1200  None
# ...     ...   ...
# 13315  3453  None
# 13316  3600  None
# 13317  1141  None
# 13318  4689  None
# 13319   550  None
#
# [13320 rows x 2 columns]

# %%
sp[0].unique()
# Out:
# array(['1056', '2600', '1440', ..., '1133 ', '774', '4689'], dtype=object)

# %%
import re
def change_dt(x):
    #y=x.str()
    p="\d+"
    a=re.findall(p,x)
    return a[0]

# %%
sp[0]=sp[0].apply(change_dt)

# %%
sp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13320 entries, 0 to 13319
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       13320 non-null  object
#  1   1       201 non-null    object
# dtypes: object(2)
# memory usage: 208.3+ KB

# %%
sp[0].astype('float')
# Out:
# 0        1056.0
# 1        2600.0
# 2        1440.0
# 3        1521.0
# 4        1200.0
#           ...
# 13315    3453.0
# 13316    3600.0
# 13317    1141.0
# 13318    4689.0
# 13319     550.0
# Name: 0, Length: 13320, dtype: float64

# %%
data['total_sq']=sp[0]

# %%
data['total_sq']=data['total_sq'].astype('float')

# %%
data[data['total_sq']>2000]
# Out:
#                   area_type   availability          location       size  \
# 1                Plot  Area  Ready To Move  Chikka Tirupathi  4 Bedroom
# 6      Super built-up  Area         18-May  Old Airport Road      4 BHK
# 7      Super built-up  Area  Ready To Move      Rajaji Nagar      4 BHK
# 11               Plot  Area  Ready To Move        Whitefield  4 Bedroom
# 14               Plot  Area  Ready To Move          Sarjapur  3 Bedroom
# ...                     ...            ...               ...        ...
# 13294  Super built-up  Area  Ready To Move     Sultan Palaya      4 BHK
# 13299  Super built-up  Area         18-Dec        Whitefield      4 BHK
# 13315        Built-up  Area  Ready To Move        Whitefield  5 Bedroom
# 13316  Super built-up  Area  Ready To Move     Richards Town      4 BHK
# 13318  Super built-up  Area         18-Jun   Padmanabhanagar      4 BHK
#
#        society   total_sqft  bath  balcony  price  bedroom  total_sq
# ...

# %%
#6.Get all properties with more than 2 bathrooms and located in “Electronic City”.
data[(data["location"]=='Electronic City') & (data["bath"]>2)]
# Out:
#                   area_type   availability         location       size  \
# 245              Plot  Area  Ready To Move  Electronic City  3 Bedroom
# 378    Super built-up  Area  Ready To Move  Electronic City      3 BHK
# 522    Super built-up  Area         18-Apr  Electronic City      3 BHK
# 543    Super built-up  Area         18-Apr  Electronic City      3 BHK
# 1191         Built-up  Area  Ready To Move  Electronic City      3 BHK
# 1325             Plot  Area  Ready To Move  Electronic City  4 Bedroom
# 2089   Super built-up  Area         18-Jan  Electronic City      3 BHK
# 2111   Super built-up  Area         18-Dec  Electronic City      3 BHK
# 3020             Plot  Area         18-Dec  Electronic City  4 Bedroom
# 3131   Super built-up  Area         21-Dec  Electronic City      3 BHK
# 3149   Super built-up  Area  Ready To Move  Electronic City      3 BHK
# 3303   Super built-up  Area  Ready To Move  Electronic City      3 BHK
# ...

# %%
#6.Retrieve all listings whose location contains “Indiranagar”.
data["location"].str.contains("Indiranagar",case=True,na=False)
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 13315    False
# 13316    False
# 13317    False
# 13318    False
# 13319    False
# Name: location, Length: 13320, dtype: bool

# %%
#7.Filter properties where price_per_sqft is between 4000 and 7000.
data["price_per_sqft"]=(data["price"]*10000000)/data["total_sq"]

# %%
data
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price  bedroom  \
# ...

# %%
data[(data["price_per_sqft"]>4000) & (data["price_per_sqft"]<7000)]
# Out:
# Empty DataFrame
# Columns: [area_type, availability, location, size, society, total_sqft, bath, balcony, price, bedroom, total_sq, price_per_sqft]
# Index: []

# %%
#8.Show all rows where availability equals “Ready To Move”.
data[data["availability"]=="Ready To Move"]
# Out:
#                   area_type   availability               location       size  \
# 1                Plot  Area  Ready To Move       Chikka Tirupathi  4 Bedroom
# 2            Built-up  Area  Ready To Move            Uttarahalli      3 BHK
# 3      Super built-up  Area  Ready To Move     Lingadheeranahalli      3 BHK
# 4      Super built-up  Area  Ready To Move               Kothanur      2 BHK
# 5      Super built-up  Area  Ready To Move             Whitefield      2 BHK
# ...                     ...            ...                    ...        ...
# 13314  Super built-up  Area  Ready To Move      Green Glen Layout      3 BHK
# 13315        Built-up  Area  Ready To Move             Whitefield  5 Bedroom
# 13316  Super built-up  Area  Ready To Move          Richards Town      4 BHK
# 13317        Built-up  Area  Ready To Move  Raja Rajeshwari Nagar      2 BHK
# 13319  Super built-up  Area  Ready To Move           Doddathoguru      1 BHK
#
# ...

# %%
#9.Get listings that are available “Immediately”.
data["availability"].unique()
# Out:
# array(['19-Dec', 'Ready To Move', '18-May', '18-Feb', '18-Nov', '20-Dec',
#        '17-Oct', '21-Dec', '19-Sep', '20-Sep', '18-Mar', '20-Feb',
#        '18-Apr', '20-Aug', '18-Oct', '19-Mar', '17-Sep', '18-Dec',
#        '17-Aug', '19-Apr', '18-Jun', '22-Dec', '22-Jan', '18-Aug',
#        '19-Jan', '17-Jul', '18-Jul', '21-Jun', '20-May', '19-Aug',
#        '18-Sep', '17-May', '17-Jun', '21-May', '18-Jan', '20-Mar',
#        '17-Dec', '16-Mar', '19-Jun', '22-Jun', '19-Jul', '21-Feb',
#        'Immediate Possession', '19-May', '17-Nov', '20-Oct', '20-Jun',
#        '19-Feb', '21-Oct', '21-Jan', '17-Mar', '17-Apr', '22-May',
#        '19-Oct', '21-Jul', '21-Nov', '21-Mar', '16-Dec', '22-Mar',
#        '20-Jan', '21-Sep', '21-Aug', '14-Nov', '19-Nov', '15-Nov',
#        '16-Jul', '15-Jun', '17-Feb', '20-Nov', '20-Jul', '16-Sep',
#        '15-Oct', '15-Dec', '16-Oct', '22-Nov', '15-Aug', '17-Jan',
#        '16-Nov', '20-Apr', '16-Jan', '14-Jul'], dtype=object)

# %%
data[data["availability"]=="Immediate Possession"]
# Out:
#         area_type          availability        location size  society  \
# 579    Plot  Area  Immediate Possession  Sarjapur  Road  NaN  Asiss B
# 1775   Plot  Area  Immediate Possession        IVC Road  NaN  Orana N
# 2264   Plot  Area  Immediate Possession    Banashankari  NaN      NaN
# 2809   Plot  Area  Immediate Possession  Sarjapur  Road  NaN  AsdiaAr
# 2862   Plot  Area  Immediate Possession     Devanahalli  NaN  Ajleyor
# 5333   Plot  Area  Immediate Possession     Devanahalli  NaN  Emngs S
# 6423   Plot  Area  Immediate Possession      Whitefield  NaN  SRniaGa
# 6636   Plot  Area  Immediate Possession          Jigani  NaN  S2enste
# 6719   Plot  Area  Immediate Possession         Hoskote  NaN  SJowsn
# 7680   Plot  Area  Immediate Possession    Kasavanhalli  NaN      NaN
# 8306   Plot  Area  Immediate Possession          Anekal  NaN  Vaensnd
# 8565   Plot  Area  Immediate Possession      Carmelaram  NaN  Ocezes
# ...

# %%
#10.Display houses where the size column contains “4 BHK”.
data[data["size"]=="4 BHK"]
# Out:
#                   area_type   availability          location   size  society  \
# 6      Super built-up  Area         18-May  Old Airport Road  4 BHK  Jaades
# 7      Super built-up  Area  Ready To Move      Rajaji Nagar  4 BHK  Brway G
# 30     Super built-up  Area         19-Dec         Yelahanka  4 BHK  LedorSa
# 122    Super built-up  Area         18-Mar            Hebbal  4 BHK  SNontle
# 123          Built-up  Area  Ready To Move          Shampura  4 BHK      NaN
# ...                     ...            ...               ...    ...      ...
# 13293  Super built-up  Area  Ready To Move    Sarjapur  Road  4 BHK  Puallhi
# 13294  Super built-up  Area  Ready To Move     Sultan Palaya  4 BHK  RSntsAp
# 13299  Super built-up  Area         18-Dec        Whitefield  4 BHK  Prtates
# 13316  Super built-up  Area  Ready To Move     Richards Town  4 BHK      NaN
# 13318  Super built-up  Area         18-Jun   Padmanabhanagar  4 BHK  SollyCl
#
# ...

# %%
#11.Select properties where balcony equals zero.
data[data["balcony"]==0]
# Out:
#                   area_type   availability        location       size  \
# 24     Super built-up  Area         18-Nov     Thanisandra       1 RK
# 30     Super built-up  Area         19-Dec       Yelahanka      4 BHK
# 42     Super built-up  Area  Ready To Move     Ganga Nagar      1 BHK
# 43               Plot  Area  Ready To Move       Yelahanka  1 Bedroom
# 46     Super built-up  Area  Ready To Move    Doddathoguru      2 BHK
# ...                     ...            ...             ...        ...
# 13260        Built-up  Area  Ready To Move     Frazer Town      2 BHK
# 13265  Super built-up  Area         20-Sep           Hoodi      2 BHK
# 13291            Plot  Area         18-Jan  Weavers Colony  1 Bedroom
# 13299  Super built-up  Area         18-Dec      Whitefield      4 BHK
# 13315        Built-up  Area  Ready To Move      Whitefield  5 Bedroom
#
#        society   total_sqft  bath  balcony    price  bedroom  total_sq  \
# ...

# %%
#12.Filter rows where area_type is “Super built-up Area”.
data[data["area_type"]=='Super built-up  Area']
# Out:
#                   area_type   availability                  location   size  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II  2 BHK
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli  3 BHK
# 4      Super built-up  Area  Ready To Move                  Kothanur  2 BHK
# 5      Super built-up  Area  Ready To Move                Whitefield  2 BHK
# 6      Super built-up  Area         18-May          Old Airport Road  4 BHK
# ...                     ...            ...                       ...    ...
# 13313  Super built-up  Area  Ready To Move               Uttarahalli  3 BHK
# 13314  Super built-up  Area  Ready To Move         Green Glen Layout  3 BHK
# 13316  Super built-up  Area  Ready To Move             Richards Town  4 BHK
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar  4 BHK
# 13319  Super built-up  Area  Ready To Move              Doddathoguru  1 BHK
#
# ...

# %%
data["area_type"].unique()
# Out:
# array(['Super built-up  Area', 'Plot  Area', 'Built-up  Area',
#        'Carpet  Area'], dtype=object)

# %%
#13.Retrieve all properties where bath &gt; 3 and price &lt; 80.
data[(data['bath']>3) & (data["price"]<80)]
# Out:
#                   area_type   availability  \
# 222          Built-up  Area  Ready To Move
# 265          Built-up  Area  Ready To Move
# 308    Super built-up  Area  Ready To Move
# 603              Plot  Area  Ready To Move
# 617          Built-up  Area  Ready To Move
# ...                     ...            ...
# 13045            Plot  Area  Ready To Move
# 13146  Super built-up  Area  Ready To Move
# 13221            Plot  Area  Ready To Move
# 13275            Plot  Area  Ready To Move
# 13303            Plot  Area  Ready To Move
#
#                                            location       size  society  \
# 222    Lakshminarayanapura, Electronic City Phase 2      4 BHK      NaN
# 265                                        Attibele  4 Bedroom  Natic T
# 308                                           Begur      4 BHK  Prntsrt
# 603                                      Doddagubbi  3 Bedroom      NaN
# 617                                      R.T. Nagar  4 Bedroom      NaN
# ...

# %%
#14.Get listings where total_sqft column value is a number and greater than 1500.
df=data[data["total_sqft"].str.isnumeric()]

# %%
df['total_sqft'].unique()
# Out:
# array(['1056', '2600', '1440', ..., '2758', '774', '4689'], dtype=object)

# %%
df['total_sqft']=df['total_sqft'].astype('int')
# Out:
# C:\Users\rames\AppData\Local\Temp\ipykernel_16020\2476502196.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['total_sqft']=df['total_sqft'].astype('int')

# %%
df[df['total_sqft']>1500]
# Out:
#                   area_type   availability            location       size  \
# 1                Plot  Area  Ready To Move    Chikka Tirupathi  4 Bedroom
# 3      Super built-up  Area  Ready To Move  Lingadheeranahalli      3 BHK
# 6      Super built-up  Area         18-May    Old Airport Road      4 BHK
# 7      Super built-up  Area  Ready To Move        Rajaji Nagar      4 BHK
# 10     Super built-up  Area         18-Feb          Whitefield      3 BHK
# ...                     ...            ...                 ...        ...
# 13309  Super built-up  Area  Ready To Move        Yeshwanthpur      3 BHK
# 13314  Super built-up  Area  Ready To Move   Green Glen Layout      3 BHK
# 13315        Built-up  Area  Ready To Move          Whitefield  5 Bedroom
# 13316  Super built-up  Area  Ready To Move       Richards Town      4 BHK
# 13318  Super built-up  Area         18-Jun     Padmanabhanagar      4 BHK
#
#        society  total_sqft  bath  balcony   price  bedroom  total_sq  \
# ...

# %%
#15.Display houses in “Marathahalli” with a price_per_sqft &gt; 6000.
df[(df["location"]=='Marathahalli') & (df["price_per_sqft"]>6000)]
# Out:
#                   area_type   availability      location       size  society  \
# 8      Super built-up  Area  Ready To Move  Marathahalli      3 BHK      NaN
# 67     Super built-up  Area  Ready To Move  Marathahalli      2 BHK      NaN
# 189    Super built-up  Area  Ready To Move  Marathahalli      2 BHK  VRave E
# 194    Super built-up  Area  Ready To Move  Marathahalli      2 BHK  Aiitya
# 322              Plot  Area  Ready To Move  Marathahalli  2 Bedroom      NaN
# ...                     ...            ...           ...        ...      ...
# 12185  Super built-up  Area  Ready To Move  Marathahalli      2 BHK  Spsic C
# 12836  Super built-up  Area  Ready To Move  Marathahalli      2 BHK      NaN
# 12846  Super built-up  Area  Ready To Move  Marathahalli      3 BHK      NaN
# 12968        Built-up  Area  Ready To Move  Marathahalli      3 BHK      NaN
# 13255  Super built-up  Area         19-Dec  Marathahalli      2 BHK  PrensKe
#
# ...

# %%
df.drop(columns=["total_sq"],inplace=True)
# Out:
# C:\Users\rames\AppData\Local\Temp\ipykernel_16020\3311818651.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=["total_sq"],inplace=True)

# %%
#16.Retrieve all properties with 2 BHK or 3 BHK only.
df[(df['size']=="2 BHK") | (df["size"]=="3 BHK")]
# Out:
#                   area_type   availability                  location   size  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II  2 BHK
# 2            Built-up  Area  Ready To Move               Uttarahalli  3 BHK
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli  3 BHK
# 4      Super built-up  Area  Ready To Move                  Kothanur  2 BHK
# 5      Super built-up  Area  Ready To Move                Whitefield  2 BHK
# ...                     ...            ...                       ...    ...
# 13310  Super built-up  Area  Ready To Move              Rachenahalli  2 BHK
# 13312  Super built-up  Area  Ready To Move                 Bellandur  2 BHK
# 13313  Super built-up  Area  Ready To Move               Uttarahalli  3 BHK
# 13314  Super built-up  Area  Ready To Move         Green Glen Layout  3 BHK
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar  2 BHK
#
# ...

# %%
#17.Filter houses with an even number of bathrooms.
df[df['bath']%2==0]
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# 5      Super built-up  Area  Ready To Move                Whitefield
# 6      Super built-up  Area         18-May          Old Airport Road
# ...                     ...            ...                       ...
# 13312  Super built-up  Area  Ready To Move                 Bellandur
# 13313  Super built-up  Area  Ready To Move               Uttarahalli
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
#
#             size  society  total_sqft  bath  balcony   price  bedroom  \
# ...

# %%
#18.Display listings where the number of bathrooms is less than bedrooms.
df[df["bath"]<df["bedroom"]]
# Out:
#                   area_type   availability          location       size  \
# 2            Built-up  Area  Ready To Move       Uttarahalli      3 BHK
# 10     Super built-up  Area         18-Feb        Whitefield      3 BHK
# 26     Super built-up  Area  Ready To Move   Electronic City      2 BHK
# 29     Super built-up  Area  Ready To Move   Electronic City      3 BHK
# 31     Super built-up  Area  Ready To Move     Bisuvanahalli      3 BHK
# ...                     ...            ...               ...        ...
# 13290  Super built-up  Area  Ready To Move    Sarjapur  Road      4 BHK
# 13292  Super built-up  Area         18-Jul  Udayapur Village      3 BHK
# 13294  Super built-up  Area  Ready To Move     Sultan Palaya      4 BHK
# 13313  Super built-up  Area  Ready To Move       Uttarahalli      3 BHK
# 13315        Built-up  Area  Ready To Move        Whitefield  5 Bedroom
#
#        society  total_sqft  bath  balcony   price  bedroom  price_per_sqft
# ...

# %%
#19.Show rows where the location starts with “B”.
df[df["location"].str[0]=="B"]
# Out:
#                   area_type   availability           location   size  society  \
# 16     Super built-up  Area  Ready To Move      Bisuvanahalli  3 BHK  Prityel
# 21     Super built-up  Area         19-Dec         Binny Pete  3 BHK  She 2rk
# 23     Super built-up  Area  Ready To Move          Bellandur  3 BHK      NaN
# 31     Super built-up  Area  Ready To Move      Bisuvanahalli  3 BHK  Prityel
# 51     Super built-up  Area         18-Mar        Bhoganhalli  3 BHK  Rosha I
# ...                     ...            ...                ...    ...      ...
# 13274  Super built-up  Area  Ready To Move           Budigere  2 BHK  PrityTr
# 13284  Super built-up  Area  Ready To Move  Bannerghatta Road  2 BHK  SNity S
# 13307        Built-up  Area  Ready To Move       Billekahalli  3 BHK      NaN
# 13308        Built-up  Area  Ready To Move  Bannerghatta Road  3 BHK  Baanise
# 13312  Super built-up  Area  Ready To Move          Bellandur  2 BHK      NaN
#
# ...

# %%
#20.Select all rows where the location ends with “Layout”.
df[df['location'].notna() & df["location"].str.endswith("Layout")]
# Out:
#                   area_type   availability                   location  \
# 18     Super built-up  Area  Ready To Move      Ramakrishnappa Layout
# 45               Plot  Area  Ready To Move                 HSR Layout
# 57     Super built-up  Area  Ready To Move      Ramakrishnappa Layout
# 79           Built-up  Area  Ready To Move                ISRO Layout
# 80     Super built-up  Area  Ready To Move       Kodanda Reddy Layout
# ...                     ...            ...                        ...
# 13262        Built-up  Area  Ready To Move              Abshot Layout
# 13278        Built-up  Area  Ready To Move  Reliaable Tranquil Layout
# 13285  Super built-up  Area  Ready To Move               VHBCS Layout
# 13302  Super built-up  Area  Ready To Move       Annaiah Reddy Layout
# 13314  Super built-up  Area  Ready To Move          Green Glen Layout
#
#             size  society  total_sqft  bath  balcony  price  bedroom  \
# ...

# %%
#21.Retrieve properties where area_type is not “Plot Area”.
df[df["area_type"]!='Plot  Area']
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# 5      Super built-up  Area  Ready To Move                Whitefield
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society  total_sqft  bath  balcony   price  bedroom  \
# ...

# %%
#22.Display listings with price greater than the average price of the dataset.
avg_p=df['price'].mean()

# %%
df[df["price"]>avg_p]
# Out:
#                   area_type   availability           location       size  \
# 1                Plot  Area  Ready To Move   Chikka Tirupathi  4 Bedroom
# 6      Super built-up  Area         18-May   Old Airport Road      4 BHK
# 7      Super built-up  Area  Ready To Move       Rajaji Nagar      4 BHK
# 9                Plot  Area  Ready To Move       Gandhi Bazar  6 Bedroom
# 11               Plot  Area  Ready To Move         Whitefield  4 Bedroom
# ...                     ...            ...                ...        ...
# 13308        Built-up  Area  Ready To Move  Bannerghatta Road      3 BHK
# 13311            Plot  Area  Ready To Move   Ramamurthy Nagar  7 Bedroom
# 13315        Built-up  Area  Ready To Move         Whitefield  5 Bedroom
# 13316  Super built-up  Area  Ready To Move      Richards Town      4 BHK
# 13318  Super built-up  Area         18-Jun    Padmanabhanagar      4 BHK
#
#        society  total_sqft  bath  balcony  price  bedroom  price_per_sqft
# ...

# %%
#23.Get all rows where availability contains the word “Soon”.
df[df['availability'].str.contains("Soon",case=False,na=False)]
# Out:
# Empty DataFrame
# Columns: [area_type, availability, location, size, society, total_sqft, bath, balcony, price, bedroom, price_per_sqft]
# Index: []

# %%
df['availability'].unique()
# Out:
# array(['19-Dec', 'Ready To Move', '18-May', '18-Feb', '18-Nov', '20-Dec',
#        '17-Oct', '21-Dec', '20-Sep', '18-Mar', '18-Apr', '20-Aug',
#        '19-Mar', '17-Sep', '18-Dec', '17-Aug', '19-Apr', '18-Jun',
#        '22-Dec', '22-Jan', '18-Aug', '19-Jan', '17-Jul', '18-Jul',
#        '21-Jun', '20-May', '19-Aug', '18-Sep', '17-May', '17-Jun',
#        '18-Oct', '21-May', '18-Jan', '20-Mar', '17-Dec', '16-Mar',
#        '19-Jun', '22-Jun', '19-Jul', '21-Feb', '19-May', '17-Nov',
#        '20-Oct', '20-Jun', '19-Feb', '21-Oct', '21-Jan', '17-Mar',
#        '19-Sep', '17-Apr', '19-Oct', '21-Jul', '21-Nov', '21-Mar',
#        '16-Dec', '22-Mar', '20-Jan', '21-Sep', 'Immediate Possession',
#        '21-Aug', '14-Nov', '19-Nov', '15-Nov', '16-Jul', '15-Jun',
#        '17-Feb', '20-Nov', '20-Jul', '16-Sep', '15-Oct', '20-Feb',
#        '15-Dec', '16-Oct', '22-Nov', '15-Aug', '17-Jan', '16-Nov',
#        '20-Apr', '16-Jan', '14-Jul'], dtype=object)

# %%
#24.Filter houses that have “Penthouse” in their name (if present).
df['society'].unique()
# Out:
# array(['Coomee ', 'Theanmp', nan, ..., 'SJovest', 'ThhtsV ', 'RSntsAp'],
#       dtype=object)

# %%
df[df['society'].str.contains("Penthouse",case=False,na=False)]
# Out:
# Empty DataFrame
# Columns: [area_type, availability, location, size, society, total_sqft, bath, balcony, price, bedroom, price_per_sqft]
# Index: []

# %%
#25.Select properties where total_sqft value lies between 1000 and 2000.
df[(df["total_sqft"]>1000) & (df["total_sqft"]<2000)]
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# 5      Super built-up  Area  Ready To Move                Whitefield
# ...                     ...            ...                       ...
# 13311            Plot  Area  Ready To Move          Ramamurthy Nagar
# 13312  Super built-up  Area  Ready To Move                 Bellandur
# 13313  Super built-up  Area  Ready To Move               Uttarahalli
# 13314  Super built-up  Area  Ready To Move         Green Glen Layout
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
#
#             size  society  total_sqft  bath  balcony   price  bedroom  \
# ...

# %%
#26.Retrieve listings that have exactly 3 balconies.
df[df["balcony"]==3]
# Out:
#                   area_type   availability               location       size  \
# 1                Plot  Area  Ready To Move       Chikka Tirupathi  4 Bedroom
# 2            Built-up  Area  Ready To Move            Uttarahalli      3 BHK
# 11               Plot  Area  Ready To Move             Whitefield  4 Bedroom
# 17     Super built-up  Area  Ready To Move  Raja Rajeshwari Nagar      3 BHK
# 33     Super built-up  Area  Ready To Move  Raja Rajeshwari Nagar      3 BHK
# ...                     ...            ...                    ...        ...
# 13301  Super built-up  Area  Ready To Move               Kothanur      3 BHK
# 13303            Plot  Area  Ready To Move         Vidyaranyapura  5 Bedroom
# 13305          Carpet  Area  Ready To Move               Hulimavu      1 BHK
# 13307        Built-up  Area  Ready To Move           Billekahalli      3 BHK
# 13314  Super built-up  Area  Ready To Move      Green Glen Layout      3 BHK
#
# ...

# %%
#27.Display rows where size column has a missing bedroom count (e.g., “BHK” missing number).
df['size'].unique()
# Out:
# array(['2 BHK', '4 Bedroom', '3 BHK', '4 BHK', '6 Bedroom', '3 Bedroom',
#        '1 BHK', '1 RK', '1 Bedroom', '8 Bedroom', '2 Bedroom',
#        '7 Bedroom', '5 BHK', '7 BHK', '6 BHK', '5 Bedroom', '11 BHK',
#        '9 BHK', '9 Bedroom', '27 BHK', '10 Bedroom', '11 Bedroom', nan,
#        '10 BHK', '19 BHK', '16 BHK', '43 Bedroom', '14 BHK', '8 BHK',
#        '12 Bedroom', '13 BHK', '18 Bedroom'], dtype=object)

# %%
d1=df[~df['size'].str.contains("Bedroom",case=False,na=False)]

# %%
d2=d1[~d1['size'].str.contains("BHK",case=False,na=False)]

# %%
d2
# Out:
#                   area_type          availability                  location  \
# 24     Super built-up  Area                18-Nov               Thanisandra
# 782    Super built-up  Area         Ready To Move               Thanisandra
# 1363   Super built-up  Area                21-Nov               Thanisandra
# 2264             Plot  Area  Immediate Possession              Banashankari
# 2486   Super built-up  Area                19-Dec               Bhoganhalli
# 2557         Built-up  Area         Ready To Move                    Anekal
# 2788   Super built-up  Area                20-Aug              Rachenahalli
# 4876         Built-up  Area         Ready To Move           Electronic City
# 5079         Built-up  Area                17-Jun                Whitefield
# 6423             Plot  Area  Immediate Possession                Whitefield
# 6586   Super built-up  Area         Ready To Move  Electronics City Phase 1
# ...

# %%
#28.Filter properties where the ratio price / total_sqft &gt; 5.
df[(df["price"]/df["total_sqft"])>5]
# Out:
#            area_type   availability             location       size  society  \
# 349       Plot  Area         18-Dec   Suragajakkanahalli  3 Bedroom  PrhyaK
# 1122  Built-up  Area  Ready To Move  Grihalakshmi Layout  5 Bedroom      NaN
# 4086      Plot  Area  Ready To Move       Sarjapur  Road  4 Bedroom      NaN
# 4972  Built-up  Area  Ready To Move          Srirampuram      7 BHK      NaN
#
#       total_sqft  bath  balcony  price  bedroom  price_per_sqft
# 349           11   3.0      2.0   74.0        3    6.727273e+07
# 1122          24   2.0      2.0  150.0        5    6.250000e+07
# 4086           1   4.0      NaN  120.0        4    1.200000e+09
# 4972           5   7.0      3.0  115.0        7    2.300000e+08

# %%
#29.Get all properties in “BTM Layout” priced below 1 crore.
btm=df[df["location"]=='BTM Layout']

# %%
btm[btm["price"]<1]
# Out:
# Empty DataFrame
# Columns: [area_type, availability, location, size, society, total_sqft, bath, balcony, price, bedroom, price_per_sqft]
# Index: []

# %%
#30.Show all properties not located in “Electronic City”.
df[~df["location"].str.contains('Electronic City',case=False,na=False)]
# Out:
#                   area_type   availability               location       size  \
# 1                Plot  Area  Ready To Move       Chikka Tirupathi  4 Bedroom
# 2            Built-up  Area  Ready To Move            Uttarahalli      3 BHK
# 3      Super built-up  Area  Ready To Move     Lingadheeranahalli      3 BHK
# 4      Super built-up  Area  Ready To Move               Kothanur      2 BHK
# 5      Super built-up  Area  Ready To Move             Whitefield      2 BHK
# ...                     ...            ...                    ...        ...
# 13315        Built-up  Area  Ready To Move             Whitefield  5 Bedroom
# 13316  Super built-up  Area  Ready To Move          Richards Town      4 BHK
# 13317        Built-up  Area  Ready To Move  Raja Rajeshwari Nagar      2 BHK
# 13318  Super built-up  Area         18-Jun        Padmanabhanagar      4 BHK
# 13319  Super built-up  Area  Ready To Move           Doddathoguru      1 BHK
#
# ...

# %%
#31.Display rows where both bath and balcony are greater than or equal to 2.
df[(df['bath']>=2) & (df["balcony"]>=2)]
# Out:
#                   area_type   availability           location       size  \
# 1                Plot  Area  Ready To Move   Chikka Tirupathi  4 Bedroom
# 2            Built-up  Area  Ready To Move        Uttarahalli      3 BHK
# 10     Super built-up  Area         18-Feb         Whitefield      3 BHK
# 11               Plot  Area  Ready To Move         Whitefield  4 Bedroom
# 13           Built-up  Area  Ready To Move          Gottigere      2 BHK
# ...                     ...            ...                ...        ...
# 13307        Built-up  Area  Ready To Move       Billekahalli      3 BHK
# 13310  Super built-up  Area  Ready To Move       Rachenahalli      2 BHK
# 13311            Plot  Area  Ready To Move   Ramamurthy Nagar  7 Bedroom
# 13312  Super built-up  Area  Ready To Move          Bellandur      2 BHK
# 13314  Super built-up  Area  Ready To Move  Green Glen Layout      3 BHK
#
#        society  total_sqft  bath  balcony   price  bedroom  price_per_sqft
# ...

# %%
#32.Retrieve properties where total_sqft is greater than 3 times bath.
df[df["total_sqft"]>3*df['bath']]
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society  total_sqft  bath  balcony   price  bedroom  \
# ...

# %%
#33.Select properties whose location name has more than two words.
df["location"].str.split(" ")
# Out:
# 0        [Electronic, City, Phase, II]
# 1                  [Chikka, Tirupathi]
# 2                        [Uttarahalli]
# 3                 [Lingadheeranahalli]
# 4                           [Kothanur]
#                      ...
# 13315                     [Whitefield]
# 13316                 [Richards, Town]
# 13317        [Raja, Rajeshwari, Nagar]
# 13318                [Padmanabhanagar]
# 13319                   [Doddathoguru]
# Name: location, Length: 12986, dtype: object

# %%
#34.Create a new column price_in_lakhs = price * 100.
df["price_in_lakhs"]=df["price"]*100
# Out:
# C:\Users\rames\AppData\Local\Temp\ipykernel_16020\3654456425.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["price_in_lakhs"]=df["price"]*100

# %%
df
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society  total_sqft  bath  balcony   price  bedroom  \
# ...

# %%
#35.Add a new column bedroom_count extracted from the size column.
df['size'].unique()
# Out:
# array(['2 BHK', '4 Bedroom', '3 BHK', '4 BHK', '6 Bedroom', '3 Bedroom',
#        '1 BHK', '1 RK', '1 Bedroom', '8 Bedroom', '2 Bedroom',
#        '7 Bedroom', '5 BHK', '7 BHK', '6 BHK', '5 Bedroom', '11 BHK',
#        '9 BHK', '9 Bedroom', '27 BHK', '10 Bedroom', '11 Bedroom', nan,
#        '10 BHK', '19 BHK', '16 BHK', '43 Bedroom', '14 BHK', '8 BHK',
#        '12 Bedroom', '13 BHK', '18 Bedroom'], dtype=object)

# %%
new=df['size'].str.split(" ",expand=True)

# %%
new
# Out:
#        0        1
# 0      2      BHK
# 1      4  Bedroom
# 2      3      BHK
# 3      3      BHK
# 4      2      BHK
# ...   ..      ...
# 13315  5  Bedroom
# 13316  4      BHK
# 13317  2      BHK
# 13318  4      BHK
# 13319  1      BHK
#
# [12986 rows x 2 columns]

# %%
df["bedroom_count"]=new[0]
# Out:
# C:\Users\rames\AppData\Local\Temp\ipykernel_16020\3678129462.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["bedroom_count"]=new[0]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 12986 entries, 0 to 13319
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   area_type       12986 non-null  object
#  1   availability    12986 non-null  object
#  2   location        12985 non-null  object
#  3   size            12978 non-null  object
#  4   society         7528 non-null   object
#  5   total_sqft      12986 non-null  int64
#  6   bath            12970 non-null  float64
#  7   balcony         12439 non-null  float64
#  8   price           12986 non-null  float64
#  9   bedroom         12978 non-null  Int64
#  10  price_per_sqft  12986 non-null  float64
#  11  price_in_lakhs  12986 non-null  float64
#  12  bedroom_count   12978 non-null  object
# dtypes: Int64(1), float64(5), int64(1), object(6)
# memory usage: 1.4+ MB

# %%
df["bedroom_count"]=df['bedroom_count'].astype('float')
# Out:
# C:\Users\rames\AppData\Local\Temp\ipykernel_16020\3935102387.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["bedroom_count"]=df['bedroom_count'].astype('float')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 12986 entries, 0 to 13319
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   area_type       12986 non-null  object
#  1   availability    12986 non-null  object
#  2   location        12985 non-null  object
#  3   size            12978 non-null  object
#  4   society         7528 non-null   object
#  5   total_sqft      12986 non-null  int64
#  6   bath            12970 non-null  float64
#  7   balcony         12439 non-null  float64
#  8   price           12986 non-null  float64
#  9   bedroom         12978 non-null  Int64
#  10  price_per_sqft  12986 non-null  float64
#  11  price_in_lakhs  12986 non-null  float64
#  12  bedroom_count   12978 non-null  float64
# dtypes: Int64(1), float64(6), int64(1), object(5)
# memory usage: 1.4+ MB

# %%
#36.Create a column sqft_per_bathroom = total_sqft / bath.
df["sqft_per_bathroom"]=df["total_sqft"]/df["bath"]
# Out:
# C:\Users\rames\AppData\Local\Temp\ipykernel_16020\4184083560.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["sqft_per_bathroom"]=df["total_sqft"]/df["bath"]

# %%
#37.Convert availability values to lowercase.
df['availability']=df['availability'].str.lower()
# Out:
# C:\Users\rames\AppData\Local\Temp\ipykernel_16020\1448210978.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['availability']=df['availability'].str.lower()

# %%
df
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-dec  Electronic City Phase II
# 1                Plot  Area  ready to move          Chikka Tirupathi
# 2            Built-up  Area  ready to move               Uttarahalli
# 3      Super built-up  Area  ready to move        Lingadheeranahalli
# 4      Super built-up  Area  ready to move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  ready to move                Whitefield
# 13316  Super built-up  Area  ready to move             Richards Town
# 13317        Built-up  Area  ready to move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-jun           Padmanabhanagar
# 13319  Super built-up  Area  ready to move              Doddathoguru
#
#             size  society  total_sqft  bath  balcony   price  bedroom  \
# ...

# %%
#38.Add a column is_ready_to_move with True if availability is “Ready To Move”, else False.
df["is_ready_to_move"]=df['availability']=='ready to move'
# Out:
# C:\Users\rames\AppData\Local\Temp\ipykernel_16020\2542527903.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["is_ready_to_move"]=df['availability']=='ready to move'

# %%
df
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-dec  Electronic City Phase II
# 1                Plot  Area  ready to move          Chikka Tirupathi
# 2            Built-up  Area  ready to move               Uttarahalli
# 3      Super built-up  Area  ready to move        Lingadheeranahalli
# 4      Super built-up  Area  ready to move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  ready to move                Whitefield
# 13316  Super built-up  Area  ready to move             Richards Town
# 13317        Built-up  Area  ready to move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-jun           Padmanabhanagar
# 13319  Super built-up  Area  ready to move              Doddathoguru
#
#             size  society  total_sqft  bath  balcony   price  bedroom  \
# ...

# %%
#39.Rename the column price to price_in_crores.
df.rename(columns={"price":'price_in_crores'},inplace=True)
# Out:
# C:\Users\rames\AppData\Local\Temp\ipykernel_16020\1314600946.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns={"price":'price_in_crores'},inplace=True)

# %%
df
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-dec  Electronic City Phase II
# 1                Plot  Area  ready to move          Chikka Tirupathi
# 2            Built-up  Area  ready to move               Uttarahalli
# 3      Super built-up  Area  ready to move        Lingadheeranahalli
# 4      Super built-up  Area  ready to move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  ready to move                Whitefield
# 13316  Super built-up  Area  ready to move             Richards Town
# 13317        Built-up  Area  ready to move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-jun           Padmanabhanagar
# 13319  Super built-up  Area  ready to move              Doddathoguru
#
#             size  society  total_sqft  bath  balcony  price_in_crores  \
# ...

# %%
#40.Replace all spaces in column names with underscores.

# %%
#41.Extract only the numeric part from total_sqft (if it’s a string like “1200 - 1500”).
df["total_sqft"]
# Out:
# 0        1056
# 1        2600
# 2        1440
# 3        1521
# 4        1200
#          ...
# 13315    3453
# 13316    3600
# 13317    1141
# 13318    4689
# 13319     550
# Name: total_sqft, Length: 12986, dtype: int64

# %%
#42.Create a column price_category → “Low”, “Medium”, “High” based on price ranges.
avg_p
# Out:
# np.float64(112.27140458955799)

# %%
def p_category(x):
    if x<avg_p:
        return "low"
    elif x>avg_p:
        return "High"
    else:
        return "Medium"

# %%
df.rename(columns={"price_in_crores":"price"},inplace=True)
# Out:
# C:\Users\rames\AppData\Local\Temp\ipykernel_16020\24621233.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns={"price_in_crores":"price"},inplace=True)

# %%
df["price_category"]=df["price"].apply(p_category)
# Out:
# C:\Users\rames\AppData\Local\Temp\ipykernel_16020\1847839521.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["price_category"]=df["price"].apply(p_category)

# %%
df
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-dec  Electronic City Phase II
# 1                Plot  Area  ready to move          Chikka Tirupathi
# 2            Built-up  Area  ready to move               Uttarahalli
# 3      Super built-up  Area  ready to move        Lingadheeranahalli
# 4      Super built-up  Area  ready to move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  ready to move                Whitefield
# 13316  Super built-up  Area  ready to move             Richards Town
# 13317        Built-up  Area  ready to move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-jun           Padmanabhanagar
# 13319  Super built-up  Area  ready to move              Doddathoguru
#
#             size  society  total_sqft  bath  balcony   price  bedroom  \
# ...

# %%
#43.Add a new column area_sqft by converting total_sqft to float values.
df["area_sqft"]=df["total_sqft"].astype("float")
# Out:
# C:\Users\rames\AppData\Local\Temp\ipykernel_16020\18843765.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["area_sqft"]=df["total_sqft"].astype("float")

# %%
#44.Create a column price_per_bath = price / bath.
df["price_per_bath"]=df["price"]/df["bath"]
# Out:
# C:\Users\rames\AppData\Local\Temp\ipykernel_16020\3122534525.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["price_per_bath"]=df["price"]/df["bath"]

# %%
#45.Add a column price_per_room = price / bedroom_count.
df["price_per_room"]=df["price"]/df['bedroom_count']
# Out:
# C:\Users\rames\AppData\Local\Temp\ipykernel_16020\3375834680.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["price_per_room"]=df["price"]/df['bedroom_count']

# %%
#46.Create a derived column total_cost_in_lakhs = price_in_crores * 100.
df["price_in_lakhs"]
# Out:
# 0         3907.0
# 1        12000.0
# 2         6200.0
# 3         9500.0
# 4         5100.0
#           ...
# 13315    23100.0
# 13316    40000.0
# 13317     6000.0
# 13318    48800.0
# 13319     1700.0
# Name: price_in_lakhs, Length: 12986, dtype: float64

# %%
#47.Add a Boolean column large_balcony = True if balcony ≥ 3.
df["large_balcony"]=df["balcony"]>=3
# Out:
# C:\Users\rames\AppData\Local\Temp\ipykernel_16020\796701971.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["large_balcony"]=df["balcony"]>=3

# %%
#48.Create a column showing whether the location contains “Road”.
df["contain_road"]=df["location"].str.contains("Road",case=False,na=False)
# Out:
# C:\Users\rames\AppData\Local\Temp\ipykernel_16020\4247769626.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["contain_road"]=df["location"].str.contains("Road",case=False,na=False)

# %%
df
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-dec  Electronic City Phase II
# 1                Plot  Area  ready to move          Chikka Tirupathi
# 2            Built-up  Area  ready to move               Uttarahalli
# 3      Super built-up  Area  ready to move        Lingadheeranahalli
# 4      Super built-up  Area  ready to move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  ready to move                Whitefield
# 13316  Super built-up  Area  ready to move             Richards Town
# 13317        Built-up  Area  ready to move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-jun           Padmanabhanagar
# 13319  Super built-up  Area  ready to move              Doddathoguru
#
#             size  society  total_sqft  bath  balcony   price  bedroom  ...  \
# ...

# %%
df["contain_road"].unique()
# Out:
# array([False,  True])

# %%
#49.Add a new column with the number of words in each location.
df["words_in_location"]=df["location"].apply(lambda x:len(str(x).split()))
# Out:
# C:\Users\rames\AppData\Local\Temp\ipykernel_16020\638978108.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["words_in_location"]=df["location"].apply(lambda x:len(str(x).split()))

# %%
df
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-dec  Electronic City Phase II
# 1                Plot  Area  ready to move          Chikka Tirupathi
# 2            Built-up  Area  ready to move               Uttarahalli
# 3      Super built-up  Area  ready to move        Lingadheeranahalli
# 4      Super built-up  Area  ready to move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  ready to move                Whitefield
# 13316  Super built-up  Area  ready to move             Richards Town
# 13317        Built-up  Area  ready to move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-jun           Padmanabhanagar
# 13319  Super built-up  Area  ready to move              Doddathoguru
#
#             size  society  total_sqft  bath  balcony   price  bedroom  ...  \
# ...

# %%
#50.Combine area_type and availability into a new column property_status.
df["property_status"]=df["area_type"]+" "+df["availability"]
# Out:
# C:\Users\rames\AppData\Local\Temp\ipykernel_16020\2886897517.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["property_status"]=df["area_type"]+" "+df["availability"]

# %%
#51.Extract the first word from each location into a column main_area.
df["main_area"]=df["location"].apply(lambda x:str(x).split()[0])
# Out:
# C:\Users\rames\AppData\Local\Temp\ipykernel_16020\3949857795.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["main_area"]=df["location"].apply(lambda x:str(x).split()[0])

# %%
df
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-dec  Electronic City Phase II
# 1                Plot  Area  ready to move          Chikka Tirupathi
# 2            Built-up  Area  ready to move               Uttarahalli
# 3      Super built-up  Area  ready to move        Lingadheeranahalli
# 4      Super built-up  Area  ready to move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  ready to move                Whitefield
# 13316  Super built-up  Area  ready to move             Richards Town
# 13317        Built-up  Area  ready to move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-jun           Padmanabhanagar
# 13319  Super built-up  Area  ready to move              Doddathoguru
#
#             size  society  total_sqft  bath  balcony   price  bedroom  ...  \
# ...

# %%
#52.Convert all values in area_type to uppercase.
df["area_type"]=df["area_type"].str.upper()
# Out:
# C:\Users\rames\AppData\Local\Temp\ipykernel_16020\103898350.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["area_type"]=df["area_type"].str.upper()

# %%
#53.Replace the word “BHK” with “Bedrooms” in the size column.
df["size"]=df["size"].str.replace("BHK","Bedroom",case=False)
# Out:
# C:\Users\rames\AppData\Local\Temp\ipykernel_16020\2954445117.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["size"]=df["size"].str.replace("BHK","Bedroom",case=False)

# %%
#54.Add a new column price_per_sqft_rounded rounded to 2 decimals.
df.columns
# Out:
# Index(['area_type', 'availability', 'location', 'size', 'society',
#        'total_sqft', 'bath', 'balcony', 'price', 'bedroom', 'price_per_sqft',
#        'price_in_lakhs', 'bedroom_count', 'sqft_per_bathroom',
#        'is_ready_to_move', 'price_category', 'area_sqft', 'price_per_bath',
#        'price_per_room', 'large_balcony', 'contain_road', 'words_in_location',
#        'property_status', 'main_area'],
#       dtype='object')

# %%
df["price_per_sqft"]
# Out:
# 0        3.699811e+05
# 1        4.615385e+05
# 2        4.305556e+05
# 3        6.245891e+05
# 4        4.250000e+05
#              ...
# 13315    6.689835e+05
# 13316    1.111111e+06
# 13317    5.258545e+05
# 13318    1.040734e+06
# 13319    3.090909e+05
# Name: price_per_sqft, Length: 12986, dtype: float64

# %%
df["price_per_sqft_rounded"]=(df["price"]*100)/df["total_sqft"].round(2)
# Out:
# C:\Users\rames\AppData\Local\Temp\ipykernel_16020\4202826235.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["price_per_sqft_rounded"]=(df["price"]*100)/df["total_sqft"].round(2)

# %%
#54.Reorder columns so that price appears first.
column=df.pop("price")
df.insert(0,"price",column)

# %%
df
# Out:
#         price             area_type   availability                  location  \
# 0       39.07  SUPER BUILT-UP  AREA         19-dec  Electronic City Phase II
# 1      120.00            PLOT  AREA  ready to move          Chikka Tirupathi
# 2       62.00        BUILT-UP  AREA  ready to move               Uttarahalli
# 3       95.00  SUPER BUILT-UP  AREA  ready to move        Lingadheeranahalli
# 4       51.00  SUPER BUILT-UP  AREA  ready to move                  Kothanur
# ...       ...                   ...            ...                       ...
# 13315  231.00        BUILT-UP  AREA  ready to move                Whitefield
# 13316  400.00  SUPER BUILT-UP  AREA  ready to move             Richards Town
# 13317   60.00        BUILT-UP  AREA  ready to move     Raja Rajeshwari Nagar
# 13318  488.00  SUPER BUILT-UP  AREA         18-jun           Padmanabhanagar
# 13319   17.00  SUPER BUILT-UP  AREA  ready to move              Doddathoguru
#
# ...

# %%
#55.Drop the column society if it exists.
df.drop(columns=["society"],inplace=True)
# Out:
# C:\Users\rames\AppData\Local\Temp\ipykernel_16020\1435818240.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=["society"],inplace=True)

# %%
df
# Out:
#         price             area_type   availability                  location  \
# 0       39.07  SUPER BUILT-UP  AREA         19-dec  Electronic City Phase II
# 1      120.00            PLOT  AREA  ready to move          Chikka Tirupathi
# 2       62.00        BUILT-UP  AREA  ready to move               Uttarahalli
# 3       95.00  SUPER BUILT-UP  AREA  ready to move        Lingadheeranahalli
# 4       51.00  SUPER BUILT-UP  AREA  ready to move                  Kothanur
# ...       ...                   ...            ...                       ...
# 13315  231.00        BUILT-UP  AREA  ready to move                Whitefield
# 13316  400.00  SUPER BUILT-UP  AREA  ready to move             Richards Town
# 13317   60.00        BUILT-UP  AREA  ready to move     Raja Rajeshwari Nagar
# 13318  488.00  SUPER BUILT-UP  AREA         18-jun           Padmanabhanagar
# 13319   17.00  SUPER BUILT-UP  AREA  ready to move              Doddathoguru
#
# ...

# %%
#56.Change all text in the availability column to title case.
df["availability"]=df["availability"].str.title()
# Out:
# C:\Users\rames\AppData\Local\Temp\ipykernel_16020\3773213857.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["availability"]=df["availability"].str.title()

# %%
#57.Create a Boolean column multi_balcony where value is True if balcony &gt; 1.
df["multi_balcony"]=df["balcony"]>1
# Out:
# C:\Users\rames\AppData\Local\Temp\ipykernel_16020\1675305387.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["multi_balcony"]=df["balcony"]>1

# %%
df
# Out:
#         price             area_type   availability                  location  \
# 0       39.07  SUPER BUILT-UP  AREA         19-Dec  Electronic City Phase II
# 1      120.00            PLOT  AREA  Ready To Move          Chikka Tirupathi
# 2       62.00        BUILT-UP  AREA  Ready To Move               Uttarahalli
# 3       95.00  SUPER BUILT-UP  AREA  Ready To Move        Lingadheeranahalli
# 4       51.00  SUPER BUILT-UP  AREA  Ready To Move                  Kothanur
# ...       ...                   ...            ...                       ...
# 13315  231.00        BUILT-UP  AREA  Ready To Move                Whitefield
# 13316  400.00  SUPER BUILT-UP  AREA  Ready To Move             Richards Town
# 13317   60.00        BUILT-UP  AREA  Ready To Move     Raja Rajeshwari Nagar
# 13318  488.00  SUPER BUILT-UP  AREA         18-Jun           Padmanabhanagar
# 13319   17.00  SUPER BUILT-UP  AREA  Ready To Move              Doddathoguru
#
# ...

# %%
#58.Add a column indicating if total_sqft &gt; median of the dataset.
med_sqft=df["total_sqft"].mean()

# %%
df["total_sqft_bool"]=df["total_sqft"]>med_sqft
# Out:
# C:\Users\rames\AppData\Local\Temp\ipykernel_16020\1004187404.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["total_sqft_bool"]=df["total_sqft"]>med_sqft

# %%
#59.Replace all occurrences of “Super built-up Area” with “SuperBuiltUp”.
df['area_type']=df['area_type'].str.replace("Super built-up  Area","SuperBuiltUp",case=False)
# Out:
# C:\Users\rames\AppData\Local\Temp\ipykernel_16020\1632302125.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['area_type']=df['area_type'].str.replace("Super built-up  Area","SuperBuiltUp",case=False)

# %%
df['area_type'].unique()
# Out:
# array(['SuperBuiltUp', 'PLOT  AREA', 'BUILT-UP  AREA', 'CARPET  AREA'],
#       dtype=object)

# %%
#60.Create a column bath_to_room_ratio = bath / bedroom_count.
df["bath_to_room_ratio"]=df["bath"]/df["bedroom_count"]
# Out:
# C:\Users\rames\AppData\Local\Temp\ipykernel_16020\1168653080.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["bath_to_room_ratio"]=df["bath"]/df["bedroom_count"]

# %%
#61.Add a column with the total number of characters in each property’s location name.
df["words_in_location"]
# Out:
# 0        4
# 1        2
# 2        1
# 3        1
# 4        1
#         ..
# 13315    1
# 13316    2
# 13317    3
# 13318    1
# 13319    1
# Name: words_in_location, Length: 12986, dtype: int64

# %%
#62.Create a column location_zone by extracting the first two letters of the location.
df["location_zone"]=df['location'].str[:2]
# Out:
# C:\Users\rames\AppData\Local\Temp\ipykernel_16020\862511436.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["location_zone"]=df['location'].str[:2]

# %%
df
# Out:
#         price       area_type   availability                  location  \
# 0       39.07    SuperBuiltUp         19-Dec  Electronic City Phase II
# 1      120.00      PLOT  AREA  Ready To Move          Chikka Tirupathi
# 2       62.00  BUILT-UP  AREA  Ready To Move               Uttarahalli
# 3       95.00    SuperBuiltUp  Ready To Move        Lingadheeranahalli
# 4       51.00    SuperBuiltUp  Ready To Move                  Kothanur
# ...       ...             ...            ...                       ...
# 13315  231.00  BUILT-UP  AREA  Ready To Move                Whitefield
# 13316  400.00    SuperBuiltUp  Ready To Move             Richards Town
# 13317   60.00  BUILT-UP  AREA  Ready To Move     Raja Rajeshwari Nagar
# 13318  488.00    SuperBuiltUp         18-Jun           Padmanabhanagar
# 13319   17.00    SuperBuiltUp  Ready To Move              Doddathoguru
#
#             size  total_sqft  bath  balcony  bedroom  price_per_sqft  ...  \
# ...

# %%
#63.Rename multiple columns at once (size→bhk_type, bath→bathrooms).
df.rename(columns={"size":"bhk_type","bath":'bathrooms'},inplace=True)
# Out:
# C:\Users\rames\AppData\Local\Temp\ipykernel_16020\2844343397.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns={"size":"bhk_type","bath":'bathrooms'},inplace=True)

# %%
df
# Out:
#         price       area_type   availability                  location  \
# 0       39.07    SuperBuiltUp         19-Dec  Electronic City Phase II
# 1      120.00      PLOT  AREA  Ready To Move          Chikka Tirupathi
# 2       62.00  BUILT-UP  AREA  Ready To Move               Uttarahalli
# 3       95.00    SuperBuiltUp  Ready To Move        Lingadheeranahalli
# 4       51.00    SuperBuiltUp  Ready To Move                  Kothanur
# ...       ...             ...            ...                       ...
# 13315  231.00  BUILT-UP  AREA  Ready To Move                Whitefield
# 13316  400.00    SuperBuiltUp  Ready To Move             Richards Town
# 13317   60.00  BUILT-UP  AREA  Ready To Move     Raja Rajeshwari Nagar
# 13318  488.00    SuperBuiltUp         18-Jun           Padmanabhanagar
# 13319   17.00    SuperBuiltUp  Ready To Move              Doddathoguru
#
#         bhk_type  total_sqft  bathrooms  balcony  bedroom  price_per_sqft  \
# ...

# %%
#64.Replace all “Plot Area” entries with “Land Area” in the area_type column.
df["area_type"]=df["area_type"].str.replace("plot  area","Land Area",case=False)
# Out:
# C:\Users\rames\AppData\Local\Temp\ipykernel_16020\2431467407.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["area_type"]=df["area_type"].str.replace("plot  area","Land Area",case=False)

# %%
df["area_type"].unique()
# Out:
# array(['SuperBuiltUp', 'Land Area', 'BUILT-UP  AREA', 'CARPET  AREA'],
#       dtype=object)

# %%
#65.Create a new column compact_house = True if total_sqft &lt; 1000.
df["compact_house"]=df['total_sqft']<1000
# Out:
# C:\Users\rames\AppData\Local\Temp\ipykernel_16020\229360555.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["compact_house"]=df['total_sqft']<1000

# %%
#66.Count how many properties exist per area_type.
df.groupby('area_type')["price"].count()
# Out:
# area_type
# BUILT-UP  AREA    2386
# CARPET  AREA        71
# Land Area         1994
# SuperBuiltUp      8535
# Name: price, dtype: int64

# %%
#67.Find the average price for each area_type.
df.groupby('area_type')["price"].mean()
# Out:
# area_type
# BUILT-UP  AREA    103.525704
# CARPET  AREA       93.777324
# Land Area         209.396028
# SuperBuiltUp       92.179292
# Name: price, dtype: float64

# %%
#68.Group by location and compute the mean price.
df.groupby('location')["price"].mean()
# Out:
# location
#  Anekal                  16.000000
#  Banaswadi               35.000000
#  Basavangudi             50.000000
#  Bhoganhalli             22.890000
#  Devarabeesana Halli    124.833333
#                            ...
# t.c palya               160.000000
# tc.palya                 60.750000
# vinayakanagar           200.000000
# white field,kadugodi    275.000000
# whitefiled               32.730000
# Name: price, Length: 1295, dtype: float64

# %%
#69.Find which location has the maximum average price_per_sqft.
df.columns
# Out:
# Index(['price', 'area_type', 'availability', 'location', 'bhk_type',
#        'total_sqft', 'bathrooms', 'balcony', 'bedroom', 'price_per_sqft',
#        'price_in_lakhs', 'bedroom_count', 'sqft_per_bathroom',
#        'is_ready_to_move', 'price_category', 'area_sqft', 'price_per_bath',
#        'price_per_room', 'large_balcony', 'contain_road', 'words_in_location',
#        'property_status', 'main_area', 'price_per_sqft_rounded',
#        'multi_balcony', 'total_sqft_bool', 'bath_to_room_ratio',
#        'location_zone', 'compact_house'],
#       dtype='object')

# %%
df.groupby('location')["price_per_sqft"].mean().idxmax()
# Out:
# 'Grihalakshmi Layout'

# %%
#70.Compute total number of listings per availability status.
df.groupby('availability')["price"].count()
# Out:
# availability
# 14-Jul                      1
# 14-Nov                      1
# 15-Aug                      1
# 15-Dec                      1
# 15-Jun                      1
#                         ...
# 22-Jun                     19
# 22-Mar                      3
# 22-Nov                      2
# Immediate Possession        8
# Ready To Move           10431
# Name: price, Length: 80, dtype: int64

# %%
#71.Find the average number of bathrooms per area type.
df.groupby('area_type')["bathrooms"].mean()
# Out:
# area_type
# BUILT-UP  AREA    2.635600
# CARPET  AREA      2.535211
# Land Area         3.906848
# SuperBuiltUp      2.423045
# Name: bathrooms, dtype: float64

# %%
#72.Determine how many houses have more than 3 bedrooms per area type.
bed=df[df["bedroom"]>3]

# %%
bed.groupby('area_type')['bedroom'].count()
# Out:
# area_type
# BUILT-UP  AREA     452
# CARPET  AREA         9
# Land Area         1199
# SuperBuiltUp       520
# Name: bedroom, dtype: Int64

# %%
#73.For each availability type, get the minimum and maximum price.
df.groupby('availability')['price'].max()
# Out:
# availability
# 14-Jul                    43.71
# 14-Nov                    43.71
# 15-Aug                    62.00
# 15-Dec                   130.00
# 15-Jun                    97.00
#                          ...
# 22-Jun                   146.00
# 22-Mar                    70.00
# 22-Nov                    79.15
# Immediate Possession     460.00
# Ready To Move           3600.00
# Name: price, Length: 80, dtype: float64

# %%
df.groupby('availability')['price'].min()
# Out:
# availability
# 14-Jul                   43.71
# 14-Nov                   43.71
# 15-Aug                   62.00
# 15-Dec                  130.00
# 15-Jun                   97.00
#                          ...
# 22-Jun                   41.00
# 22-Mar                   30.00
# 22-Nov                   77.59
# Immediate Possession      8.44
# Ready To Move             8.00
# Name: price, Length: 80, dtype: float64

# %%
#74.Count the number of unique area_type values per availability group.
df.groupby(['availability','area_type'])['price'].count()
# Out:
# availability          area_type
# 14-Jul                BUILT-UP  AREA       1
# 14-Nov                BUILT-UP  AREA       1
# 15-Aug                BUILT-UP  AREA       1
# 15-Dec                BUILT-UP  AREA       1
# 15-Jun                BUILT-UP  AREA       1
#                                         ...
# Immediate Possession  Land Area            8
# Ready To Move         BUILT-UP  AREA    2120
#                       CARPET  AREA        61
#                       Land Area         1770
#                       SuperBuiltUp      6480
# Name: price, Length: 147, dtype: int64

# %%
#75.Find which area_type has the most properties in “Ready To Move” condition.
av=df[df['availability']=='Ready To Move']

# %%
av.groupby('area_type')['price'].count().idxmax()
# Out:
# 'SuperBuiltUp'

# %%
#76.Compute average price_per_sqft for each bedroom count.
df.groupby('bedroom_count')['price_per_sqft'].mean()
# Out:
# bedroom_count
# 1.0     6.669415e+05
# 2.0     5.179276e+05
# 3.0     6.566016e+05
# 4.0     1.972834e+06
# 5.0     1.379025e+06
# 6.0     1.258832e+06
# 7.0     3.457453e+06
# 8.0     1.306683e+06
# 9.0     1.309501e+06
# 10.0    1.620051e+06
# 11.0    9.091667e+05
# 12.0    1.344086e+06
# 13.0    5.069124e+05
# 14.0    1.000000e+06
# 16.0    5.500000e+05
# 18.0    1.666667e+06
# 19.0    2.450000e+06
# 27.0    2.875000e+05
# 43.0    2.750000e+06
# Name: price_per_sqft, dtype: float64

# %%
#77.Group by location and find total number of houses with bath &gt; 2.
bath=df[df["bathrooms"]>2]

# %%
bath.groupby('location')['price'].count()
# Out:
# location
#  Devarabeesana Halli    4
#  Devarachikkanahalli    3
#  south                  1
# 1 Annasandrapalya       1
# 1 Giri Nagar            1
#                        ..
# sarjapura main road     1
# singapura paradise      1
# t.c palya               1
# vinayakanagar           1
# white field,kadugodi    1
# Name: price, Length: 969, dtype: int64

# %%
#78.Determine which location has the maximum number of 2 BHK houses.
df['bhk_type'].unique()
# Out:
# array(['2 Bedroom', '4 Bedroom', '3 Bedroom', '6 Bedroom', '1 Bedroom',
#        '1 RK', '8 Bedroom', '7 Bedroom', '5 Bedroom', '11 Bedroom',
#        '9 Bedroom', '27 Bedroom', '10 Bedroom', nan, '19 Bedroom',
#        '16 Bedroom', '43 Bedroom', '14 Bedroom', '12 Bedroom',
#        '13 Bedroom', '18 Bedroom'], dtype=object)

# %%
bhk=df[df["bhk_type"]=='2 Bedroom']

# %%
bhk.groupby('location')['price'].count().idxmax()
# Out:
# 'Whitefield'

# %%
#79.For each area_type, count how many houses have balconies.
bal_n=df[~df["balcony"].isnull()]

# %%
bal=bal_n[bal_n['balcony']!=0]

# %%
bal.groupby('area_type')['price'].count()
# Out:
# area_type
# BUILT-UP  AREA    1979
# CARPET  AREA        57
# Land Area         1449
# SuperBuiltUp      8084
# Name: price, dtype: int64

# %%
df.isnull().sum()
# Out:
# price                       0
# area_type                   0
# availability                0
# location                    1
# bhk_type                    8
# total_sqft                  0
# bathrooms                  16
# balcony                   547
# bedroom                     8
# price_per_sqft              0
# price_in_lakhs              0
# bedroom_count               8
# sqft_per_bathroom          16
# is_ready_to_move            0
# price_category              0
# area_sqft                   0
# price_per_bath             16
# price_per_room              8
# large_balcony               0
# contain_road                0
# words_in_location           0
# property_status             0
# main_area                   0
# price_per_sqft_rounded      0
# multi_balcony               0
# total_sqft_bool             0
# bath_to_room_ratio         16
# location_zone               1
# compact_house               0
# dtype: int64

# %%
#80.Find the most common availability for 3 BHK houses.
bhk_3=df[df["bhk_type"]=="3 Bedroom"]

# %%
bhk_3
# Out:
#         price       area_type   availability            location   bhk_type  \
# 2       62.00  BUILT-UP  AREA  Ready To Move         Uttarahalli  3 Bedroom
# 3       95.00    SuperBuiltUp  Ready To Move  Lingadheeranahalli  3 Bedroom
# 8       63.25    SuperBuiltUp  Ready To Move        Marathahalli  3 Bedroom
# 10      70.00    SuperBuiltUp         18-Feb          Whitefield  3 Bedroom
# 14     148.00       Land Area  Ready To Move            Sarjapur  3 Bedroom
# ...       ...             ...            ...                 ...        ...
# 13307  134.00  BUILT-UP  AREA  Ready To Move        Billekahalli  3 Bedroom
# 13308  142.00  BUILT-UP  AREA  Ready To Move   Bannerghatta Road  3 Bedroom
# 13309   92.13    SuperBuiltUp  Ready To Move        Yeshwanthpur  3 Bedroom
# 13313   57.00    SuperBuiltUp  Ready To Move         Uttarahalli  3 Bedroom
# 13314  112.00    SuperBuiltUp  Ready To Move   Green Glen Layout  3 Bedroom
#
# ...

# %%
bhk_3["availability"].max()
# Out:
# 'Ready To Move'

# %%
#81.Group by both area_type and availability and find average price.
df.groupby(["area_type","availability"])["price"].mean()
# Out:
# area_type       availability
# BUILT-UP  AREA  14-Jul            43.710000
#                 14-Nov            43.710000
#                 15-Aug            62.000000
#                 15-Dec           130.000000
#                 15-Jun            97.000000
#                                     ...
# SuperBuiltUp    22-Jan            65.166667
#                 22-Jun           107.224737
#                 22-Mar            49.000000
#                 22-Nov            78.370000
#                 Ready To Move     91.414941
# Name: price, Length: 147, dtype: float64

# %%
#82.Count how many houses in each location have a price greater than 1 crore.
price_1=df[df["price"]>1]

# %%
price_1.groupby("location")['price'].count()
# Out:
# location
#  Anekal                 1
#  Banaswadi              1
#  Basavangudi            1
#  Bhoganhalli            1
#  Devarabeesana Halli    6
#                        ..
# t.c palya               1
# tc.palya                4
# vinayakanagar           1
# white field,kadugodi    1
# whitefiled              1
# Name: price, Length: 1295, dtype: int64

# %%
#83.For each bedroom count, compute average and median price_per_sqft.
df.groupby('bedroom_count')['price_per_sqft'].mean()
# Out:
# bedroom_count
# 1.0     6.669415e+05
# 2.0     5.179276e+05
# 3.0     6.566016e+05
# 4.0     1.972834e+06
# 5.0     1.379025e+06
# 6.0     1.258832e+06
# 7.0     3.457453e+06
# 8.0     1.306683e+06
# 9.0     1.309501e+06
# 10.0    1.620051e+06
# 11.0    9.091667e+05
# 12.0    1.344086e+06
# 13.0    5.069124e+05
# 14.0    1.000000e+06
# 16.0    5.500000e+05
# 18.0    1.666667e+06
# 19.0    2.450000e+06
# 27.0    2.875000e+05
# 43.0    2.750000e+06
# Name: price_per_sqft, dtype: float64

# %%
df.groupby('bedroom_count')['price_per_sqft'].median()
# Out:
# bedroom_count
# 1.0     5.187831e+05
# 2.0     4.801903e+05
# 3.0     5.588235e+05
# 4.0     8.760965e+05
# 5.0     1.041667e+06
# 6.0     1.153846e+06
# 7.0     1.212406e+06
# 8.0     1.210227e+06
# 9.0     1.233696e+06
# 10.0    1.367794e+06
# 11.0    9.850000e+05
# 12.0    1.344086e+06
# 13.0    5.069124e+05
# 14.0    1.000000e+06
# 16.0    5.500000e+05
# 18.0    1.666667e+06
# 19.0    2.450000e+06
# 27.0    2.875000e+05
# 43.0    2.750000e+06
# Name: price_per_sqft, dtype: float64

# %%
#84.Find which location has the least number of listings.
df.groupby('location')['price'].count().idxmin()
# Out:
# ' Anekal'

# %%
#85.Find top 5 locations with the highest average price.
df.groupby('location')['price'].mean().sort_values(ascending=False).head()
# Out:
# location
# Cubbon Road       1900.000000
# Ashok Nagar       1486.000000
# Defence Colony    1167.714286
# Yemlur            1093.388889
# Church Street     1068.000000
# Name: price, dtype: float64

# %%
#86.Count listings for each combination of (location, area_type).
df.groupby(['location','area_type'])['price'].count()
# Out:
# location              area_type
#  Anekal               BUILT-UP  AREA    1
#  Banaswadi            SuperBuiltUp      1
#  Basavangudi          SuperBuiltUp      1
#  Bhoganhalli          SuperBuiltUp      1
#  Devarabeesana Halli  BUILT-UP  AREA    1
#                                        ..
# t.c palya             Land Area         1
# tc.palya              Land Area         4
# vinayakanagar         SuperBuiltUp      1
# white field,kadugodi  Land Area         1
# whitefiled            SuperBuiltUp      1
# Name: price, Length: 2301, dtype: int64

# %%
#87.Get the total sum of price grouped by availability.
df.groupby('availability')['price'].sum()
# Out:
# availability
# 14-Jul                       43.71
# 14-Nov                       43.71
# 15-Aug                       62.00
# 15-Dec                      130.00
# 15-Jun                       97.00
#                            ...
# 22-Jun                     2037.27
# 22-Mar                      147.00
# 22-Nov                      156.74
# Immediate Possession       1088.27
# Ready To Move           1198779.87
# Name: price, Length: 80, dtype: float64

# %%
#88.For each location, calculate the maximum number of balconies.
df.groupby('location')['balcony'].max()
# Out:
# location
#  Anekal                 1.0
#  Banaswadi              0.0
#  Basavangudi            1.0
#  Bhoganhalli            0.0
#  Devarabeesana Halli    3.0
#                        ...
# t.c palya               3.0
# tc.palya                1.0
# vinayakanagar           2.0
# white field,kadugodi    NaN
# whitefiled              1.0
# Name: balcony, Length: 1295, dtype: float64

# %%
#89.Determine which area type has the largest total square footage.
df.groupby('area_type')['total_sqft'].sum().idxmax()
# Out:
# 'SuperBuiltUp'

# %%
#90.Group by availability and count how many listings have more than 2 bathrooms.
bath=df[df['bathrooms']>2]

# %%
bath.groupby('availability')['bathrooms'].count()
# Out:
# availability
# 14-Nov              1
# 15-Nov              2
# 15-Oct              2
# 16-Dec              3
# 16-Jan              1
#                  ...
# 22-Dec              2
# 22-Jan              2
# 22-Jun              8
# 22-Nov              2
# Ready To Move    4441
# Name: bathrooms, Length: 71, dtype: int64

# %%
df.columns
# Out:
# Index(['price', 'area_type', 'availability', 'location', 'bhk_type',
#        'total_sqft', 'bathrooms', 'balcony', 'bedroom', 'price_per_sqft',
#        'price_in_lakhs', 'bedroom_count', 'sqft_per_bathroom',
#        'is_ready_to_move', 'price_category', 'area_sqft', 'price_per_bath',
#        'price_per_room', 'large_balcony', 'contain_road', 'words_in_location',
#        'property_status', 'main_area', 'price_per_sqft_rounded',
#        'multi_balcony', 'total_sqft_bool', 'bath_to_room_ratio',
#        'location_zone', 'compact_house'],
#       dtype='object')

# %%
#91.For each bedroom count, find the average total_sqft.
df.groupby('bedroom_count')['total_sqft'].mean()
# Out:
# bedroom_count
# 1.0       754.911960
# 2.0      1138.333578
# 3.0      1675.740413
# 4.0      2695.295252
# 5.0      2371.904899
# 6.0      2040.100457
# 7.0      2309.750000
# 8.0      1922.056818
# 9.0      2928.557692
# 10.0     3411.142857
# 11.0     3350.000000
# 12.0     2232.000000
# 13.0     5425.000000
# 14.0     1250.000000
# 16.0    10000.000000
# 18.0     1200.000000
# 19.0     2000.000000
# 27.0     8000.000000
# 43.0     2400.000000
# Name: total_sqft, dtype: float64

# %%
#92.Group by location and get the count of unique area_type values.
df.groupby('location')['area_type'].nunique()
# Out:
# location
#  Anekal                 1
#  Banaswadi              1
#  Basavangudi            1
#  Bhoganhalli            1
#  Devarabeesana Halli    2
#                        ..
# t.c palya               1
# tc.palya                1
# vinayakanagar           1
# white field,kadugodi    1
# whitefiled              1
# Name: area_type, Length: 1295, dtype: int64

# %%
#93.Find which location has the highest total price sum.
df.groupby('location')['price'].sum().idxmax()
# Out:
# 'Whitefield'

# %%
#94.For each area_type, find the listing with the highest price_per_sqft.
df.groupby('area_type')['price_per_sqft'].max()
# Out:
# area_type
# BUILT-UP  AREA    2.300000e+08
# CARPET  AREA      2.000000e+07
# Land Area         1.200000e+09
# SuperBuiltUp      5.600000e+06
# Name: price_per_sqft, dtype: float64

# %%
#95.Count number of properties where bath equals bedroom_count for each area type.
bath_bed=df[df['bathrooms']==df['bedroom_count']]

# %%
bath_bed.groupby('area_type')['bathrooms'].count()
# Out:
# area_type
# BUILT-UP  AREA    1846
# CARPET  AREA        56
# Land Area         1185
# SuperBuiltUp      6764
# Name: bathrooms, dtype: int64

# %%
df.groupby('area_type')['bathrooms'].apply(lambda x: (x == df.loc[x.index, 'bedroom_count']).sum())
# Out:
# area_type
# BUILT-UP  AREA    1846
# CARPET  AREA        56
# Land Area         1185
# SuperBuiltUp      6764
# Name: bathrooms, dtype: int64

# %%
#96.Group by bedroom count and find average number of balconies.
df.groupby('bedroom_count')['balcony'].mean()
# Out:
# bedroom_count
# 1.0     0.829146
# 2.0     1.443745
# 3.0     1.836909
# 4.0     1.743913
# 5.0     1.648464
# 6.0     1.815789
# 7.0     1.976471
# 8.0     1.701493
# 9.0     1.939394
# 10.0    3.000000
# 11.0    2.000000
# 12.0    2.000000
# 13.0    0.000000
# 14.0    0.000000
# 16.0         NaN
# 18.0         NaN
# 19.0         NaN
# 27.0    0.000000
# 43.0    0.000000
# Name: balcony, dtype: float64

# %%
#97.Group by both area_type and location to compute total price.
df.groupby(['area_type','location'])['price'].sum()
# Out:
# area_type       location
# BUILT-UP  AREA   Anekal                  16.00
#                  Devarabeesana Halli    149.00
#                  Devarachikkanahalli     47.00
#                  Electronic City         46.50
#                  Mysore Highway          17.00
#                                          ...
# SuperBuiltUp    rr nagar                 60.00
#                 sapthagiri Layout       115.00
#                 sarjapura main road     250.00
#                 vinayakanagar           200.00
#                 whitefiled               32.73
# Name: price, Length: 2301, dtype: float64

# %%
#98.Find which availability category contributes the highest overall total price.
df.groupby('availability')['price'].sum().idxmax()
# Out:
# 'Ready To Move'
