# %%
import pandas as pd

# %%
data=pd.read_csv("Admission_predict.csv")

# %%
data
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0             1        337          118                  4  4.5   4.5  9.65
# 1             2        324          107                  4  4.0   4.5  8.87
# 2             3        316          104                  3  3.0   3.5  8.00
# 3             4        322          110                  3  3.5   2.5  8.67
# 4             5        314          103                  2  2.0   3.0  8.21
# ..          ...        ...          ...                ...  ...   ...   ...
# 395         396        324          110                  3  3.5   3.5  9.04
# 396         397        325          107                  3  3.0   3.5  9.11
# 397         398        330          116                  4  5.0   4.5  9.45
# 398         399        312          103                  3  3.5   4.0  8.78
# 399         400        333          117                  4  5.0   4.0  9.66
#
#      Research  Chance of Admit
# ...

# %%
#1.Display all rows where GRE Score is greater than 320.
data[data["GRE Score"]>320]
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0             1        337          118                  4  4.5   4.5  9.65
# 1             2        324          107                  4  4.0   4.5  8.87
# 3             4        322          110                  3  3.5   2.5  8.67
# 5             6        330          115                  5  4.5   3.0  9.34
# 6             7        321          109                  3  3.0   4.0  8.20
# ..          ...        ...          ...                ...  ...   ...   ...
# 394         395        329          111                  4  4.5   4.0  9.23
# 395         396        324          110                  3  3.5   3.5  9.04
# 396         397        325          107                  3  3.0   3.5  9.11
# 397         398        330          116                  4  5.0   4.5  9.45
# 399         400        333          117                  4  5.0   4.0  9.66
#
#      Research  Chance of Admit
# ...

# %%
#2.Show applicants whose TOEFL Score is less than 100.
data[data['TOEFL Score']<100]
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 27           28        298           98                  2  1.5   2.5  7.50
# 28           29        295           93                  1  2.0   2.0  7.20
# 29           30        310           99                  2  1.5   2.0  7.30
# 30           31        300           97                  2  3.0   3.0  8.10
# 50           51        313           98                  3  2.5   4.5  8.30
# 57           58        298           99                  2  4.0   2.0  7.60
# 58           59        300           99                  1  3.0   2.0  6.80
# 77           78        301           99                  2  3.0   2.0  8.22
# 78           79        296           95                  2  3.0   2.0  7.54
# 79           80        294           93                  1  1.5   2.0  7.36
# 91           92        299           97                  3  5.0   3.5  7.66
# ...

# %%
#3.Get records where University Rating equals 5.
data[data['University Rating']==5]
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 5             6        330          115                  5  4.5   3.0  9.34
# 22           23        328          116                  5  5.0   5.0  9.50
# 23           24        334          119                  5  5.0   4.5  9.70
# 24           25        336          119                  5  4.0   3.5  9.80
# 25           26        340          120                  5  4.5   4.5  9.60
# 26           27        322          109                  5  4.5   3.5  8.80
# 33           34        340          114                  5  4.0   4.0  9.60
# 34           35        331          112                  5  4.0   5.0  9.80
# 35           36        320          110                  5  5.0   5.0  9.20
# 44           45        326          113                  5  4.5   4.0  9.40
# 45           46        322          110                  5  5.0   4.0  9.10
# ...

# %%
#4.Select all students who have done Research (value 1).
data[data["Research"]==1]
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0             1        337          118                  4  4.5   4.5  9.65
# 1             2        324          107                  4  4.0   4.5  8.87
# 2             3        316          104                  3  3.0   3.5  8.00
# 3             4        322          110                  3  3.5   2.5  8.67
# 5             6        330          115                  5  4.5   3.0  9.34
# ..          ...        ...          ...                ...  ...   ...   ...
# 394         395        329          111                  4  4.5   4.0  9.23
# 395         396        324          110                  3  3.5   3.5  9.04
# 396         397        325          107                  3  3.0   3.5  9.11
# 397         398        330          116                  4  5.0   4.5  9.45
# 399         400        333          117                  4  5.0   4.0  9.66
#
#      Research  Chance of Admit
# ...

# %%
#5.Display students who have not done Research (value 0).
data[data["Research"]==0]
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 4             5        314          103                  2  2.0   3.0  8.21
# 7             8        308          101                  2  3.0   4.0  7.90
# 8             9        302          102                  1  2.0   1.5  8.00
# 9            10        323          108                  3  3.5   3.0  8.60
# 15           16        314          105                  3  3.5   2.5  8.30
# ..          ...        ...          ...                ...  ...   ...   ...
# 388         389        296           97                  2  1.5   2.0  7.80
# 390         391        314          102                  2  2.0   2.5  8.24
# 391         392        318          106                  3  2.0   3.0  8.65
# 393         394        317          104                  2  3.0   3.0  8.76
# 398         399        312          103                  3  3.5   4.0  8.78
#
#      Research  Chance of Admit
# ...

# %%
#6.Find applicants with CGPA greater than 9.0.
data[data['CGPA']>9.0]
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0             1        337          118                  4  4.5   4.5  9.65
# 5             6        330          115                  5  4.5   3.0  9.34
# 12           13        328          112                  4  4.0   4.5  9.10
# 22           23        328          116                  5  5.0   5.0  9.50
# 23           24        334          119                  5  5.0   4.5  9.70
# ..          ...        ...          ...                ...  ...   ...   ...
# 394         395        329          111                  4  4.5   4.0  9.23
# 395         396        324          110                  3  3.5   3.5  9.04
# 396         397        325          107                  3  3.0   3.5  9.11
# 397         398        330          116                  4  5.0   4.5  9.45
# 399         400        333          117                  4  5.0   4.0  9.66
#
#      Research  Chance of Admit
# ...

# %%
#7.Retrieve records where both GRE Score &gt; 320 and CGPA &gt; 9.0.
data[(data['GRE Score']>320) & (data["CGPA"]>9.0)]
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0             1        337          118                  4  4.5   4.5  9.65
# 5             6        330          115                  5  4.5   3.0  9.34
# 12           13        328          112                  4  4.0   4.5  9.10
# 22           23        328          116                  5  5.0   5.0  9.50
# 23           24        334          119                  5  5.0   4.5  9.70
# ..          ...        ...          ...                ...  ...   ...   ...
# 394         395        329          111                  4  4.5   4.0  9.23
# 395         396        324          110                  3  3.5   3.5  9.04
# 396         397        325          107                  3  3.0   3.5  9.11
# 397         398        330          116                  4  5.0   4.5  9.45
# 399         400        333          117                  4  5.0   4.0  9.66
#
#      Research  Chance of Admit
# ...

# %%
#8.Display records where either SOP or LOR rating is 5.0.
data[(data['SOP']==5.0)]
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 22           23        328          116                  5  5.0   5.0  9.50
# 23           24        334          119                  5  5.0   4.5  9.70
# 35           36        320          110                  5  5.0   5.0  9.20
# 45           46        322          110                  5  5.0   4.0  9.10
# 70           71        332          118                  5  5.0   5.0  9.64
# 71           72        336          112                  5  5.0   5.0  9.76
# 72           73        321          111                  5  5.0   5.0  9.45
# 81           82        340          120                  4  5.0   5.0  9.50
# 82           83        320          110                  5  5.0   4.5  9.22
# 91           92        299           97                  3  5.0   3.5  7.66
# 98           99        332          119                  4  5.0   4.5  9.24
# ...

# %%
#9.Get rows where Chance of Admit is above 0.8 and University Rating ≥ 4.
#data[(data['Chance of Admit'] > 0.8)]# & (data["University Rating"] >= 4)]

# %%
data[(data["University Rating"] >= 4)]
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0             1        337          118                  4  4.5   4.5  9.65
# 1             2        324          107                  4  4.0   4.5  8.87
# 5             6        330          115                  5  4.5   3.0  9.34
# 11           12        327          111                  4  4.0   4.5  9.00
# 12           13        328          112                  4  4.0   4.5  9.10
# ..          ...        ...          ...                ...  ...   ...   ...
# 385         386        335          117                  5  5.0   5.0  9.82
# 392         393        326          112                  4  4.0   3.5  9.12
# 394         395        329          111                  4  4.5   4.0  9.23
# 397         398        330          116                  4  5.0   4.5  9.45
# 399         400        333          117                  4  5.0   4.0  9.66
#
#      Research  Chance of Admit
# ...

# %%
#10.Find all rows where TOEFL Score is between 100 and 110.
data[(data["TOEFL Score"]>100) & (data["TOEFL Score"]<110)]
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 1             2        324          107                  4  4.0   4.5  8.87
# 2             3        316          104                  3  3.0   3.5  8.00
# 4             5        314          103                  2  2.0   3.0  8.21
# 6             7        321          109                  3  3.0   4.0  8.20
# 7             8        308          101                  2  3.0   4.0  7.90
# ..          ...        ...          ...                ...  ...   ...   ...
# 390         391        314          102                  2  2.0   2.5  8.24
# 391         392        318          106                  3  2.0   3.0  8.65
# 393         394        317          104                  2  3.0   3.0  8.76
# 396         397        325          107                  3  3.0   3.5  9.11
# 398         399        312          103                  3  3.5   4.0  8.78
#
#      Research  Chance of Admit
# ...

# %%
#11.Display data for students whose GRE Score is not equal to 300.
data[data['TOEFL Score'] != 300]
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0             1        337          118                  4  4.5   4.5  9.65
# 1             2        324          107                  4  4.0   4.5  8.87
# 2             3        316          104                  3  3.0   3.5  8.00
# 3             4        322          110                  3  3.5   2.5  8.67
# 4             5        314          103                  2  2.0   3.0  8.21
# ..          ...        ...          ...                ...  ...   ...   ...
# 395         396        324          110                  3  3.5   3.5  9.04
# 396         397        325          107                  3  3.0   3.5  9.11
# 397         398        330          116                  4  5.0   4.5  9.45
# 398         399        312          103                  3  3.5   4.0  8.78
# 399         400        333          117                  4  5.0   4.0  9.66
#
#      Research  Chance of Admit
# ...

# %%
#12.Show all students with CGPA less than 8 and Research = 1.
data[(data["CGPA"]<8) & (data["Research"]==1)]
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 20           21        312          107                  3  3.0   2.0  7.90
# 27           28        298           98                  2  1.5   2.5  7.50
# 51           52        312          100                  2  1.5   3.5  7.90
# 58           59        300           99                  1  3.0   2.0  6.80
# 78           79        296           95                  2  3.0   2.0  7.54
# 90           91        318          106                  2  4.0   4.0  7.92
# 93           94        301           97                  2  3.0   3.0  7.88
# 168         169        293           97                  2  2.0   4.0  7.80
# 357         358        301          104                  2  3.5   3.5  7.89
#
#      Research  Chance of Admit
# 20          1              0.64
# 27          1              0.44
# 51          1              0.56
# 58          1              0.36
# 78          1              0.44
# ...

# %%
#13.Retrieve rows where University Rating &lt; 3 and SOP &gt; 4.
data[(data["University Rating"]<3) & (data["SOP"]>4)]
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 103         104        317          104                  2  4.5   4.0  8.47
# 138         139        326          116                  2  4.5   3.0  9.08
# 141         142        332          118                  2  4.5   3.5  9.36
#
#      Research  Chance of Admit
# 103         0              0.57
# 138         1              0.80
# 141         1              0.90

# %%
#14.Get records of students having TOEFL Score &gt; 105 but GRE Score &lt; 310.
data[(data["TOEFL Score"]>105) & (data["GRE Score"]<310)]
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 13           14        307          109                  3  4.0   3.0  8.00
# 36           37        299          106                  2  4.0   4.0  8.40
# 39           40        307          108                  2  4.0   3.5  7.70
# 40           41        308          110                  3  3.5   3.0  8.00
# 110         111        305          108                  5  3.0   3.0  8.48
# 112         113        301          107                  3  3.5   3.5  8.34
# 123         124        308          108                  3  3.5   3.5  8.22
# 124         125        301          106                  4  2.5   3.0  8.47
# 158         159        306          106                  2  2.0   2.5  8.14
# 178         179        309          108                  3  2.5   3.0  8.12
# 181         182        305          107                  2  2.5   2.5  8.42
# ...

# %%
#15.Display records where Chance of Admit &lt; 0.6 or GRE Score &lt; 300.
#data[(data["Chance of Admit"]<0.6) or (data["GRE Score"]<300)]

# %%
#16.Find the top 10 students with the highest GRE Score.
data["GRE Score"].nlargest(10)
# Out:
# 25     340
# 33     340
# 81     340
# 84     340
# 143    340
# 202    340
# 284    340
# 384    340
# 47     339
# 130    339
# Name: GRE Score, dtype: int64

# %%
data.nlargest(10,"GRE Score")
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 25           26        340          120                  5  4.5   4.5  9.60
# 33           34        340          114                  5  4.0   4.0  9.60
# 81           82        340          120                  4  5.0   5.0  9.50
# 84           85        340          115                  5  4.5   4.5  9.45
# 143         144        340          120                  4  4.5   4.0  9.92
# 202         203        340          120                  5  4.5   4.5  9.91
# 284         285        340          112                  4  5.0   4.5  9.66
# 384         385        340          113                  4  5.0   5.0  9.74
# 47           48        339          119                  5  4.5   4.0  9.70
# 130         131        339          114                  5  4.0   4.5  9.76
#
#      Research  Chance of Admit
# 25          1              0.94
# 33          1              0.90
# 81          1              0.96
# ...

# %%
data["GRE Score"].unique()
# Out:
# array([337, 324, 316, 322, 314, 330, 321, 308, 302, 323, 325, 327, 328,
#        307, 311, 317, 319, 318, 303, 312, 334, 336, 340, 298, 295, 310,
#        300, 338, 331, 320, 299, 304, 313, 332, 326, 329, 339, 309, 315,
#        301, 296, 294, 306, 305, 290, 335, 333, 297, 293])

# %%
#17.Display applicants who scored exactly 4.5 in LOR.
#data[data["LOR"]==4.5]

# %%
#18.Select students whose SOP rating lies between 3 and 4 (inclusive).
data[(data['SOP']>3) & (data['SOP']<4)]
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 3             4        322          110                  3  3.5   2.5  8.67
# 9            10        323          108                  3  3.5   3.0  8.60
# 10           11        325          106                  3  3.5   4.0  8.40
# 14           15        311          104                  3  3.5   2.0  8.20
# 15           16        314          105                  3  3.5   2.5  8.30
# ..          ...        ...          ...                ...  ...   ...   ...
# 371         372        324          110                  3  3.5   3.0  9.22
# 380         381        322          104                  3  3.5   4.0  8.84
# 389         390        320          108                  3  3.5   4.0  8.44
# 395         396        324          110                  3  3.5   3.5  9.04
# 398         399        312          103                  3  3.5   4.0  8.78
#
#      Research  Chance of Admit
# ...

# %%
#19.Display all students whose University Rating is either 2 or 3.
data[(data['University Rating']==2) | (data['University Rating']==3)]
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 2             3        316          104                  3  3.0   3.5  8.00
# 3             4        322          110                  3  3.5   2.5  8.67
# 4             5        314          103                  2  2.0   3.0  8.21
# 6             7        321          109                  3  3.0   4.0  8.20
# 7             8        308          101                  2  3.0   4.0  7.90
# ..          ...        ...          ...                ...  ...   ...   ...
# 391         392        318          106                  3  2.0   3.0  8.65
# 393         394        317          104                  2  3.0   3.0  8.76
# 395         396        324          110                  3  3.5   3.5  9.04
# 396         397        325          107                  3  3.0   3.5  9.11
# 398         399        312          103                  3  3.5   4.0  8.78
#
#      Research  Chance of Admit
# ...

# %%
#20.Filter rows where CGPA is an integer value (e.g., 8.0, 9.0).
data[data["CGPA"] % 1 == 0]
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 2             3        316          104                  3  3.0   3.5   8.0
# 8             9        302          102                  1  2.0   1.5   8.0
# 11           12        327          111                  4  4.0   4.5   9.0
# 13           14        307          109                  3  4.0   3.0   8.0
# 17           18        319          106                  3  4.0   3.0   8.0
# 40           41        308          110                  3  3.5   3.0   8.0
# 52           53        334          116                  4  4.0   3.0   8.0
# 54           55        322          110                  3  3.0   3.5   8.0
# 96           97        306          100                  2  3.0   3.0   8.0
# 251         252        316           99                  2  2.5   3.0   9.0
# 289         290        313          109                  3  4.0   3.5   9.0
# ...

# %%
#21.Retrieve records where Chance of Admit is between 0.5 and 0.7.
#data[(data['Chance of Admit']>0.5) & (data['Chance of Admit']<0.7)]

# %%
#22.Select students who scored below average GRE Score.
avg=data["GRE Score"].mean()
data[data['GRE Score']<avg]
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 2             3        316          104                  3  3.0   3.5  8.00
# 4             5        314          103                  2  2.0   3.0  8.21
# 7             8        308          101                  2  3.0   4.0  7.90
# 8             9        302          102                  1  2.0   1.5  8.00
# 13           14        307          109                  3  4.0   3.0  8.00
# ..          ...        ...          ...                ...  ...   ...   ...
# 386         387        302          101                  2  2.5   3.5  7.96
# 387         388        307          105                  2  2.0   3.5  8.10
# 388         389        296           97                  2  1.5   2.0  7.80
# 390         391        314          102                  2  2.0   2.5  8.24
# 398         399        312          103                  3  3.5   4.0  8.78
#
#      Research  Chance of Admit
# ...

# %%
#23.Show all records where TOEFL Score equals the dataset’s maximum TOEFL Score.
max_toefl=data['TOEFL Score'].max()
data[data['TOEFL Score']==max_toefl]
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 25           26        340          120                  5  4.5   4.5  9.60
# 81           82        340          120                  4  5.0   5.0  9.50
# 97           98        331          120                  3  4.0   4.0  8.96
# 143         144        340          120                  4  4.5   4.0  9.92
# 202         203        340          120                  5  4.5   4.5  9.91
# 203         204        334          120                  5  4.0   5.0  9.87
# 212         213        338          120                  4  5.0   5.0  9.66
# 297         298        320          120                  3  4.0   4.5  9.11
#
#      Research  Chance of Admit
# 25          1              0.94
# 81          1              0.96
# 97          1              0.86
# 143         1              0.97
# 202         1              0.97
# 203         1              0.97
# 212         1              0.95
# ...

# %%
#24.Filter students who have both LOR and SOP less than 3.
data[(data['SOP']<3)]
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 4             5        314          103                  2  2.0   3.0  8.21
# 8             9        302          102                  1  2.0   1.5  8.00
# 27           28        298           98                  2  1.5   2.5  7.50
# 28           29        295           93                  1  2.0   2.0  7.20
# 29           30        310           99                  2  1.5   2.0  7.30
# ..          ...        ...          ...                ...  ...   ...   ...
# 386         387        302          101                  2  2.5   3.5  7.96
# 387         388        307          105                  2  2.0   3.5  8.10
# 388         389        296           97                  2  1.5   2.0  7.80
# 390         391        314          102                  2  2.0   2.5  8.24
# 391         392        318          106                  3  2.0   3.0  8.65
#
#      Research  Chance of Admit
# ...

# %%
#25.Retrieve students who have GRE Score divisible by 5.  Add a new column named GRE_to_TOEFL_Ratio = GRE Score / TOEFL Score.
div=data[data["GRE Score"]%5==0]

# %%
div
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 5             6        330          115                  5  4.5   3.0  9.34
# 10           11        325          106                  3  3.5   4.0  8.40
# 21           22        325          114                  4  3.0   2.0  8.40
# 25           26        340          120                  5  4.5   4.5  9.60
# 28           29        295           93                  1  2.0   2.0  7.20
# ..          ...        ...          ...                ...  ...   ...   ...
# 384         385        340          113                  4  5.0   5.0  9.74
# 385         386        335          117                  5  5.0   5.0  9.82
# 389         390        320          108                  3  3.5   4.0  8.44
# 396         397        325          107                  3  3.0   3.5  9.11
# 397         398        330          116                  4  5.0   4.5  9.45
#
#      Research  Chance of Admit
# ...

# %%
data["GRE_to_TOEFL_Ratio"]=div["GRE Score"]/div["TOEFL Score"]

# %%
data
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0             1        337          118                  4  4.5   4.5  9.65
# 1             2        324          107                  4  4.0   4.5  8.87
# 2             3        316          104                  3  3.0   3.5  8.00
# 3             4        322          110                  3  3.5   2.5  8.67
# 4             5        314          103                  2  2.0   3.0  8.21
# ..          ...        ...          ...                ...  ...   ...   ...
# 395         396        324          110                  3  3.5   3.5  9.04
# 396         397        325          107                  3  3.0   3.5  9.11
# 397         398        330          116                  4  5.0   4.5  9.45
# 398         399        312          103                  3  3.5   4.0  8.78
# 399         400        333          117                  4  5.0   4.0  9.66
#
#      Research  Chance of Admit   GRE_to_TOEFL_Ratio
# ...

# %%
#26.Create a new column Admission_Chance_% = Chance of Admit × 100.
#data["Admission_Chance_%"]=data['Chance of Admit']*100

# %%
#27.Rename the column Chance of Admit to Admit_Probability.
data.rename(columns={"Chance of Admit":"Admit_Probability"},inplace=True)

# %%
data
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0             1        337          118                  4  4.5   4.5  9.65
# 1             2        324          107                  4  4.0   4.5  8.87
# 2             3        316          104                  3  3.0   3.5  8.00
# 3             4        322          110                  3  3.5   2.5  8.67
# 4             5        314          103                  2  2.0   3.0  8.21
# ..          ...        ...          ...                ...  ...   ...   ...
# 395         396        324          110                  3  3.5   3.5  9.04
# 396         397        325          107                  3  3.0   3.5  9.11
# 397         398        330          116                  4  5.0   4.5  9.45
# 398         399        312          103                  3  3.5   4.0  8.78
# 399         400        333          117                  4  5.0   4.0  9.66
#
#      Research  Chance of Admit   GRE_to_TOEFL_Ratio
# ...

# %%
#28.Change all column names to lowercase.
data.columns
# Out:
# Index(['Serial No.', 'GRE Score', 'TOEFL Score', 'University Rating', 'SOP',
#        'LOR ', 'CGPA', 'Research', 'Chance of Admit ', 'GRE_to_TOEFL_Ratio'],
#       dtype='object')

# %%
data.columns=data.columns.str.lower()

# %%
data.columns
# Out:
# Index(['serial no.', 'gre score', 'toefl score', 'university rating', 'sop',
#        'lor ', 'cgpa', 'research', 'chance of admit ', 'gre_to_toefl_ratio'],
#       dtype='object')

# %%
data
# Out:
#      serial no.  gre score  toefl score  university rating  sop  lor   cgpa  \
# 0             1        337          118                  4  4.5   4.5  9.65
# 1             2        324          107                  4  4.0   4.5  8.87
# 2             3        316          104                  3  3.0   3.5  8.00
# 3             4        322          110                  3  3.5   2.5  8.67
# 4             5        314          103                  2  2.0   3.0  8.21
# ..          ...        ...          ...                ...  ...   ...   ...
# 395         396        324          110                  3  3.5   3.5  9.04
# 396         397        325          107                  3  3.0   3.5  9.11
# 397         398        330          116                  4  5.0   4.5  9.45
# 398         399        312          103                  3  3.5   4.0  8.78
# 399         400        333          117                  4  5.0   4.0  9.66
#
#      research  chance of admit   gre_to_toefl_ratio
# ...

# %%
#29.Drop the column Serial No..
data.drop("serial no.",axis=1)
# Out:
#      gre score  toefl score  university rating  sop  lor   cgpa  research  \
# 0          337          118                  4  4.5   4.5  9.65         1
# 1          324          107                  4  4.0   4.5  8.87         1
# 2          316          104                  3  3.0   3.5  8.00         1
# 3          322          110                  3  3.5   2.5  8.67         1
# 4          314          103                  2  2.0   3.0  8.21         0
# ..         ...          ...                ...  ...   ...   ...       ...
# 395        324          110                  3  3.5   3.5  9.04         1
# 396        325          107                  3  3.0   3.5  9.11         1
# 397        330          116                  4  5.0   4.5  9.45         1
# 398        312          103                  3  3.5   4.0  8.78         0
# 399        333          117                  4  5.0   4.0  9.66         1
#
#      chance of admit   gre_to_toefl_ratio
# ...

# %%
#30.Round all values in CGPA to one decimal place.
data["cgpa"]=data["cgpa"].round(decimals=1)

# %%
data
# Out:
#      serial no.  gre score  toefl score  university rating  sop  lor   cgpa  \
# 0             1        337          118                  4  4.5   4.5   9.6
# 1             2        324          107                  4  4.0   4.5   8.9
# 2             3        316          104                  3  3.0   3.5   8.0
# 3             4        322          110                  3  3.5   2.5   8.7
# 4             5        314          103                  2  2.0   3.0   8.2
# ..          ...        ...          ...                ...  ...   ...   ...
# 395         396        324          110                  3  3.5   3.5   9.0
# 396         397        325          107                  3  3.0   3.5   9.1
# 397         398        330          116                  4  5.0   4.5   9.4
# 398         399        312          103                  3  3.5   4.0   8.8
# 399         400        333          117                  4  5.0   4.0   9.7
#
#      research  chance of admit   gre_to_toefl_ratio
# ...

# %%
#31.Replace all University Rating values of 5 with 10.
data["university rating"]=data["university rating"].replace(5,10)

# %%
data
# Out:
#      serial no.  gre score  toefl score  university rating  sop  lor   cgpa  \
# 0             1        337          118                  4  4.5   4.5   9.6
# 1             2        324          107                  4  4.0   4.5   8.9
# 2             3        316          104                  3  3.0   3.5   8.0
# 3             4        322          110                  3  3.5   2.5   8.7
# 4             5        314          103                  2  2.0   3.0   8.2
# ..          ...        ...          ...                ...  ...   ...   ...
# 395         396        324          110                  3  3.5   3.5   9.0
# 396         397        325          107                  3  3.0   3.5   9.1
# 397         398        330          116                  4  5.0   4.5   9.4
# 398         399        312          103                  3  3.5   4.0   8.8
# 399         400        333          117                  4  5.0   4.0   9.7
#
#      research  chance of admit   gre_to_toefl_ratio
# ...

# %%
data["university rating"].unique()
# Out:
# array([ 4,  3,  2, 10,  1])

# %%
#32.Convert Research column values from 0/1 to “No”/“Yes”.
data["research"].unique()
# Out:
# array([1, 0])

# %%
data["research"]=data["research"].replace((0,1),("No","Yes"))

# %%
data
# Out:
#      serial no.  gre score  toefl score  university rating  sop  lor   cgpa  \
# 0             1        337          118                  4  4.5   4.5   9.6
# 1             2        324          107                  4  4.0   4.5   8.9
# 2             3        316          104                  3  3.0   3.5   8.0
# 3             4        322          110                  3  3.5   2.5   8.7
# 4             5        314          103                  2  2.0   3.0   8.2
# ..          ...        ...          ...                ...  ...   ...   ...
# 395         396        324          110                  3  3.5   3.5   9.0
# 396         397        325          107                  3  3.0   3.5   9.1
# 397         398        330          116                  4  5.0   4.5   9.4
# 398         399        312          103                  3  3.5   4.0   8.8
# 399         400        333          117                  4  5.0   4.0   9.7
#
#     research  chance of admit   gre_to_toefl_ratio
# ...

# %%
#33.Create a new column GRE_Level = “High” if GRE ≥ 320 else “Low”.
def convert(x):
    if x>=320:
        return "High"
    else:
        return "Low"
data["GRE_Level"]=data["gre score"].apply(convert)

# %%
data
# Out:
#      serial no.  gre score  toefl score  university rating  sop  lor   cgpa  \
# 0             1        337          118                  4  4.5   4.5   9.6
# 1             2        324          107                  4  4.0   4.5   8.9
# 2             3        316          104                  3  3.0   3.5   8.0
# 3             4        322          110                  3  3.5   2.5   8.7
# 4             5        314          103                  2  2.0   3.0   8.2
# ..          ...        ...          ...                ...  ...   ...   ...
# 395         396        324          110                  3  3.5   3.5   9.0
# 396         397        325          107                  3  3.0   3.5   9.1
# 397         398        330          116                  4  5.0   4.5   9.4
# 398         399        312          103                  3  3.5   4.0   8.8
# 399         400        333          117                  4  5.0   4.0   9.7
#
# ...

# %%
#34.Normalize CGPA column to range 0–1 using min-max scaling (without sklearn).
data["Normalized"]=(data["cgpa"]-data["cgpa"].min())/(data["cgpa"].max()-data["cgpa"].min())

# %%
data
# Out:
#      serial no.  gre score  toefl score  university rating  sop  lor   cgpa  \
# 0             1        337          118                  4  4.5   4.5   9.6
# 1             2        324          107                  4  4.0   4.5   8.9
# 2             3        316          104                  3  3.0   3.5   8.0
# 3             4        322          110                  3  3.5   2.5   8.7
# 4             5        314          103                  2  2.0   3.0   8.2
# ..          ...        ...          ...                ...  ...   ...   ...
# 395         396        324          110                  3  3.5   3.5   9.0
# 396         397        325          107                  3  3.0   3.5   9.1
# 397         398        330          116                  4  5.0   4.5   9.4
# 398         399        312          103                  3  3.5   4.0   8.8
# 399         400        333          117                  4  5.0   4.0   9.7
#
# ...

# %%
#35.Increase all TOEFL Score values by 2 points.
data["toefl score"]=data["toefl score"]+2

# %%
data
# Out:
#      serial no.  gre score  toefl score  university rating  sop  lor   cgpa  \
# 0             1        337          120                  4  4.5   4.5   9.6
# 1             2        324          109                  4  4.0   4.5   8.9
# 2             3        316          106                  3  3.0   3.5   8.0
# 3             4        322          112                  3  3.5   2.5   8.7
# 4             5        314          105                  2  2.0   3.0   8.2
# ..          ...        ...          ...                ...  ...   ...   ...
# 395         396        324          112                  3  3.5   3.5   9.0
# 396         397        325          109                  3  3.0   3.5   9.1
# 397         398        330          118                  4  5.0   4.5   9.4
# 398         399        312          105                  3  3.5   4.0   8.8
# 399         400        333          119                  4  5.0   4.0   9.7
#
# ...

# %%
#36.Add a column Weighted_Score = GRE Score * 0.3 + TOEFL Score * 0.2 + CGPA * 0.5.
data["Weighted_Score"]=data["gre score"]*0.3 + data["toefl score"]*0.2 + data["cgpa"]*0.5

# %%
data
# Out:
#      serial no.  gre score  toefl score  university rating  sop  lor   cgpa  \
# 0             1        337          120                  4  4.5   4.5   9.6
# 1             2        324          109                  4  4.0   4.5   8.9
# 2             3        316          106                  3  3.0   3.5   8.0
# 3             4        322          112                  3  3.5   2.5   8.7
# 4             5        314          105                  2  2.0   3.0   8.2
# ..          ...        ...          ...                ...  ...   ...   ...
# 395         396        324          112                  3  3.5   3.5   9.0
# 396         397        325          109                  3  3.0   3.5   9.1
# 397         398        330          118                  4  5.0   4.5   9.4
# 398         399        312          105                  3  3.5   4.0   8.8
# 399         400        333          119                  4  5.0   4.0   9.7
#
# ...

# %%
#37.Drop all duplicate rows if any.
data.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 395    False
# 396    False
# 397    False
# 398    False
# 399    False
# Length: 400, dtype: bool

# %%
data.drop_duplicates(inplace=True)

# %%
data
# Out:
#      serial no.  gre score  toefl score  university rating  sop  lor   cgpa  \
# 0             1        337          120                  4  4.5   4.5   9.6
# 1             2        324          109                  4  4.0   4.5   8.9
# 2             3        316          106                  3  3.0   3.5   8.0
# 3             4        322          112                  3  3.5   2.5   8.7
# 4             5        314          105                  2  2.0   3.0   8.2
# ..          ...        ...          ...                ...  ...   ...   ...
# 395         396        324          112                  3  3.5   3.5   9.0
# 396         397        325          109                  3  3.0   3.5   9.1
# 397         398        330          118                  4  5.0   4.5   9.4
# 398         399        312          105                  3  3.5   4.0   8.8
# 399         400        333          119                  4  5.0   4.0   9.7
#
# ...

# %%
#38.Replace all SOP values less than 2 with the mean SOP.
sop_mean=data["sop"].mean()

# %%
sop_mean
# Out:
# np.float64(3.4)

# %%
data["sop"].unique()
# Out:
# array([4.5, 4. , 3. , 3.5, 2. , 5. , 1.5, 1. , 2.5])

# %%
def sop_re(x):
    if x<2:
        return sop_mean
    else:
        return x

# %%
data['sop']=data['sop'].apply(sop_re)

# %%
data["sop"].unique()
# Out:
# array([4.5, 4. , 3. , 3.5, 2. , 5. , 3.4, 2.5])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   serial no.          400 non-null    int64
#  1   gre score           400 non-null    int64
#  2   toefl score         400 non-null    int64
#  3   university rating   400 non-null    int64
#  4   sop                 400 non-null    float64
#  5   lor                 400 non-null    float64
#  6   cgpa                400 non-null    float64
#  7   research            400 non-null    object
#  8   chance of admit     400 non-null    float64
#  9   gre_to_toefl_ratio  84 non-null     float64
#  10  GRE_Level           400 non-null    object
#  11  Normalized          400 non-null    float64
#  12  Weighted_Score      400 non-null    float64
# dtypes: float64(7), int64(4), object(2)
# memory usage: 40.8+ KB

# %%
#39.Create a new column combining University Rating and Research (e.g.,&quot;Rating-Research&quot;).
data["Rating-Research"]=data["university rating"].astype('str') +" "+ data["research"]

# %%
data
# Out:
#      serial no.  gre score  toefl score  university rating  sop  lor   cgpa  \
# 0             1        337          120                  4  4.5   4.5   9.6
# 1             2        324          109                  4  4.0   4.5   8.9
# 2             3        316          106                  3  3.0   3.5   8.0
# 3             4        322          112                  3  3.5   2.5   8.7
# 4             5        314          105                  2  2.0   3.0   8.2
# ..          ...        ...          ...                ...  ...   ...   ...
# 395         396        324          112                  3  3.5   3.5   9.0
# 396         397        325          109                  3  3.0   3.5   9.1
# 397         398        330          118                  4  5.0   4.5   9.4
# 398         399        312          105                  3  3.5   4.0   8.8
# 399         400        333          119                  4  5.0   4.0   9.7
#
# ...

# %%
#40.Convert Chance of Admit to categorical bins: “Low”, “Medium”, “High”.

# %%
#41.Add a constant column Country with value “India”.
data["Country"]="India"

# %%
data
# Out:
#      serial no.  gre score  toefl score  university rating  sop  lor   cgpa  \
# 0             1        337          120                  4  4.5   4.5   9.6
# 1             2        324          109                  4  4.0   4.5   8.9
# 2             3        316          106                  3  3.0   3.5   8.0
# 3             4        322          112                  3  3.5   2.5   8.7
# 4             5        314          105                  2  2.0   3.0   8.2
# ..          ...        ...          ...                ...  ...   ...   ...
# 395         396        324          112                  3  3.5   3.5   9.0
# 396         397        325          109                  3  3.0   3.5   9.1
# 397         398        330          118                  4  5.0   4.5   9.4
# 398         399        312          105                  3  3.5   4.0   8.8
# 399         400        333          119                  4  5.0   4.0   9.7
#
# ...

# %%
#42.Reorder columns so that Chance of Admit comes first.
#new_order=['chance of admit','gre score','toefl score','university rating','sop','lor','research','serial no.']
#new=data[new_order]

# %%
#43.Replace values in LOR column where rating is 5 with 4.9.
#data["lor"]=data['lor'].replace(5,4.9)

# %%
#44.Convert all float columns to integers (after rounding).
data1=[]
data1=pd.DataFrame(data1)
data1["sop"]=data["sop"].astype("int")
data1["cgpa"]=data["cgpa"].astype("int")
data1["Weighted_Score"]=data["Weighted_Score"].astype("int")

# %%
data1
# Out:
#      sop  cgpa  Weighted_Score
# 0      4     9             129
# 1      4     8             123
# 2      3     8             120
# 3      3     8             123
# 4      2     8             119
# ..   ...   ...             ...
# 395    3     9             124
# 396    3     9             123
# 397    5     9             127
# 398    3     8             119
# 399    5     9             128
#
# [400 rows x 3 columns]

# %%
#45.Replace CGPA values above 9.5 with 9.5.
def cgpa(x):
    if x>9.5:
        return 9.5
    else:
        return x
new_data=data
new_data["cgpa"].apply(cgpa)
# Out:
# 0      9.5
# 1      8.9
# 2      8.0
# 3      8.7
# 4      8.2
#       ...
# 395    9.0
# 396    9.1
# 397    9.4
# 398    8.8
# 399    9.5
# Name: cgpa, Length: 400, dtype: float64

# %%
new_data
# Out:
#      serial no.  gre score  toefl score  university rating  sop  lor   cgpa  \
# 0             1        337          120                  4  4.5   4.5   9.6
# 1             2        324          109                  4  4.0   4.5   8.9
# 2             3        316          106                  3  3.0   3.5   8.0
# 3             4        322          112                  3  3.5   2.5   8.7
# 4             5        314          105                  2  2.0   3.0   8.2
# ..          ...        ...          ...                ...  ...   ...   ...
# 395         396        324          112                  3  3.5   3.5   9.0
# 396         397        325          109                  3  3.0   3.5   9.1
# 397         398        330          118                  4  5.0   4.5   9.4
# 398         399        312          105                  3  3.5   4.0   8.8
# 399         400        333          119                  4  5.0   4.0   9.7
#
# ...

# %%
#46.Apply a lambda function to square all SOP values.
new_data["sop"].apply(lambda x:x*x)
# Out:
# 0      20.25
# 1      16.00
# 2       9.00
# 3      12.25
# 4       4.00
#        ...
# 395    12.25
# 396     9.00
# 397    25.00
# 398    12.25
# 399    25.00
# Name: sop, Length: 400, dtype: float64

# %%
new_data
# Out:
#      serial no.  gre score  toefl score  university rating  sop  lor   cgpa  \
# 0             1        337          120                  4  4.5   4.5   9.6
# 1             2        324          109                  4  4.0   4.5   8.9
# 2             3        316          106                  3  3.0   3.5   8.0
# 3             4        322          112                  3  3.5   2.5   8.7
# 4             5        314          105                  2  2.0   3.0   8.2
# ..          ...        ...          ...                ...  ...   ...   ...
# 395         396        324          112                  3  3.5   3.5   9.0
# 396         397        325          109                  3  3.0   3.5   9.1
# 397         398        330          118                  4  5.0   4.5   9.4
# 398         399        312          105                  3  3.5   4.0   8.8
# 399         400        333          119                  4  5.0   4.0   9.7
#
# ...

# %%
#47.Add a column GRE_Category = “Below Avg”, “Avg”, “Above Avg” based on mean GRE.
mean=new_data["gre score"].mean()
def category(x):
    if x<mean:
        return "Below Avg"
    elif x==mean:
        return "Avg"
    else:
        return "Above Avg"
new_data["gre score"].apply(category)
# Out:
# 0      Above Avg
# 1      Above Avg
# 2      Below Avg
# 3      Above Avg
# 4      Below Avg
#          ...
# 395    Above Avg
# 396    Above Avg
# 397    Above Avg
# 398    Below Avg
# 399    Above Avg
# Name: gre score, Length: 400, dtype: object

# %%
new_data
# Out:
#      serial no.  gre score  toefl score  university rating  sop  lor   cgpa  \
# 0             1        337          120                  4  4.5   4.5   9.6
# 1             2        324          109                  4  4.0   4.5   8.9
# 2             3        316          106                  3  3.0   3.5   8.0
# 3             4        322          112                  3  3.5   2.5   8.7
# 4             5        314          105                  2  2.0   3.0   8.2
# ..          ...        ...          ...                ...  ...   ...   ...
# 395         396        324          112                  3  3.5   3.5   9.0
# 396         397        325          109                  3  3.0   3.5   9.1
# 397         398        330          118                  4  5.0   4.5   9.4
# 398         399        312          105                  3  3.5   4.0   8.8
# 399         400        333          119                  4  5.0   4.0   9.7
#
# ...

# %%
#48.Standardize column names to snake_case (lowercase, replace spaces with _).
new_data.columns
# Out:
# Index(['serial no.', 'gre score', 'toefl score', 'university rating', 'sop',
#        'lor ', 'cgpa', 'research', 'chance of admit ', 'gre_to_toefl_ratio',
#        'GRE_Level', 'Normalized', 'Weighted_Score', 'Rating-Research',
#        'Country'],
#       dtype='object')

# %%
new_data.columns=new_data.columns.str.lower()

# %%
new_data.columns=new_data.columns.str.replace(" ","_")

# %%
#49.Create a new column showing difference between TOEFL Score and GRE Score/4.
new_data["difference"]=data['gre_score'] - new_data["toefl_score"]

# %%
data.columns
# Out:
# Index(['serial_no.', 'gre_score', 'toefl_score', 'university_rating', 'sop',
#        'lor_', 'cgpa', 'research', 'chance_of_admit_', 'gre_to_toefl_ratio',
#        'gre_level', 'normalized', 'weighted_score', 'rating-research',
#        'country', 'difference'],
#       dtype='object')

# %%
new_data.columns
# Out:
# Index(['serial_no.', 'gre_score', 'toefl_score', 'university_rating', 'sop',
#        'lor_', 'cgpa', 'research', 'chance_of_admit_', 'gre_to_toefl_ratio',
#        'gre_level', 'normalized', 'weighted_score', 'rating-research',
#        'country', 'difference'],
#       dtype='object')

# %%
data['lor_']
# Out:
# 0      4.5
# 1      4.5
# 2      3.5
# 3      2.5
# 4      3.0
#       ...
# 395    3.5
# 396    3.5
# 397    4.5
# 398    4.0
# 399    4.0
# Name: lor_, Length: 400, dtype: float64

# %%
#50.Find the average GRE Score for each University Rating.
data["university_rating"].unique()
# Out:
# array([ 4,  3,  2, 10,  1])

# %%
data["university_rating"].value_counts()
# Out:
# university_rating
# 3     133
# 2     107
# 4      74
# 10     60
# 1      26
# Name: count, dtype: int64

# %%
for_3=data[data["university_rating"]==3]

# %%
for_3["gre_score"].mean()
# Out:
# np.float64(315.9548872180451)

# %%
for_2=data[data["university_rating"]==2]
for_2["gre_score"].mean()
# Out:
# np.float64(309.1775700934579)

# %%
for_4=data[data["university_rating"]==4]
for_4["gre_score"].mean()
# Out:
# np.float64(324.8243243243243)

# %%
for_10=data[data["university_rating"]==10]
for_10["gre_score"].mean()
# Out:
# np.float64(328.3333333333333)

# %%
for_1=data[data["university_rating"]==1]
for_1["gre_score"].mean()
# Out:
# np.float64(303.15384615384613)

# %%
#51.Get the mean CGPA for students with and without research.
with_research=data[data["research"]=="Yes"]
with_research['cgpa'].mean()
# Out:
# np.float64(8.88082191780822)

# %%
without_research=data[data["research"]=="No"]
without_research['cgpa'].mean()
# Out:
# np.float64(8.256906077348066)

# %%
#52.Count how many applicants have each University Rating.
data["university_rating"].value_counts()
# Out:
# university_rating
# 3     133
# 2     107
# 4      74
# 10     60
# 1      26
# Name: count, dtype: int64

# %%
#53.Find the total number of students in each Research category.
data["research"].value_counts()
# Out:
# research
# Yes    219
# No     181
# Name: count, dtype: int64

# %%
#54.Group by University Rating and show average TOEFL Score.
g=data.groupby("university_rating")['toefl_score'].mean()

# %%
g
# Out:
# university_rating
# 1     101.076923
# 2     105.523364
# 3     108.887218
# 4     113.824324
# 10    115.666667
# Name: toefl_score, dtype: float64

# %%
#55.Get the maximum Chance of Admit for each Research group.
r_group=data.groupby("research")['chance_of_admit_'].max()

# %%
r_group
# Out:
# research
# No     0.89
# Yes    0.97
# Name: chance_of_admit_, dtype: float64

# %%
#56.Find minimum SOP value per University Rating.
u_group=data.groupby("university_rating")['sop'].min()

# %%
u_group
# Out:
# university_rating
# 1     2.0
# 2     2.0
# 3     2.0
# 4     2.0
# 10    3.0
# Name: sop, dtype: float64

# %%
gre=data[data["gre_score"]>=320]

# %%
#57.Count number of students with GRE Score ≥ 320 for each University Rating.
u_group_gre_score=gre.groupby("university_rating")['university_rating'].value_counts()

# %%
u_group_gre_score
# Out:
# university_rating
# 2     11
# 3     49
# 4     59
# 10    56
# Name: count, dtype: int64

# %%
#58.Calculate median CGPA grouped by Research.
group_r=data.groupby("research")['cgpa'].median()

# %%
group_r
# Out:
# research
# No     8.3
# Yes    9.0
# Name: cgpa, dtype: float64

# %%
#59.Get the number of students per combination of University Rating and Research.
group_u_and_r=data.groupby(["university_rating",'research'])["university_rating"].value_counts()

# %%
group_u_and_r
# Out:
# university_rating  research
# 1                  No          21
#                    Yes          5
# 2                  No          75
#                    Yes         32
# 3                  No          62
#                    Yes         71
# 4                  No          15
#                    Yes         59
# 10                 No           8
#                    Yes         52
# Name: count, dtype: int64

# %%
#60.Find the mean GRE Score grouped by both Research and SOP.
group_r_and_s=data.groupby(['research','sop'])["gre_score"].mean()

# %%
group_r_and_s
# Out:
# research  sop
# No        2.0    308.481481
#           2.5    307.696970
#           3.0    311.352941
#           3.4    301.409091
#           3.5    310.925926
#           4.0    311.476190
#           4.5    320.833333
#           5.0    306.400000
# Yes       2.0    309.166667
#           2.5    315.571429
#           3.0    316.800000
#           3.4    309.500000
#           3.5    319.023256
#           4.0    325.653061
#           4.5    328.000000
#           5.0    330.218750
# Name: gre_score, dtype: float64

# %%
#61.For each University Rating, find both min and max TOEFL Score.
group_u=data.groupby("university_rating")

# %%
group_u['toefl_score'].min()
# Out:
# university_rating
# 1      94
# 2      97
# 3      99
# 4     102
# 10    105
# Name: toefl_score, dtype: int64

# %%
group_u['toefl_score'].max()
# Out:
# university_rating
# 1     111
# 2     120
# 3     122
# 4     122
# 10    122
# Name: toefl_score, dtype: int64

# %%
#62.Display number of unique GRE Score values per University Rating.
group_u["gre_score"].unique()
# Out:
# university_rating
# 1     [302, 295, 300, 304, 294, 318, 297, 315, 298, ...
# 2     [314, 308, 298, 310, 300, 299, 307, 316, 313, ...
# 3     [316, 322, 321, 323, 325, 307, 311, 314, 317, ...
# 4     [337, 324, 327, 328, 325, 338, 332, 334, 314, ...
# 10    [330, 328, 334, 336, 340, 322, 331, 320, 326, ...
# Name: gre_score, dtype: object

# %%
#63.Find the average of all numeric columns grouped by Research.
group_r=data.groupby('research')

# %%
group_r["gre_score"].mean()
# Out:
# research
# No     309.491713
# Yes    322.853881
# Name: gre_score, dtype: float64

# %%
group_r["toefl_score"].mean()
# Out:
# research
# No     106.143646
# Yes    112.109589
# Name: toefl_score, dtype: float64

# %%
group_r["university_rating"].mean()
# Out:
# research
# No     2.745856
# Yes    4.739726
# Name: university_rating, dtype: float64

# %%
group_r["sop"].mean()
# Out:
# research
# No     3.153591
# Yes    3.842922
# Name: sop, dtype: float64

# %%
group_r["lor_"].mean()
# Out:
# research
# No     3.060773
# Yes    3.776256
# Name: lor_, dtype: float64

# %%
group_r["cgpa"].mean()
# Out:
# research
# No     8.256906
# Yes    8.880822
# Name: cgpa, dtype: float64

# %%
group_r["chance_of_admit_"].mean()
# Out:
# research
# No     0.637680
# Yes    0.795982
# Name: chance_of_admit_, dtype: float64

# %%
data
# Out:
#      serial_no.  gre_score  toefl_score  university_rating  sop  lor_  cgpa  \
# 0             1        337          120                  4  4.5   4.5   9.6
# 1             2        324          109                  4  4.0   4.5   8.9
# 2             3        316          106                  3  3.0   3.5   8.0
# 3             4        322          112                  3  3.5   2.5   8.7
# 4             5        314          105                  2  2.0   3.0   8.2
# ..          ...        ...          ...                ...  ...   ...   ...
# 395         396        324          112                  3  3.5   3.5   9.0
# 396         397        325          109                  3  3.0   3.5   9.1
# 397         398        330          118                  4  5.0   4.5   9.4
# 398         399        312          105                  3  3.5   4.0   8.8
# 399         400        333          119                  4  5.0   4.0   9.7
#
# ...

# %%
#64.Get the count of applicants having CGPA &gt; 9 grouped by Research.
data[data["cgpa"]>9].groupby("research")["cgpa"].value_counts()
# Out:
# research  cgpa
# No        9.1      5
#           9.7      1
# Yes       9.1     21
#           9.2     21
#           9.4     16
#           9.3      9
#           9.5      7
#           9.8      7
#           9.6      6
#           9.7      6
#           9.9      3
# Name: count, dtype: int64

# %%
#65.For each SOP rating, find mean Chance of Admit.
group_sop=data.groupby("sop")

# %%
group_sop["chance_of_admit_"].mean()
# Out:
# sop
# 2.0    0.602727
# 2.5    0.651277
# 3.0    0.683594
# 3.4    0.525385
# 3.5    0.713571
# 4.0    0.778000
# 4.5    0.843962
# 5.0    0.883514
# Name: chance_of_admit_, dtype: float64

# %%
#66.Calculate mean and std deviation of GRE Score per University Rating.
group_u["gre_score"].mean()
# Out:
# university_rating
# 1     303.153846
# 2     309.177570
# 3     315.954887
# 4     324.824324
# 10    328.333333
# Name: gre_score, dtype: float64

# %%
group_u["gre_score"].std()
# Out:
# university_rating
# 1     7.918042
# 2     8.503954
# 3     7.748768
# 4     9.917962
# 10    8.524475
# Name: gre_score, dtype: float64

# %%
group_u["gre_score"].agg(['mean','std'])
# Out:
#                          mean       std
# university_rating
# 1                  303.153846  7.918042
# 2                  309.177570  8.503954
# 3                  315.954887  7.748768
# 4                  324.824324  9.917962
# 10                 328.333333  8.524475

# %%
#67.Get total number of students whose Chance of Admit &gt; 0.8 per Research.
data[data["chance_of_admit_"]>0.8].groupby("research")["chance_of_admit_"].value_counts()
# Out:
# research  chance_of_admit_
# No        0.82                 2
#           0.81                 1
#           0.83                 1
#           0.85                 1
#           0.86                 1
#           0.87                 1
#           0.89                 1
# Yes       0.94                12
#           0.84                 9
#           0.93                 9
#           0.89                 8
#           0.90                 8
#           0.81                 7
#           0.86                 7
#           0.91                 7
#           0.96                 7
#           0.82                 6
#           0.92                 6
#           0.85                 5
#           0.87                 4
#           0.88                 4
#           0.95                 4
#           0.97                 4
#           0.83                 2
# Name: count, dtype: int64

# %%
#68.Find number of records for each distinct combination of University Rating, SOP, and LOR.
data.groupby(["university_rating",'sop','lor_']).size()
# Out:
# university_rating  sop  lor_
# 1                  2.0  1.5      1
#                         2.0      3
#                         2.5      2
#                         3.0      1
#                    2.5  3.0      2
#                                 ..
# 10                 4.5  5.0      3
#                    5.0  3.5      1
#                         4.0      3
#                         4.5      7
#                         5.0     13
# Length: 121, dtype: int64

# %%
#69.Get the highest GRE Score among students with Research = 0.
gre=data[data["research"]=="No"]

# %%
gre
# Out:
#      serial_no.  gre_score  toefl_score  university_rating  sop  lor_  cgpa  \
# 4             5        314          105                  2  2.0   3.0   8.2
# 7             8        308          103                  2  3.0   4.0   7.9
# 8             9        302          104                  1  2.0   1.5   8.0
# 9            10        323          110                  3  3.5   3.0   8.6
# 15           16        314          107                  3  3.5   2.5   8.3
# ..          ...        ...          ...                ...  ...   ...   ...
# 388         389        296           99                  2  3.4   2.0   7.8
# 390         391        314          104                  2  2.0   2.5   8.2
# 391         392        318          108                  3  2.0   3.0   8.6
# 393         394        317          106                  2  3.0   3.0   8.8
# 398         399        312          105                  3  3.5   4.0   8.8
#
# ...

# %%
gre["gre_score"].max()
# Out:
# 339

# %%
#70.Find how many students in each Research category have CGPA &gt; 9.
data[data["cgpa"]>9].groupby("research")["cgpa"].value_counts()
# Out:
# research  cgpa
# No        9.1      5
#           9.7      1
# Yes       9.1     21
#           9.2     21
#           9.4     16
#           9.3      9
#           9.5      7
#           9.8      7
#           9.6      6
#           9.7      6
#           9.9      3
# Name: count, dtype: int64

# %%
#71.Calculate total GRE Score for each University Rating.
group_u["gre_score"].sum()
# Out:
# university_rating
# 1      7882
# 2     33082
# 3     42022
# 4     24037
# 10    19700
# Name: gre_score, dtype: int64

# %%
#72.Find mean Chance of Admit for each unique LOR score.
group_lor=data.groupby('lor_')

# %%
group_lor["chance_of_admit_"].mean()
# Out:
# lor_
# 1.0    0.420000
# 1.5    0.567143
# 2.0    0.563158
# 2.5    0.632564
# 3.0    0.674235
# 3.5    0.721096
# 4.0    0.776364
# 4.5    0.858444
# 5.0    0.883429
# Name: chance_of_admit_, dtype: float64

# %%
#73.Get number of students with same TOEFL Score grouped by that score.
group_toefl=data.groupby("toefl_score")

# %%
group_toefl["toefl_score"].value_counts()
# Out:
# toefl_score
# 94      1
# 95      2
# 96      1
# 97      2
# 98      4
# 99      6
# 100     9
# 101    18
# 102    19
# 103    11
# 104    17
# 105    16
# 106    25
# 107    28
# 108    24
# 109    26
# 110    17
# 111    17
# 112    37
# 113    17
# 114    21
# 115    14
# 116    15
# 117     9
# 118    11
# 119     7
# 120     9
# 121     9
# 122     8
# Name: count, dtype: int64

# %%
#74.Find the group with the maximum average Chance of Admit.
gr=data.groupby('chance_of_admit_')

# %%
gr["chance_of_admit_"].mean()
# Out:
# chance_of_admit_
# 0.34    0.34
# 0.36    0.36
# 0.38    0.38
# 0.39    0.39
# 0.42    0.42
# 0.43    0.43
# 0.44    0.44
# 0.45    0.45
# 0.46    0.46
# 0.47    0.47
# 0.48    0.48
# 0.49    0.49
# 0.50    0.50
# 0.51    0.51
# 0.52    0.52
# 0.53    0.53
# 0.54    0.54
# 0.55    0.55
# 0.56    0.56
# 0.57    0.57
# 0.58    0.58
# 0.59    0.59
# 0.60    0.60
# 0.61    0.61
# 0.62    0.62
# 0.63    0.63
# 0.64    0.64
# 0.65    0.65
# 0.66    0.66
# 0.67    0.67
# 0.68    0.68
# 0.69    0.69
# 0.70    0.70
# 0.71    0.71
# 0.72    0.72
# 0.73    0.73
# 0.74    0.74
# 0.75    0.75
# 0.76    0.76
# 0.77    0.77
# 0.78    0.78
# 0.79    0.79
# 0.80    0.80
# 0.81    0.81
# 0.82    0.82
# 0.83    0.83
# 0.84    0.84
# 0.85    0.85
# 0.86    0.86
# 0.87    0.87
# 0.88    0.88
# 0.89    0.89
# 0.90    0.90
# 0.91    0.91
# 0.92    0.92
# 0.93    0.93
# 0.94    0.94
# 0.95    0.95
# 0.96    0.96
# 0.97    0.97
# Name: chance_of_admit_, dtype: float64

# %%
#75.Sort dataset by GRE Score in descending order.
data.sort_values(by="gre_score",ascending=False)
# Out:
#      serial_no.  gre_score  toefl_score  university_rating  sop  lor_  cgpa  \
# 25           26        340          122                 10  4.5   4.5   9.6
# 33           34        340          116                 10  4.0   4.0   9.6
# 81           82        340          122                  4  5.0   5.0   9.5
# 84           85        340          117                 10  4.5   4.5   9.4
# 284         285        340          114                  4  5.0   4.5   9.7
# ..          ...        ...          ...                ...  ...   ...   ...
# 272         273        294           97                  1  3.4   1.5   7.6
# 79           80        294           95                  1  3.4   2.0   7.4
# 168         169        293           99                  2  2.0   4.0   7.8
# 117         118        290          106                  4  2.0   2.5   7.5
# 377         378        290          102                  1  3.4   2.0   7.6
#
# ...

# %%
#76.Sort by University Rating, then CGPA.
data.sort_values(by="university_rating")
# Out:
#      serial_no.  gre_score  toefl_score  university_rating  sop  lor_  cgpa  \
# 28           29        295           95                  1  2.0   2.0   7.2
# 368         369        298           94                  1  2.0   2.0   7.9
# 369         370        301          100                  1  2.0   3.0   8.0
# 378         379        303          100                  1  2.0   2.5   7.6
# 377         378        290          102                  1  3.4   2.0   7.6
# ..          ...        ...          ...                ...  ...   ...   ...
# 131         132        303          107                 10  5.0   4.5   8.6
# 130         131        339          116                 10  4.0   4.5   9.8
# 129         130        333          120                 10  5.0   5.0   9.4
# 132         133        309          107                 10  3.5   3.5   8.6
# 337         338        332          120                 10  5.0   5.0   9.5
#
# ...

# %%
data.sort_values(by="cgpa")
# Out:
#      serial_no.  gre_score  toefl_score  university_rating  sop  lor_  cgpa  \
# 58           59        300          101                  1  3.0   2.0   6.8
# 348         349        302          101                  1  2.0   2.0   7.2
# 28           29        295           95                  1  2.0   2.0   7.2
# 347         348        299           96                  1  3.4   1.0   7.3
# 344         345        295           98                  2  3.4   2.0   7.3
# ..          ...        ...          ...                ...  ...   ...   ...
# 24           25        336          121                 10  4.0   3.5   9.8
# 71           72        336          114                 10  5.0   5.0   9.8
# 202         203        340          122                 10  4.5   4.5   9.9
# 143         144        340          122                  4  4.5   4.0   9.9
# 203         204        334          122                 10  4.0   5.0   9.9
#
# ...

# %%
#77.Display top 5 rows with highest Chance of Admit.
data.nlargest(5,"chance_of_admit_")
# Out:
#      serial_no.  gre_score  toefl_score  university_rating  sop  lor_  cgpa  \
# 24           25        336          121                 10  4.0   3.5   9.8
# 143         144        340          122                  4  4.5   4.0   9.9
# 202         203        340          122                 10  4.5   4.5   9.9
# 203         204        334          122                 10  4.0   5.0   9.9
# 71           72        336          114                 10  5.0   5.0   9.8
#
#     research  chance_of_admit_  gre_to_toefl_ratio gre_level  normalized  \
# 24       Yes              0.97                 NaN      High    0.967742
# 143      Yes              0.97            2.833333      High    1.000000
# 202      Yes              0.97            2.833333      High    1.000000
# 203      Yes              0.97                 NaN      High    1.000000
# 71       Yes              0.96                 NaN      High    0.967742
#
#      weighted_score rating-research country  difference
# ...

# %%
#78.Sort values by TOEFL Score ascending.
data.sort_values("toefl_score")
# Out:
#      serial_no.  gre_score  toefl_score  university_rating  sop  lor_  cgpa  \
# 368         369        298           94                  1  2.0   2.0   7.9
# 79           80        294           95                  1  3.4   2.0   7.4
# 28           29        295           95                  1  2.0   2.0   7.2
# 347         348        299           96                  1  3.4   1.0   7.3
# 78           79        296           97                  2  3.0   2.0   7.5
# ..          ...        ...          ...                ...  ...   ...   ...
# 202         203        340          122                 10  4.5   4.5   9.9
# 212         213        338          122                  4  5.0   5.0   9.7
# 203         204        334          122                 10  4.0   5.0   9.9
# 81           82        340          122                  4  5.0   5.0   9.5
# 25           26        340          122                 10  4.5   4.5   9.6
#
# ...

# %%
#79.Set Serial No. as index.
data.set_index("serial_no.",inplace=True)

# %%
data
# Out:
#             gre_score  toefl_score  university_rating  sop  lor_  cgpa  \
# serial_no.
# 1                 337          120                  4  4.5   4.5   9.6
# 2                 324          109                  4  4.0   4.5   8.9
# 3                 316          106                  3  3.0   3.5   8.0
# 4                 322          112                  3  3.5   2.5   8.7
# 5                 314          105                  2  2.0   3.0   8.2
# ...               ...          ...                ...  ...   ...   ...
# 396               324          112                  3  3.5   3.5   9.0
# 397               325          109                  3  3.0   3.5   9.1
# 398               330          118                  4  5.0   4.5   9.4
# 399               312          105                  3  3.5   4.0   8.8
# 400               333          119                  4  5.0   4.0   9.7
#
#            research  chance_of_admit_  gre_to_toefl_ratio gre_level  \
# serial_no.
# ...

# %%
#80.Reset index to default.
data=data.reset_index()

# %%
#81.Sort dataset by multiple columns: Research and Chance of Admit.
data.replace(["Yes","No"],[1,0])
# Out:
#      serial_no.  gre_score  toefl_score  university_rating  sop  lor_  cgpa  \
# 0             1        337          120                  4  4.5   4.5   9.6
# 1             2        324          109                  4  4.0   4.5   8.9
# 2             3        316          106                  3  3.0   3.5   8.0
# 3             4        322          112                  3  3.5   2.5   8.7
# 4             5        314          105                  2  2.0   3.0   8.2
# ..          ...        ...          ...                ...  ...   ...   ...
# 395         396        324          112                  3  3.5   3.5   9.0
# 396         397        325          109                  3  3.0   3.5   9.1
# 397         398        330          118                  4  5.0   4.5   9.4
# 398         399        312          105                  3  3.5   4.0   8.8
# 399         400        333          119                  4  5.0   4.0   9.7
#
# ...

# %%
data.sort_values(by=["research","chance_of_admit_"])
# Out:
#      serial_no.  gre_score  toefl_score  university_rating  sop  lor_  cgpa  \
# 92           93        298          100                  2  4.0   3.0   8.0
# 376         377        297           98                  2  2.5   2.0   7.4
# 94           95        303          101                  3  2.0   2.5   7.7
# 91           92        299           99                  3  5.0   3.5   7.7
# 375         376        304          103                  2  2.0   2.5   7.7
# ..          ...        ...          ...                ...  ...   ...   ...
# 385         386        335          119                 10  5.0   5.0   9.8
# 24           25        336          121                 10  4.0   3.5   9.8
# 143         144        340          122                  4  4.5   4.0   9.9
# 202         203        340          122                 10  4.5   4.5   9.9
# 203         204        334          122                 10  4.0   5.0   9.9
#
# ...

# %%
#82.Sort all applicants by CGPA then GRE Score descending.
data.sort_values(by="cgpa")
# Out:
#      serial_no.  gre_score  toefl_score  university_rating  sop  lor_  cgpa  \
# 58           59        300          101                  1  3.0   2.0   6.8
# 348         349        302          101                  1  2.0   2.0   7.2
# 28           29        295           95                  1  2.0   2.0   7.2
# 347         348        299           96                  1  3.4   1.0   7.3
# 344         345        295           98                  2  3.4   2.0   7.3
# ..          ...        ...          ...                ...  ...   ...   ...
# 24           25        336          121                 10  4.0   3.5   9.8
# 71           72        336          114                 10  5.0   5.0   9.8
# 202         203        340          122                 10  4.5   4.5   9.9
# 143         144        340          122                  4  4.5   4.0   9.9
# 203         204        334          122                 10  4.0   5.0   9.9
#
# ...

# %%
data.sort_values(by="gre_score",ascending=False)
# Out:
#      serial_no.  gre_score  toefl_score  university_rating  sop  lor_  cgpa  \
# 25           26        340          122                 10  4.5   4.5   9.6
# 33           34        340          116                 10  4.0   4.0   9.6
# 81           82        340          122                  4  5.0   5.0   9.5
# 84           85        340          117                 10  4.5   4.5   9.4
# 284         285        340          114                  4  5.0   4.5   9.7
# ..          ...        ...          ...                ...  ...   ...   ...
# 272         273        294           97                  1  3.4   1.5   7.6
# 79           80        294           95                  1  3.4   2.0   7.4
# 168         169        293           99                  2  2.0   4.0   7.8
# 117         118        290          106                  4  2.0   2.5   7.5
# 377         378        290          102                  1  3.4   2.0   7.6
#
# ...

# %%
#83.Retrieve bottom 10 rows after sorting by GRE Score.
gre_s=data.sort_values(by="gre_score")

# %%
gre_s.tail(10)
# Out:
#      serial_no.  gre_score  toefl_score  university_rating  sop  lor_  cgpa  \
# 148         149        339          118                  4  4.0   3.5   9.8
# 47           48        339          121                 10  4.5   4.0   9.7
# 33           34        340          116                 10  4.0   4.0   9.6
# 81           82        340          122                  4  5.0   5.0   9.5
# 84           85        340          117                 10  4.5   4.5   9.4
# 143         144        340          122                  4  4.5   4.0   9.9
# 202         203        340          122                 10  4.5   4.5   9.9
# 384         385        340          115                  4  5.0   5.0   9.7
# 284         285        340          114                  4  5.0   4.5   9.7
# 25           26        340          122                 10  4.5   4.5   9.6
#
#      research  chance_of_admit_  gre_to_toefl_ratio gre_level  normalized  \
# ...

# %%
#84.Use .nlargest() to get top 5 CGPA values.
data.nlargest(5,"cgpa")
# Out:
#      serial_no.  gre_score  toefl_score  university_rating  sop  lor_  cgpa  \
# 143         144        340          122                  4  4.5   4.0   9.9
# 202         203        340          122                 10  4.5   4.5   9.9
# 203         204        334          122                 10  4.0   5.0   9.9
# 24           25        336          121                 10  4.0   3.5   9.8
# 34           35        331          114                 10  4.0   5.0   9.8
#
#      research  chance_of_admit_  gre_to_toefl_ratio gre_level  normalized  \
# 143         1              0.97            2.833333      High    1.000000
# 202         1              0.97            2.833333      High    1.000000
# 203         1              0.97                 NaN      High    1.000000
# 24          1              0.97                 NaN      High    0.967742
# 34          1              0.94                 NaN      High    0.967742
#
#      weighted_score rating-research country  difference
# ...

# %%
#85.Use .nsmallest() to get lowest 5 TOEFL Score values.
data.nsmallest(5,'toefl_score')
# Out:
#      serial_no.  gre_score  toefl_score  university_rating  sop  lor_  cgpa  \
# 368         369        298           94                  1  2.0   2.0   7.9
# 28           29        295           95                  1  2.0   2.0   7.2
# 79           80        294           95                  1  3.4   2.0   7.4
# 347         348        299           96                  1  3.4   1.0   7.3
# 78           79        296           97                  2  3.0   2.0   7.5
#
#      research  chance_of_admit_  gre_to_toefl_ratio gre_level  normalized  \
# 368         0              0.51                 NaN       Low    0.354839
# 28          0              0.46            3.172043       Low    0.129032
# 79          0              0.46                 NaN       Low    0.193548
# 347         0              0.42                 NaN       Low    0.161290
# 78          1              0.44                 NaN       Low    0.225806
#
#      weighted_score rating-research country  difference
# ...

# %%
#86.Add a new DataFrame containing only students with Research = 1 and merge it with main dataset.
new=data[data['research']==1]

# %%
merge_data=pd.merge(data,new,left_on="serial_no.",right_on="serial_no.",how="inner")

# %%
merge_data
# Out:
#      serial_no.  gre_score_x  toefl_score_x  university_rating_x  sop_x  \
# 0             1          337            120                    4    4.5
# 1             2          324            109                    4    4.0
# 2             3          316            106                    3    3.0
# 3             4          322            112                    3    3.5
# 4             6          330            117                   10    4.5
# ..          ...          ...            ...                  ...    ...
# 214         395          329            113                    4    4.5
# 215         396          324            112                    3    3.5
# 216         397          325            109                    3    3.0
# 217         398          330            118                    4    5.0
# 218         400          333            119                    4    5.0
#
#      lor__x  cgpa_x  research_x  chance_of_admit__x  gre_to_toefl_ratio_x  \
# ...

# %%
merge_data["research_x"].unique()
# Out:
# array([1])

# %%
#87.Create two DataFrames — one for Research = 0, another for Research = 1 — and concatenate them.

# %%
new2=data[data['research']==0]

# %%
merge_r_inner=pd.merge(new,new2,left_on="serial_no.",right_on="serial_no.",how="inner")

# %%
merge_r_inner
# Out:
# Empty DataFrame
# Columns: [serial_no., gre_score_x, toefl_score_x, university_rating_x, sop_x, lor__x, cgpa_x, research_x, chance_of_admit__x, gre_to_toefl_ratio_x, gre_level_x, normalized_x, weighted_score_x, rating-research_x, country_x, difference_x, gre_score_y, toefl_score_y, university_rating_y, sop_y, lor__y, cgpa_y, research_y, chance_of_admit__y, gre_to_toefl_ratio_y, gre_level_y, normalized_y, weighted_score_y, rating-research_y, country_y, difference_y]
# Index: []
#
# [0 rows x 31 columns]

# %%
merge_r_outer=pd.merge(new,new2,left_on="serial_no.",right_on="serial_no.",how="outer")

# %%
merge_r_outer
# Out:
#      serial_no.  gre_score_x  toefl_score_x  university_rating_x  sop_x  \
# 0             1        337.0          120.0                  4.0    4.5
# 1             2        324.0          109.0                  4.0    4.0
# 2             3        316.0          106.0                  3.0    3.0
# 3             4        322.0          112.0                  3.0    3.5
# 4             5          NaN            NaN                  NaN    NaN
# ..          ...          ...            ...                  ...    ...
# 395         396        324.0          112.0                  3.0    3.5
# 396         397        325.0          109.0                  3.0    3.0
# 397         398        330.0          118.0                  4.0    5.0
# 398         399          NaN            NaN                  NaN    NaN
# 399         400        333.0          119.0                  4.0    5.0
#
#      lor__x  cgpa_x  research_x  chance_of_admit__x  gre_to_toefl_ratio_x  \
# ...

# %%
#88.Merge two datasets on University Rating.
new_u=pd.merge(data,merge_data,left_on="university_rating",right_on="university_rating_x",how="inner")

# %%
new_u
# Out:
#        serial_no._x  gre_score  toefl_score  university_rating  sop  lor_  \
# 0                 1        337          120                  4  4.5   4.5
# 1                 1        337          120                  4  4.5   4.5
# 2                 1        337          120                  4  4.5   4.5
# 3                 1        337          120                  4  4.5   4.5
# 4                 1        337          120                  4  4.5   4.5
# ...             ...        ...          ...                ...  ...   ...
# 20478           400        333          119                  4  5.0   4.0
# 20479           400        333          119                  4  5.0   4.0
# 20480           400        333          119                  4  5.0   4.0
# 20481           400        333          119                  4  5.0   4.0
# 20482           400        333          119                  4  5.0   4.0
#
#        cgpa  research  chance_of_admit_  gre_to_toefl_ratio  ... cgpa_y  \
# ...

# %%
#89.Join two DataFrames with same index using .join().
df1 = pd.DataFrame({'A': [1, 2, 3], 'B': [4, 5, 6]}, index=['X', 'Y', 'Z'])
df2 = pd.DataFrame({'C': [7, 8, 9], 'D': [10, 11, 12]}, index=['X', 'Y', 'Z'])

# %%
joined_df=df1.join(df2)

# %%
joined_df
# Out:
#    A  B  C   D
# X  1  4  7  10
# Y  2  5  8  11
# Z  3  6  9  12

# %%
#90.Use .loc[] to select students with index from 10 to 20.
data.loc[10:20]
# Out:
#     serial_no.  gre_score  toefl_score  university_rating  sop  lor_  cgpa  \
# 10          11        325          108                  3  3.5   4.0   8.4
# 11          12        327          113                  4  4.0   4.5   9.0
# 12          13        328          114                  4  4.0   4.5   9.1
# 13          14        307          111                  3  4.0   3.0   8.0
# 14          15        311          106                  3  3.5   2.0   8.2
# 15          16        314          107                  3  3.5   2.5   8.3
# 16          17        317          109                  3  4.0   3.0   8.7
# 17          18        319          108                  3  4.0   3.0   8.0
# 18          19        318          112                  3  4.0   3.0   8.8
# 19          20        303          104                  3  3.5   3.0   8.5
# 20          21        312          109                  3  3.0   2.0   7.9
#
# ...

# %%
#91.Use .iloc[] to select the first 5 rows and first 3 columns.
data.iloc[:5,:3]
# Out:
#    serial_no.  gre_score  toefl_score
# 0           1        337          120
# 1           2        324          109
# 2           3        316          106
# 3           4        322          112
# 4           5        314          105

# %%
#92.Display all columns except Serial No..
df_without_serial=data.drop("serial_no.",axis=1)

# %%
df_without_serial
# Out:
#      gre_score  toefl_score  university_rating  sop  lor_  cgpa  research  \
# 0          337          120                  4  4.5   4.5   9.6         1
# 1          324          109                  4  4.0   4.5   8.9         1
# 2          316          106                  3  3.0   3.5   8.0         1
# 3          322          112                  3  3.5   2.5   8.7         1
# 4          314          105                  2  2.0   3.0   8.2         0
# ..         ...          ...                ...  ...   ...   ...       ...
# 395        324          112                  3  3.5   3.5   9.0         1
# 396        325          109                  3  3.0   3.5   9.1         1
# 397        330          118                  4  5.0   4.5   9.4         1
# 398        312          105                  3  3.5   4.0   8.8         0
# 399        333          119                  4  5.0   4.0   9.7         1
#
#      chance_of_admit_  gre_to_toefl_ratio gre_level  normalized  \
# ...

# %%
#93.Select only GRE Score, TOEFL Score, and CGPA columns.
data[["gre_score",'toefl_score','cgpa']]
# Out:
#      gre_score  toefl_score  cgpa
# 0          337          120   9.6
# 1          324          109   8.9
# 2          316          106   8.0
# 3          322          112   8.7
# 4          314          105   8.2
# ..         ...          ...   ...
# 395        324          112   9.0
# 396        325          109   9.1
# 397        330          118   9.4
# 398        312          105   8.8
# 399        333          119   9.7
#
# [400 rows x 3 columns]

# %%
#94.Sort all rows in reverse alphabetical order of index.
data.sort_index(ascending=False)
# Out:
#      serial_no.  gre_score  toefl_score  university_rating  sop  lor_  cgpa  \
# 399         400        333          119                  4  5.0   4.0   9.7
# 398         399        312          105                  3  3.5   4.0   8.8
# 397         398        330          118                  4  5.0   4.5   9.4
# 396         397        325          109                  3  3.0   3.5   9.1
# 395         396        324          112                  3  3.5   3.5   9.0
# ..          ...        ...          ...                ...  ...   ...   ...
# 4             5        314          105                  2  2.0   3.0   8.2
# 3             4        322          112                  3  3.5   2.5   8.7
# 2             3        316          106                  3  3.0   3.5   8.0
# 1             2        324          109                  4  4.0   4.5   8.9
# 0             1        337          120                  4  4.5   4.5   9.6
#
# ...

# %%
#95.Extract rows with even index numbers only.
data.iloc[::2]
# Out:
#      serial_no.  gre_score  toefl_score  university_rating  sop  lor_  cgpa  \
# 0             1        337          120                  4  4.5   4.5   9.6
# 2             3        316          106                  3  3.0   3.5   8.0
# 4             5        314          105                  2  2.0   3.0   8.2
# 6             7        321          111                  3  3.0   4.0   8.2
# 8             9        302          104                  1  2.0   1.5   8.0
# ..          ...        ...          ...                ...  ...   ...   ...
# 390         391        314          104                  2  2.0   2.5   8.2
# 392         393        326          114                  4  4.0   3.5   9.1
# 394         395        329          113                  4  4.5   4.0   9.2
# 396         397        325          109                  3  3.0   3.5   9.1
# 398         399        312          105                  3  3.5   4.0   8.8
#
# ...

# %%
#96.Display first and last 3 rows of dataset together.
first_three=data.head(3)
last_three=data.tail(3)

# %%
conc=pd.concat([first_three,last_three])

# %%
conc
# Out:
#      serial_no.  gre_score  toefl_score  university_rating  sop  lor_  cgpa  \
# 0             1        337          120                  4  4.5   4.5   9.6
# 1             2        324          109                  4  4.0   4.5   8.9
# 2             3        316          106                  3  3.0   3.5   8.0
# 397         398        330          118                  4  5.0   4.5   9.4
# 398         399        312          105                  3  3.5   4.0   8.8
# 399         400        333          119                  4  5.0   4.0   9.7
#
#      research  chance_of_admit_  gre_to_toefl_ratio gre_level  normalized  \
# 0           1              0.92                 NaN      High    0.903226
# 1           1              0.76                 NaN      High    0.677419
# 2           1              0.72                 NaN       Low    0.387097
# 397         1              0.91            2.844828      High    0.838710
# ...

# %%
#97.Combine two DataFrames vertically using pd.concat().
df1 = pd.DataFrame({
    'Name': ['Alice', 'Bob'],
    'Age': [25, 30],
    'City': ['New York', 'London']
})
df2 = pd.DataFrame({
    'Name': ['Charlie', 'David'],
    'Age': [35, 40],
    'City': ['Paris', 'Tokyo']
})

# %%
df1
# Out:
#     Name  Age      City
# 0  Alice   25  New York
# 1    Bob   30    London

# %%
df2
# Out:
#       Name  Age   City
# 0  Charlie   35  Paris
# 1    David   40  Tokyo

# %%
concat=pd.concat([df1,df2],ignore_index=True)

# %%
concat
# Out:
#       Name  Age      City
# 0    Alice   25  New York
# 1      Bob   30    London
# 2  Charlie   35     Paris
# 3    David   40     Tokyo

# %%
#98.Sort dataset based on the rounded value of Chance of Admit.
# Out:
# 0.09999999999999964

# %%
#data.sort_values(by=data["chance_of_admit_"].apply(round),ascending=True)

# %%
data.sort_values(by=["chance_of_admit_"],ascending=True)
# Out:
#      serial_no.  gre_score  toefl_score  university_rating  sop  lor_  cgpa  \
# 92           93        298          100                  2  4.0   3.0   8.0
# 376         377        297           98                  2  2.5   2.0   7.4
# 94           95        303          101                  3  2.0   2.5   7.7
# 58           59        300          101                  1  3.0   2.0   6.8
# 375         376        304          103                  2  2.0   2.5   7.7
# ..          ...        ...          ...                ...  ...   ...   ...
# 81           82        340          122                  4  5.0   5.0   9.5
# 203         204        334          122                 10  4.0   5.0   9.9
# 202         203        340          122                 10  4.5   4.5   9.9
# 143         144        340          122                  4  4.5   4.0   9.9
# 24           25        336          121                 10  4.0   3.5   9.8
#
# ...

# %%
data["chance_of_admit_"].unique()
# Out:
# array([0.92, 0.76, 0.72, 0.8 , 0.65, 0.9 , 0.75, 0.68, 0.5 , 0.45, 0.52,
#        0.84, 0.78, 0.62, 0.61, 0.54, 0.66, 0.63, 0.64, 0.7 , 0.94, 0.95,
#        0.97, 0.44, 0.46, 0.74, 0.91, 0.88, 0.58, 0.48, 0.49, 0.53, 0.87,
#        0.86, 0.89, 0.82, 0.56, 0.36, 0.42, 0.47, 0.55, 0.57, 0.96, 0.93,
#        0.38, 0.34, 0.79, 0.71, 0.69, 0.59, 0.85, 0.77, 0.81, 0.83, 0.67,
#        0.73, 0.6 , 0.43, 0.51, 0.39])

# %%
#99.Rearrange columns alphabetically.
data.sort_index(axis=1)
# Out:
#      cgpa  chance_of_admit_ country  difference gre_level  gre_score  \
# 0     9.6              0.92   India         217      High        337
# 1     8.9              0.76   India         215      High        324
# 2     8.0              0.72   India         210       Low        316
# 3     8.7              0.80   India         210      High        322
# 4     8.2              0.65   India         209       Low        314
# ..    ...               ...     ...         ...       ...        ...
# 395   9.0              0.82   India         212      High        324
# 396   9.1              0.84   India         216      High        325
# 397   9.4              0.91   India         212      High        330
# 398   8.8              0.67   India         207       Low        312
# 399   9.7              0.95   India         214      High        333
#
#      gre_to_toefl_ratio  lor_  normalized rating-research  research  \
# 0                   NaN   4.5    0.903226           4 Yes         1
# ...
